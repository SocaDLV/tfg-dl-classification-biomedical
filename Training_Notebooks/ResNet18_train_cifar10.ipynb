# %% [markdown]
# Flowers Classification
#
#
# Dataset [here](https://public.roboflow.ai/classification/flowers)

# %% [markdown]
# ## Intro

# %% [markdown]
# ### About Fastai
# If you haven't heard of `Fastai` yet I recommend taking a look at their [homepage](https://www.fast.ai/). In their mission statement it is stated that not only do they want to accelerate and help deep learning research, they also want to decrease the entry barriers for everyone. This line is from their introduction of `PyTorch` for `Fastai` back in September 2017 [(Source)](https://www.fast.ai/2017/09/08/introducing-pytorch-for-fastai/):
#
#     Everybody should be able to use deep learning to solve their problems with no more education than it takes to use a smart phone. Therefore, each year our main research goal is to be able to teach a wider range of deep learning applications, that run faster, and are more accurate, to people with less prerequisites.
#
# You can feel this ambition even if you watch `Fastai`'s 2019 course, and it's something that gives me a good feeling about the direction the field is headed. As it often happens in research, knowledge and tools are only accessible to a certain minority. This is even more pronounced in deep learning research, where you need huge amounts of RAM in powerful GPUs to solve a lot of problems (check this unrelated [video](https://www.youtube.com/watch?v=-P28LKWTzrI) on GPU vs CPU).

# %% [markdown]
# ### Setting up Google Colab
# To avoid redundancy online, please check this [Medium post](https://towardsdatascience.com/fast-ai-lesson-1-on-google-colab-free-gpu-d2af89f53604) by [Manikanta Yadunanda](https://towardsdatascience.com/@manikantayadunanda) for a quick introduction on how to use the Google Colaboratory (Colab) with `Fastai`. Since this introduction was written, Google has included official `Fastai` and `PyTorch` support in Colab. You can check with the following line of code if all of the important `pip` packages are installed. If not, uncomment the last line and use it to install `Fastai` and `PyTorch` for Python 3.6.x and CUDA 9.x.

# %%
# Check if fastai and pytorch are installed
# !pip list | grep -e fastai -e torch -e torchvision
# Out:
# fastai                             2.7.18
# torch                              2.5.1+cu121
# torchaudio                         2.5.1+cu121
# torchsummary                       1.5.1
# torchvision                        0.20.1+cu121

# %%
# If not, uncomment this line and run to install them
#!pip install torch torchvision fastai

# %% [markdown]
# ### Cloning this Notebook
# To access this notebook and run the computations yourself, you can simply import it directly from my GitHub repository. Just go to File... Open Notebook..., select the GitHub tab and enter 'verrannt/Tutorials' in the search bar. Select the 'fastai-plant-seedlings-classification.ipynb' and you're done. Simple as that. After you checked that Colab is configured for `Fastai` support, you can continue with the data preperation part.

# %% [markdown]
# ## Data Preperation

# %% [markdown]
# ### Get the Data
#
# We'll grab our data from Roboflow.
#
# Select `Export`, and "Show Download Code".

# %%
# !curl -L "https://app.roboflow.com/ds/zT1ZSZX7xt?key=ZcnDlnCNyN" > roboflow.zip; unzip roboflow.zip; rm roboflow.zip
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
#  extracting: train/truck/delivery_truck_s_000743_png.rf.6162efbc9644f989a44ab4c95811f095.jpg
#  extracting: train/truck/delivery_truck_s_000755_png.rf.7762f2c3daee9dd33ba2490ea65e37fa.jpg
#  extracting: train/truck/delivery_truck_s_000760_png.rf.eac1dd08184854e1a6774fa87b6ab3e9.jpg
#  extracting: train/truck/delivery_truck_s_000768_png.rf.62bb392f0a9a28c92ffd53ac62bad56f.jpg
#  extracting: train/truck/delivery_truck_s_000780_png.rf.371023925f19e590fd5ecfa80355041b.jpg
#  extracting: train/truck/delivery_truck_s_000783_png.rf.20a113bd52349f42cce3ca9fb427a87a.jpg
#  extracting: train/truck/delivery_truck_s_000785_png.rf.968b03ee467130d4d90c9b67530edac3.jpg
#  extracting: train/truck/delivery_truck_s_000786_png.rf.53dd004a53d2a946d66784bf26b83419.jpg
#  extracting: train/truck/delivery_truck_s_000799_png.rf.9e2a08cf5933b87bf04dbf2903d05379.jpg
#  extracting: train/truck/delivery_truck_s_000800_png.rf.9e03576fc3b79605a528a0968c65a974.jpg
#  extracting: train/truck/delivery_truck_s_000806_png.rf.22b959d7f620fb3d2f69f8ccf1886be7.jpg
#  extracting: train/truck/delivery_truck_s_000813_png.rf.411019ef90b00b698d25d76d5788c122.jpg
#  extracting: train/truck/delivery_truck_s_000816_png.rf.4bed7b830089458da946820b63deab98.jpg
#  extracting: train/truck/delivery_truck_s_000818_png.rf.b2caaca90c6a74ccff9fff6a3e4f3633.jpg
#  extracting: train/truck/delivery_truck_s_000819_png.rf.c378787077b26e94bc50c38118227ff5.jpg
#  extracting: train/truck/delivery_truck_s_000834_png.rf.1bce770ec624125a1bb660b7a2f1654d.jpg
#  extracting: train/truck/delivery_truck_s_000857_png.rf.620284dfc6bacbfc0bd61e86e9e18972.jpg
#  extracting: train/truck/delivery_truck_s_000864_png.rf.4b3f2c330e851ab0d0524d787bd1f77a.jpg
#  extracting: train/truck/delivery_truck_s_000866_png.rf.6be852c1014fc15f99918dbdf4016d6e.jpg
#  extracting: train/truck/delivery_truck_s_000867_png.rf.46b4bd31cab9f6b45ddaca33694d1c55.jpg
#  extracting: train/truck/delivery_truck_s_000868_png.rf.60b374dd58611a8e23f3761d704940c3.jpg
#  extracting: train/truck/delivery_truck_s_000869_png.rf.b0734c35520c486787ac671983ae0ce8.jpg
#  extracting: train/truck/delivery_truck_s_000871_png.rf.7be3624f5a9be99f3a02b4c9a1e83e39.jpg
#  extracting: train/truck/delivery_truck_s_000880_png.rf.1cb33d96352dc91414b05cf896a0b065.jpg
#  extracting: train/truck/delivery_truck_s_000893_png.rf.641b5a30254f922f60917d1415c04641.jpg
#  extracting: train/truck/delivery_truck_s_000898_png.rf.c2e13d31b7b3c58b3c0f12ea46b596ff.jpg
#  extracting: train/truck/delivery_truck_s_000901_png.rf.b87b79193b62ea36fa077526277b9f2f.jpg
#  extracting: train/truck/delivery_truck_s_000915_png.rf.42fb8bcaf120259ec0775d80d94ae049.jpg
#  extracting: train/truck/delivery_truck_s_000918_png.rf.b11a4a6956b7cf4a1007b84485cbde5d.jpg
#  extracting: train/truck/delivery_truck_s_000922_png.rf.5addfb796795e953ae3142623f2ad794.jpg
#  extracting: train/truck/delivery_truck_s_000925_png.rf.014d260982e6b59f6827e17ce5155d40.jpg
#  extracting: train/truck/delivery_truck_s_000927_png.rf.b4e991533e0f11e50eaa548901cc02c7.jpg
#  extracting: train/truck/delivery_truck_s_000928_png.rf.ce156181a7439f017aeb497ecc522332.jpg
#  extracting: train/truck/delivery_truck_s_000931_png.rf.424634bcd4d9266a4932a38a11119c2d.jpg
#  extracting: train/truck/delivery_truck_s_000933_png.rf.b9bd9827a0fd6b7832cf67e1d6e4a3bb.jpg
#  extracting: train/truck/delivery_truck_s_000934_png.rf.38c8358246159f4e9a86df20a6e6381c.jpg
#  extracting: train/truck/delivery_truck_s_000965_png.rf.6f0fa66b9ea7fc06658263f2703514b0.jpg
#  extracting: train/truck/delivery_truck_s_000968_png.rf.add8069965d4dee957d665212757dacf.jpg
#  extracting: train/truck/delivery_truck_s_000974_png.rf.0345ec348ed5a75c8ba6284b5475e8c5.jpg
#  extracting: train/truck/delivery_truck_s_000975_png.rf.23ca44ee556fb96a8af2547ce60d1c26.jpg
#  extracting: train/truck/delivery_truck_s_000977_png.rf.a42481c6f3fbb4839bb156aa76767ce8.jpg
#  extracting: train/truck/delivery_truck_s_000979_png.rf.ba6c7374133e5287a3321f608c16f620.jpg
#  extracting: train/truck/delivery_truck_s_000980_png.rf.ada1a39bb4b03fc64a07a2633cdcdc83.jpg
#  extracting: train/truck/delivery_truck_s_000981_png.rf.c27385149341325b45a3a39c81814ea7.jpg
#  extracting: train/truck/delivery_truck_s_000982_png.rf.ffc276d38148e0c1a55dbce5bd2c4ba3.jpg
#  extracting: train/truck/delivery_truck_s_000983_png.rf.99b4ae4cc2ffffa7b44494dbfb8fd069.jpg
#  extracting: train/truck/delivery_truck_s_000984_png.rf.eb416f8e2a00172b4ea4f32413103970.jpg
#  extracting: train/truck/delivery_truck_s_000988_png.rf.383ed79fe0be5f8b24a8e897fb8a54f5.jpg
#  extracting: train/truck/delivery_truck_s_000989_png.rf.418b5f202009c5efb5661df7d715d15a.jpg
#  extracting: train/truck/delivery_truck_s_000991_png.rf.80bab73e9e8387bd1fdb23e236cba871.jpg
#  extracting: train/truck/delivery_truck_s_000993_png.rf.6a51f7447e760ad7b0657e2c9c485658.jpg
#  extracting: train/truck/delivery_truck_s_000998_png.rf.9dec4217ce17349d060134865d1e8311.jpg
#  extracting: train/truck/delivery_truck_s_000999_png.rf.8ae865f2cb10bceeeee4bdf61ef6491b.jpg
#  extracting: train/truck/delivery_truck_s_001000_png.rf.6f3f8c91b37c2a206f7299b4d23b0cb2.jpg
#  extracting: train/truck/delivery_truck_s_001007_png.rf.8868f029eeccc08f335c4f86350f095c.jpg
#  extracting: train/truck/delivery_truck_s_001010_png.rf.a01ff6bba31ce29bbc7f1a1cdfdd3c51.jpg
#  extracting: train/truck/delivery_truck_s_001014_png.rf.bc120dea2677ca8f95f815b0fc5038d7.jpg
#  extracting: train/truck/delivery_truck_s_001024_png.rf.acad48d509c23e266125a431403201ca.jpg
#  extracting: train/truck/delivery_truck_s_001026_png.rf.5465c4b2e3c67fea6473de19c8d740b9.jpg
#  extracting: train/truck/delivery_truck_s_001027_png.rf.1956b4407e6a9dd9df22f4948c1e83e9.jpg
#  extracting: train/truck/delivery_truck_s_001034_png.rf.e9bdc8d6dfe64a184bc3094481fd6b0e.jpg
#  extracting: train/truck/delivery_truck_s_001038_png.rf.9bd890432b56b5608bfed92db6efc4de.jpg
#  extracting: train/truck/delivery_truck_s_001040_png.rf.067e2caba19c659b47c89f6dca003bbb.jpg
#  extracting: train/truck/delivery_truck_s_001041_png.rf.1ee06c17779875e8dd6a8e7b44dbe7b9.jpg
#  extracting: train/truck/delivery_truck_s_001049_png.rf.3787b836e2d169c6c70be8a598c815fc.jpg
#  extracting: train/truck/delivery_truck_s_001052_png.rf.b6c352c9c22b79a221287efee9b1f2b4.jpg
#  extracting: train/truck/delivery_truck_s_001068_png.rf.9627af6477b0fced4f0392d3929f776e.jpg
#  extracting: train/truck/delivery_truck_s_001073_png.rf.d238148f5f728cdfb1af82f3996f2652.jpg
#  extracting: train/truck/delivery_truck_s_001088_png.rf.c2c271f3320c1b882e0c0528865cca04.jpg
#  extracting: train/truck/delivery_truck_s_001100_png.rf.ba1dc82402126e5bf0a1d72a3e831834.jpg
#  extracting: train/truck/delivery_truck_s_001102_png.rf.3ce49da39e62d658c9f5bda7fac94d33.jpg
#  extracting: train/truck/delivery_truck_s_001106_png.rf.da77d190bc9547c4dbc68d88cd79f37a.jpg
#  extracting: train/truck/delivery_truck_s_001107_png.rf.b66d3b5b453da98447ef8cea28e051a2.jpg
#  extracting: train/truck/delivery_truck_s_001108_png.rf.f809d1400eb7f89cbfda79a66568e1ed.jpg
#  extracting: train/truck/delivery_truck_s_001110_png.rf.2eb4ad2cf94fc12b80ced1c243fb3018.jpg
#  extracting: train/truck/delivery_truck_s_001111_png.rf.cbf6b063075832bb26a873f935f2a6fe.jpg
#  extracting: train/truck/delivery_truck_s_001112_png.rf.4fa4f0855f18e44506795a579af333b3.jpg
#  extracting: train/truck/delivery_truck_s_001113_png.rf.b415cc6fab04995812d33edc787ca6c4.jpg
#  extracting: train/truck/delivery_truck_s_001114_png.rf.066921a8b733927112478c9f8dc114d2.jpg
#  extracting: train/truck/delivery_truck_s_001116_png.rf.0382c9ea3f9f96b0031b728cbeeeb8d5.jpg
#  extracting: train/truck/delivery_truck_s_001120_png.rf.d321353ca64b06c3baaf05fb4253678b.jpg
#  extracting: train/truck/delivery_truck_s_001121_png.rf.80e3c5d4df807848cc00c587572239ab.jpg
#  extracting: train/truck/delivery_truck_s_001123_png.rf.00aecdbef89bfb2637e51ee5e2eb06fa.jpg
#  extracting: train/truck/delivery_truck_s_001125_png.rf.572104e45870c5921f4ef7d9babe50dd.jpg
#  extracting: train/truck/delivery_truck_s_001126_png.rf.12375262387fd2ba9848d13297043223.jpg
#  extracting: train/truck/delivery_truck_s_001130_png.rf.e214b0176fb570a8a60f0dfbc7d9b89e.jpg
#  extracting: train/truck/delivery_truck_s_001133_png.rf.43e4a75fe711ea3b3d1b3ac0e987cf31.jpg
#  extracting: train/truck/delivery_truck_s_001144_png.rf.94115c2a7aa053650349264e4f58cf65.jpg
#  extracting: train/truck/delivery_truck_s_001157_png.rf.aff2fc8537762513b658e4a63c08777c.jpg
#  extracting: train/truck/delivery_truck_s_001158_png.rf.b1693b329a68120a0dbbdb36be9d46ed.jpg
#  extracting: train/truck/delivery_truck_s_001162_png.rf.93913920112fd1a8d417b6cdb0972065.jpg
#  extracting: train/truck/delivery_truck_s_001167_png.rf.276789551479f365eadb8f6cdbedde4c.jpg
#  extracting: train/truck/delivery_truck_s_001179_png.rf.575dc6f1ec11f9f61d0ff71ee51b0ccd.jpg
#  extracting: train/truck/delivery_truck_s_001182_png.rf.07adf28908cf5507a162260559d2d735.jpg
#  extracting: train/truck/delivery_truck_s_001184_png.rf.e34dff630f9fee7905dda87e0ba0ed0e.jpg
#  extracting: train/truck/delivery_truck_s_001188_png.rf.84116e57bba23ed16f02e143e0ffc514.jpg
#  extracting: train/truck/delivery_truck_s_001201_png.rf.c901dd43d8269d72df7dc7e84eeeff61.jpg
#  extracting: train/truck/delivery_truck_s_001202_png.rf.c54e372c178351d0cbd8450d243ee02a.jpg
#  extracting: train/truck/delivery_truck_s_001203_png.rf.b0fc3a3c36bb449aaf55597e73a537cf.jpg
#  extracting: train/truck/delivery_truck_s_001204_png.rf.ef8cedd683ad31cfe41902260719fb53.jpg
#  extracting: train/truck/delivery_truck_s_001217_png.rf.692a7522a616e431e02a52cf15a912d8.jpg
#  extracting: train/truck/delivery_truck_s_001218_png.rf.b68f90c2f1a0d0aa2dfb40f18bfcbe4c.jpg
#  extracting: train/truck/delivery_truck_s_001221_png.rf.b15affd154136d990ea43763e881dcfc.jpg
#  extracting: train/truck/delivery_truck_s_001223_png.rf.5f867a3ca9cce0821b22fa0918755338.jpg
#  extracting: train/truck/delivery_truck_s_001228_png.rf.cff9fecda0ef85f4f8829e21761b3c6e.jpg
#  extracting: train/truck/delivery_truck_s_001230_png.rf.0606d8822cc365a9f99cea12c36a9915.jpg
#  extracting: train/truck/delivery_truck_s_001231_png.rf.c9ce344d7f9477146c6ad7e9ce3feb5c.jpg
#  extracting: train/truck/delivery_truck_s_001270_png.rf.3593461d8f421f6cc978555d86b1936a.jpg
#  extracting: train/truck/delivery_truck_s_001281_png.rf.08a8aae77510e7494d4af5a68ac1f48f.jpg
#  extracting: train/truck/delivery_truck_s_001282_png.rf.06f2e5e04d4c380e01112385dfb671fa.jpg
#  extracting: train/truck/delivery_truck_s_001288_png.rf.464e2ae8fa0cb4a71eac6a9aca38eec3.jpg
#  extracting: train/truck/delivery_truck_s_001289_png.rf.4be3d8ec2617f6e250ae66e2b61ebac9.jpg
#  extracting: train/truck/delivery_truck_s_001293_png.rf.4286afeab3e1c20ee6b760c668005c75.jpg
#  extracting: train/truck/delivery_truck_s_001294_png.rf.1ed6e0c8b10b6e9dbf8bb45ef6720c1c.jpg
#  extracting: train/truck/delivery_truck_s_001299_png.rf.6a47707d8e608cedc3c138093442d822.jpg
#  extracting: train/truck/delivery_truck_s_001300_png.rf.81cabd68a59ec123640e84b5b26231c6.jpg
#  extracting: train/truck/delivery_truck_s_001301_png.rf.38490e9096b8259ec7cc2208cb18f269.jpg
#  extracting: train/truck/delivery_truck_s_001304_png.rf.265c7ecfad5737fdde338991d237907c.jpg
#  extracting: train/truck/delivery_truck_s_001306_png.rf.6affbffe27255e43a3392bbb69facf8a.jpg
#  extracting: train/truck/delivery_truck_s_001308_png.rf.b30e396fff8825608709c054be1a395a.jpg
#  extracting: train/truck/delivery_truck_s_001311_png.rf.e522626fcd1e60df2b5cb1e6d6e861ae.jpg
#  extracting: train/truck/delivery_truck_s_001312_png.rf.567e0fd8edacc327fdbdf1e7d7b8c6e1.jpg
#  extracting: train/truck/delivery_truck_s_001315_png.rf.3678fea9da1f6391b3e9b91ed08b1504.jpg
#  extracting: train/truck/delivery_truck_s_001317_png.rf.873a572196cc77be08a01e4347755f29.jpg
#  extracting: train/truck/delivery_truck_s_001328_png.rf.4df8c64642aef48505f189e3b65b2ce0.jpg
#  extracting: train/truck/delivery_truck_s_001353_png.rf.018dffb8a7ba1d88633eb1d5e62bebf4.jpg
#  extracting: train/truck/delivery_truck_s_001358_png.rf.2ba237028697b56b5c7a16d3b0e865f5.jpg
#  extracting: train/truck/delivery_truck_s_001359_png.rf.cf309278be4ca5e900d6651ecb378a75.jpg
#  extracting: train/truck/delivery_truck_s_001366_png.rf.47612d71e51eb4bb14102904a55e2c4f.jpg
#  extracting: train/truck/delivery_truck_s_001370_png.rf.ee4d5bfa0d8ce8feae7e5b1b3d1b56fe.jpg
#  extracting: train/truck/delivery_truck_s_001375_png.rf.27a1a54376c5191009fd4ad3bb05bc58.jpg
#  extracting: train/truck/delivery_truck_s_001376_png.rf.57644a203b60b59b4947d6ddbaaf7ff1.jpg
#  extracting: train/truck/delivery_truck_s_001383_png.rf.b0cba4b334619f23f04921200a035662.jpg
#  extracting: train/truck/delivery_truck_s_001397_png.rf.9f77e8e62a4d17e77cf6609fc1f661aa.jpg
#  extracting: train/truck/delivery_truck_s_001399_png.rf.878e9014a0e81e4cbd717279c6a6385b.jpg
#  extracting: train/truck/delivery_truck_s_001401_png.rf.2f214ee000593ec68c08d4e35aa5016e.jpg
#  extracting: train/truck/delivery_truck_s_001414_png.rf.c853adf3c25b81d592294bbcd26f6b33.jpg
#  extracting: train/truck/delivery_truck_s_001434_png.rf.784ca94666ff9013a373d7686b466bc0.jpg
#  extracting: train/truck/delivery_truck_s_001454_png.rf.a43cc86f2caf2f112d05a315f89c3610.jpg
#  extracting: train/truck/delivery_truck_s_001458_png.rf.c9e5edc5615b9c4fa91c2f2aeb8948dd.jpg
#  extracting: train/truck/delivery_truck_s_001459_png.rf.127bdd00a614500b09dbc7f088534454.jpg
#  extracting: train/truck/delivery_truck_s_001460_png.rf.4c190a251052937e330ff9d6f96149bf.jpg
#  extracting: train/truck/delivery_truck_s_001461_png.rf.04bdf7e27fa8c7bcb2b14f6945c44dd5.jpg
#  extracting: train/truck/delivery_truck_s_001462_png.rf.503e52d7989d5af8da9336e2f75f55bc.jpg
#  extracting: train/truck/delivery_truck_s_001463_png.rf.a541a701e29c02b76720fbfc2867f391.jpg
#  extracting: train/truck/delivery_truck_s_001468_png.rf.b0e4abaedd6fc0568cd708b68f11a08f.jpg
#  extracting: train/truck/delivery_truck_s_001470_png.rf.b642a24b71401de2f8dd2daf4155eb5d.jpg
#  extracting: train/truck/delivery_truck_s_001481_png.rf.401d0b62c4d9b893e6e4b133f2238226.jpg
#  extracting: train/truck/delivery_truck_s_001488_png.rf.76901464ffa8b4e77fc448645852d22c.jpg
#  extracting: train/truck/delivery_truck_s_001498_png.rf.aff5510100b8dd038a582a10bd2d9b1d.jpg
#  extracting: train/truck/delivery_truck_s_001500_png.rf.ead538c26ca5f933d7b121c8ddd63bd7.jpg
#  extracting: train/truck/delivery_truck_s_001501_png.rf.d0aa220b3e36b58c413b88a13b51c787.jpg
#  extracting: train/truck/delivery_truck_s_001502_png.rf.8db46b9066883ae8bf7865f72185976a.jpg
#  extracting: train/truck/delivery_truck_s_001517_png.rf.5c29158885975db3aa511687fb4bd552.jpg
#  extracting: train/truck/delivery_truck_s_001518_png.rf.d046e8ced4e137b339db1b47ee2638e6.jpg
#  extracting: train/truck/delivery_truck_s_001526_png.rf.eaf1319f65b562011785660726197978.jpg
#  extracting: train/truck/delivery_truck_s_001527_png.rf.eb30ceb7078fc21b5262ad121878859e.jpg
#  extracting: train/truck/delivery_truck_s_001529_png.rf.e340ab8f31e8e70bc12b45fd4a93e81b.jpg
#  extracting: train/truck/delivery_truck_s_001537_png.rf.9a132d6e36b6427572cec2e372ae0774.jpg
#  extracting: train/truck/delivery_truck_s_001540_png.rf.c4172862aa0dfc29d7fec6c0dd58c8b8.jpg
#  extracting: train/truck/delivery_truck_s_001543_png.rf.a559be389d9862db4892bf87724d651e.jpg
#  extracting: train/truck/delivery_truck_s_001577_png.rf.c3329c24660252248863f65294db713a.jpg
#  extracting: train/truck/delivery_truck_s_001583_png.rf.3ccbd2f39d652472238ffd91eda0ceb2.jpg
#  extracting: train/truck/delivery_truck_s_001587_png.rf.effe572b702333bbe38a73c1bd2ed799.jpg
#  extracting: train/truck/delivery_truck_s_001592_png.rf.06fc7d6a0e847cff4f2492d8444534d9.jpg
#  extracting: train/truck/delivery_truck_s_001610_png.rf.ed0a867dc89d4703ea8109135b1ae63c.jpg
#  extracting: train/truck/delivery_truck_s_001616_png.rf.aabc5e0c509d034accfa931f8da9462e.jpg
#  extracting: train/truck/delivery_truck_s_001618_png.rf.b87f2c15b32dd9a9dea19a06b3368626.jpg
#  extracting: train/truck/delivery_truck_s_001619_png.rf.1f3f5e773760f3c41e66dddc40a1739d.jpg
#  extracting: train/truck/delivery_truck_s_001620_png.rf.fdf769f19f32d096ba2a61f6a191db5d.jpg
#  extracting: train/truck/delivery_truck_s_001625_png.rf.02d49ef35373badb329a972bcbe95c38.jpg
#  extracting: train/truck/delivery_truck_s_001627_png.rf.d6e4f789709444aae732126ea517e079.jpg
#  extracting: train/truck/delivery_truck_s_001634_png.rf.7c37fd905fb008be990bac64a313236b.jpg
#  extracting: train/truck/delivery_truck_s_001637_png.rf.030a50cffc0747396e08c5be6f2d4758.jpg
#  extracting: train/truck/delivery_truck_s_001641_png.rf.151fa9d0dcc000a7b992705469bcb72e.jpg
#  extracting: train/truck/delivery_truck_s_001642_png.rf.5948b45c1a502e3b34ce77b2bd174fa5.jpg
#  extracting: train/truck/delivery_truck_s_001643_png.rf.fb86d20b77f71f718b9b9667a5a16a81.jpg
#  extracting: train/truck/delivery_truck_s_001646_png.rf.4b0f6b0e3e6c61e30c0c69af0a09b741.jpg
#  extracting: train/truck/delivery_truck_s_001647_png.rf.b774706030c98e09853c5402b80ca7f7.jpg
#  extracting: train/truck/delivery_truck_s_001649_png.rf.b419137daa283da7d6e2952afa3fbb6c.jpg
#  extracting: train/truck/delivery_truck_s_001650_png.rf.b90084e68e62d6abb75c442e9e5cc803.jpg
#  extracting: train/truck/delivery_truck_s_001664_png.rf.7c20b56ab2e15eb4d4a473355098290d.jpg
#  extracting: train/truck/delivery_truck_s_001672_png.rf.8ae04307f82010c610cc2dd5bb7dee17.jpg
#  extracting: train/truck/delivery_truck_s_001675_png.rf.d93bd8f96abdd81fcb5aff0c92844a80.jpg
#  extracting: train/truck/delivery_truck_s_001677_png.rf.e668a2fbba5bf2790c64e407a64bc214.jpg
#  extracting: train/truck/delivery_truck_s_001683_png.rf.090180cc52acdb67896c719e8e6f5591.jpg
#  extracting: train/truck/delivery_truck_s_001695_png.rf.ba279c24e038c0a4babcc7b00c965420.jpg
#  extracting: train/truck/delivery_truck_s_001705_png.rf.d04af2c3d6da0853833e68b11445933d.jpg
#  extracting: train/truck/delivery_truck_s_001706_png.rf.9caf76ca96e6202817829747b436f398.jpg
#  extracting: train/truck/delivery_van_s_000003_png.rf.0d2d6da037c31541cac5ea7c7a563e47.jpg
#  extracting: train/truck/delivery_van_s_000036_png.rf.47a527e4ce1b166c5328037e9225e4ad.jpg
#  extracting: train/truck/delivery_van_s_000066_png.rf.f5dd3983979ed229328a032fbd42d079.jpg
#  extracting: train/truck/delivery_van_s_000080_png.rf.a16e6a9cd56c9a6d87a4a64e2f9c9ae2.jpg
#  extracting: train/truck/delivery_van_s_000084_png.rf.7d324d98013aaadc3a61d01ce0267ec3.jpg
#  extracting: train/truck/delivery_van_s_000088_png.rf.3ff5fe9c4a950ab69c4700b366020834.jpg
#  extracting: train/truck/delivery_van_s_000089_png.rf.fd3d90ae09f5ba4f590c896ae80c3be3.jpg
#  extracting: train/truck/delivery_van_s_000090_png.rf.c3641de700639650e1995fdd6e5b719a.jpg
#  extracting: train/truck/delivery_van_s_000093_png.rf.c4403de4f2160df2db726ac163cb5e81.jpg
#  extracting: train/truck/delivery_van_s_000098_png.rf.df50a904dda1d14c00cbc42652e59079.jpg
#  extracting: train/truck/delivery_van_s_000100_png.rf.27df52d758cef892eb7654d896bffe8b.jpg
#  extracting: train/truck/delivery_van_s_000101_png.rf.d1d240cbc003bd0bfcf892511f5d2d4c.jpg
#  extracting: train/truck/delivery_van_s_000107_png.rf.50e5f07f53298b3e1b63fe66a0df744c.jpg
#  extracting: train/truck/delivery_van_s_000110_png.rf.96ff517bab67c5e28e5c1c894356ac43.jpg
#  extracting: train/truck/delivery_van_s_000152_png.rf.e32a3f853758331cb52e6b3930e659de.jpg
#  extracting: train/truck/delivery_van_s_000156_png.rf.68dd4936aeb0a7c308c39b804988f864.jpg
#  extracting: train/truck/delivery_van_s_000244_png.rf.2acef0bc8b9e8e65fe39570446b93ed4.jpg
#  extracting: train/truck/delivery_van_s_000251_png.rf.0611fac8b0d79647a0f8d1f0c23095f1.jpg
#  extracting: train/truck/delivery_van_s_000259_png.rf.59d5cd1a2e402afe5c9d82cd940eb020.jpg
#  extracting: train/truck/delivery_van_s_000261_png.rf.c77aa5248d4796ca62b733f4f62c7184.jpg
#  extracting: train/truck/delivery_van_s_000266_png.rf.248c215379f277c2bb410141e1424356.jpg
#  extracting: train/truck/delivery_van_s_000285_png.rf.793af6404a89a4dec04c1a90dd88542c.jpg
#  extracting: train/truck/delivery_van_s_000286_png.rf.62cf6c8e9a950e1f6babe2d5e1411ecb.jpg
#  extracting: train/truck/delivery_van_s_000294_png.rf.1a10b419ae75216a82c5a87acd93d72e.jpg
#  extracting: train/truck/delivery_van_s_000320_png.rf.c7ba77da873104dddc64f8b746594855.jpg
#  extracting: train/truck/delivery_van_s_000328_png.rf.678990eb358c5709970a552b043c8a66.jpg
#  extracting: train/truck/delivery_van_s_000331_png.rf.f1f28fe289c3e20dd40f6ea6e9aeabd1.jpg
#  extracting: train/truck/delivery_van_s_000380_png.rf.76a22bc8eabada1ca1d3f8280f188e48.jpg
#  extracting: train/truck/delivery_van_s_000387_png.rf.b922400ea9d0df4da5935e4a06ccba10.jpg
#  extracting: train/truck/delivery_van_s_000392_png.rf.3ad6680d193948d8c423f13697589bb4.jpg
#  extracting: train/truck/delivery_van_s_000399_png.rf.b16f16b66e48626f7f73103c41998d00.jpg
#  extracting: train/truck/delivery_van_s_000421_png.rf.d1fdee33c3388ba568116f2fcabdecb9.jpg
#  extracting: train/truck/delivery_van_s_000446_png.rf.a0a2335e4acde6f28ee4f7148d09a181.jpg
#  extracting: train/truck/delivery_van_s_000463_png.rf.c059a79b293a990fee1850a14a1f7216.jpg
#  extracting: train/truck/delivery_van_s_000594_png.rf.d38dca2f24cfcca1110f42fa28db9ab3.jpg
#  extracting: train/truck/delivery_van_s_000645_png.rf.db2f1f47b7c3dc5d7e303af2a363e5e0.jpg
#  extracting: train/truck/delivery_van_s_000730_png.rf.624d422ac4f55fac487dfb3d96ae34b7.jpg
#  extracting: train/truck/delivery_van_s_000735_png.rf.88a304ae90490158097782ee2d6a1b7c.jpg
#  extracting: train/truck/delivery_van_s_000751_png.rf.1d1e38cbd6a030507a621a4d7c57154f.jpg
#  extracting: train/truck/delivery_van_s_000786_png.rf.f7cc97ecb9a42771b79fde07a8decbb2.jpg
#  extracting: train/truck/delivery_van_s_000871_png.rf.4e12196e460aea396361c731d59383cb.jpg
#  extracting: train/truck/delivery_van_s_000960_png.rf.6bcdccce2f39fa03dadce44c117f58c4.jpg
#  extracting: train/truck/delivery_van_s_001012_png.rf.2f64a37fe53f12c8f14c471452b442cd.jpg
#  extracting: train/truck/delivery_van_s_001056_png.rf.c697e80c6cf323c41def6b1533960858.jpg
#  extracting: train/truck/delivery_van_s_001071_png.rf.65054804405445a015839c4911bdeab0.jpg
#  extracting: train/truck/delivery_van_s_001124_png.rf.438272bf0937a84c1a5e491acde619c6.jpg
#  extracting: train/truck/delivery_van_s_001132_png.rf.5bb9ef4cf477b55f3d4b86480106dbdf.jpg
#  extracting: train/truck/delivery_van_s_001145_png.rf.46b613469dc5d2c391cff9894a89434a.jpg
#  extracting: train/truck/delivery_van_s_001189_png.rf.0c372b30ea6b415c3e2f17b74287e0b1.jpg
#  extracting: train/truck/delivery_van_s_001245_png.rf.800d5d9dde0a0d74f6515aae796e614a.jpg
#  extracting: train/truck/delivery_van_s_001268_png.rf.4f3cd4bcf60d68da151c6432b6edfcea.jpg
#  extracting: train/truck/delivery_van_s_001358_png.rf.2abee2ee0ad1099e72e5c48b5f36909a.jpg
#  extracting: train/truck/delivery_van_s_001404_png.rf.99b9f07ba2332a37190f232fbb22b5f5.jpg
#  extracting: train/truck/delivery_van_s_001434_png.rf.7fdccf965c3cdd9adebeb2effe9fc5d3.jpg
#  extracting: train/truck/delivery_van_s_001590_png.rf.198ed4341542e757957833a21bf61d49.jpg
#  extracting: train/truck/delivery_van_s_001628_png.rf.f2bac43f990d7e14fc539d3d94376fd5.jpg
#  extracting: train/truck/delivery_van_s_001717_png.rf.40b1b069b59eaee2f9d4138c35eb776b.jpg
#  extracting: train/truck/delivery_van_s_001727_png.rf.5ee06648080cead66ea6bc9dba67b92c.jpg
#  extracting: train/truck/delivery_van_s_001742_png.rf.e118cdd80a8904df08e09cb7f2a983f1.jpg
#  extracting: train/truck/delivery_van_s_001794_png.rf.53be62e5152793ae43d08868c653943e.jpg
#  extracting: train/truck/delivery_van_s_001847_png.rf.58223a320a657b2b98f0b997d0c32b4b.jpg
#  extracting: train/truck/delivery_van_s_001848_png.rf.814db7c81456e88d69a506a34949277f.jpg
#  extracting: train/truck/dump_truck_s_000001_png.rf.f5621098e92f027318e1ff3f5ec1e27a.jpg
#  extracting: train/truck/dump_truck_s_000006_png.rf.8756aa9a6720974952505317e748f9b3.jpg
#  extracting: train/truck/dump_truck_s_000008_png.rf.6ad04ec7847ff2452971ea72024e5318.jpg
#  extracting: train/truck/dump_truck_s_000009_png.rf.545f9a786b418cc598ec51879eb6e933.jpg
#  extracting: train/truck/dump_truck_s_000010_png.rf.f689f3240cfe7f29869be054dd79aeaa.jpg
#  extracting: train/truck/dump_truck_s_000012_png.rf.239adcf69ea91e4b1e8dad548aae0072.jpg
#  extracting: train/truck/dump_truck_s_000013_png.rf.782a338317dab8d2e95caaa8d9b26f2a.jpg
#  extracting: train/truck/dump_truck_s_000017_png.rf.740d81ffe9e07b1d45952c9c1d000884.jpg
#  extracting: train/truck/dump_truck_s_000018_png.rf.71f234609b60f1e2bd6dc1c4800c3444.jpg
#  extracting: train/truck/dump_truck_s_000019_png.rf.4d9d524282f81d3c279d95486baac5be.jpg
#  extracting: train/truck/dump_truck_s_000020_png.rf.fd0a285c25f4672a1d0061188f7df242.jpg
#  extracting: train/truck/dump_truck_s_000023_png.rf.0f1e5e667fcbbbb90d0ddefb97b30cf7.jpg
#  extracting: train/truck/dump_truck_s_000025_png.rf.e8d380bfe8d9e23302861e2d4a416fa9.jpg
#  extracting: train/truck/dump_truck_s_000028_png.rf.22459564f1f40039aa32299f0a304ce7.jpg
#  extracting: train/truck/dump_truck_s_000029_png.rf.47e5e864194853718281bc0789a79ebb.jpg
#  extracting: train/truck/dump_truck_s_000032_png.rf.1d8f16751afb20ac52e8812a7a8aeb36.jpg
#  extracting: train/truck/dump_truck_s_000038_png.rf.f55b5810d54205ac76ddd01b82a1267c.jpg
#  extracting: train/truck/dump_truck_s_000041_png.rf.42c9b9f201ed18e833210b9e719481be.jpg
#  extracting: train/truck/dump_truck_s_000043_png.rf.9db78e9bbaec11de0842c278305b7d7f.jpg
#  extracting: train/truck/dump_truck_s_000044_png.rf.5660d78dbe6519e1e3760f11cdcaced8.jpg
#  extracting: train/truck/dump_truck_s_000045_png.rf.837c7f69f0c7b9c8dc5eb3210d910e78.jpg
#  extracting: train/truck/dump_truck_s_000049_png.rf.3a282ca920c2b10b0a2f0356ca598f09.jpg
#  extracting: train/truck/dump_truck_s_000051_png.rf.36109d09111a0881e95f54af5b740d04.jpg
#  extracting: train/truck/dump_truck_s_000052_png.rf.ac0419110e52694d8b89cb7b10ccd999.jpg
#  extracting: train/truck/dump_truck_s_000054_png.rf.60dd7c9616917f1350aab87132f0633c.jpg
#  extracting: train/truck/dump_truck_s_000055_png.rf.0054c716bc5c7e9bb2c12861f1bd4895.jpg
#  extracting: train/truck/dump_truck_s_000065_png.rf.89938b203cc88e43773c63d55cd122e7.jpg
#  extracting: train/truck/dump_truck_s_000069_png.rf.590b2c1bf6aa1f48d0bbe6ce8af318f4.jpg
#  extracting: train/truck/dump_truck_s_000070_png.rf.e67e0f2793c497256950a885a1a513f9.jpg
#  extracting: train/truck/dump_truck_s_000074_png.rf.f49783b05974a270b7f13e7e112a91d2.jpg
#  extracting: train/truck/dump_truck_s_000075_png.rf.99b564bba4021cbb76a2d86b31e8b114.jpg
#  extracting: train/truck/dump_truck_s_000080_png.rf.6ceb588edc2ea924c98017c4970fe7a2.jpg
#  extracting: train/truck/dump_truck_s_000092_png.rf.141bbb819b32d76b23ee409a48c682ed.jpg
#  extracting: train/truck/dump_truck_s_000093_png.rf.741d1e90b44c0601059bb82224574f2e.jpg
#  extracting: train/truck/dump_truck_s_000097_png.rf.28c7cbf7926c431bd1aec1c0d7361992.jpg
#  extracting: train/truck/dump_truck_s_000098_png.rf.eaba83e6735ad3278518910ad691642a.jpg
#  extracting: train/truck/dump_truck_s_000104_png.rf.870cf14c0646d1606a784187f4f85b63.jpg
#  extracting: train/truck/dump_truck_s_000106_png.rf.971073ae90d8ccf6c4c790f5c2b22a91.jpg
#  extracting: train/truck/dump_truck_s_000108_png.rf.8e0b36d6a61175aeefa95c8a58970d22.jpg
#  extracting: train/truck/dump_truck_s_000110_png.rf.742d5d9e485c325906350f29e49ff8b3.jpg
#  extracting: train/truck/dump_truck_s_000111_png.rf.06a0bc09b001c0050e042d6d82543b14.jpg
#  extracting: train/truck/dump_truck_s_000112_png.rf.a51e9689defd7b31c223dfd1635ee30d.jpg
#  extracting: train/truck/dump_truck_s_000113_png.rf.60582ce09254b0c15f0488af468ef345.jpg
#  extracting: train/truck/dump_truck_s_000114_png.rf.4e2fe8e49347d5d3e904a1ad649b3a7a.jpg
#  extracting: train/truck/dump_truck_s_000115_png.rf.9f9190602c755667a4162f0d94c786fa.jpg
#  extracting: train/truck/dump_truck_s_000117_png.rf.5e8b693c06ac917d9dcc8e8fb04c476a.jpg
#  extracting: train/truck/dump_truck_s_000119_png.rf.eb53b85f0c1a2da3eae4917233828bae.jpg
#  extracting: train/truck/dump_truck_s_000124_png.rf.15eff7547c22a3efff0cf48c30a91ad3.jpg
#  extracting: train/truck/dump_truck_s_000129_png.rf.6238a9fab44316fefda4209b02372763.jpg
#  extracting: train/truck/dump_truck_s_000132_png.rf.aaa87a4f02f1dc693a1f550fd0820a7a.jpg
#  extracting: train/truck/dump_truck_s_000134_png.rf.3931ad7bc4909c4bb09dcaf812d3497f.jpg
#  extracting: train/truck/dump_truck_s_000138_png.rf.09c3d85f8e83d0133f2291fcd10c15ca.jpg
#  extracting: train/truck/dump_truck_s_000141_png.rf.d41f6ccf62cf438902d041b379f553c7.jpg
#  extracting: train/truck/dump_truck_s_000143_png.rf.7d238af7cc85451bfbdd1843d2d0ade6.jpg
#  extracting: train/truck/dump_truck_s_000145_png.rf.aa3bea1ee6135aba29af10c27fa9251f.jpg
#  extracting: train/truck/dump_truck_s_000147_png.rf.89d0b86fb34eeb361530f42ae1cb0767.jpg
#  extracting: train/truck/dump_truck_s_000150_png.rf.33e0ba2ae839bbd7b0e4cf802a9194b3.jpg
#  extracting: train/truck/dump_truck_s_000152_png.rf.3a2084e5d8306df418dc38b5b5661978.jpg
#  extracting: train/truck/dump_truck_s_000156_png.rf.00b11d96cc67c8da3aba16d99a4a0c40.jpg
#  extracting: train/truck/dump_truck_s_000157_png.rf.22a561dccc697f51fc8172be166f5404.jpg
#  extracting: train/truck/dump_truck_s_000158_png.rf.24f55e9e73127706eb3fe8771080817d.jpg
#  extracting: train/truck/dump_truck_s_000159_png.rf.268b3ada8bc1b79637519b855a056d26.jpg
#  extracting: train/truck/dump_truck_s_000162_png.rf.a2abe2cfed5189862e824ceb850752a4.jpg
#  extracting: train/truck/dump_truck_s_000163_png.rf.31788ab60494ecae9b0b5b430810e230.jpg
#  extracting: train/truck/dump_truck_s_000164_png.rf.8a18a0fcfc04335e4c7096c01a8678eb.jpg
#  extracting: train/truck/dump_truck_s_000169_png.rf.9ad18098603ddc198cf17135586ac5a3.jpg
#  extracting: train/truck/dump_truck_s_000171_png.rf.1e0beb8678c96b6b99b99b94b0ed2b96.jpg
#  extracting: train/truck/dump_truck_s_000179_png.rf.e8f6d05d589e8c6915e151a691e0ea46.jpg
#  extracting: train/truck/dump_truck_s_000181_png.rf.73c9bd3f4d6210a4f5caf70129d60f64.jpg
#  extracting: train/truck/dump_truck_s_000188_png.rf.72f4dd2a462aa9c4f76a38a713c40dcf.jpg
#  extracting: train/truck/dump_truck_s_000193_png.rf.85ed40386f0f57dbea578d3cc9e0de8a.jpg
#  extracting: train/truck/dump_truck_s_000201_png.rf.59ce42a009b54b0582a4c7c36584313d.jpg
#  extracting: train/truck/dump_truck_s_000204_png.rf.9cf246fb7b61241e98abd7b8416e4795.jpg
#  extracting: train/truck/dump_truck_s_000215_png.rf.2b4d900c1ffdeb9e9d202f180235cfaf.jpg
#  extracting: train/truck/dump_truck_s_000234_png.rf.6bf2f20e368746ffb6baa095f4c8cc8f.jpg
#  extracting: train/truck/dump_truck_s_000235_png.rf.609a072528b7b80b3907c8dcba4a52ac.jpg
#  extracting: train/truck/dump_truck_s_000236_png.rf.ef4939805fabf341b5470e5e59ce7cae.jpg
#  extracting: train/truck/dump_truck_s_000246_png.rf.d896b4b332265038429d58652104c960.jpg
#  extracting: train/truck/dump_truck_s_000248_png.rf.6bcc6ccd25fc107a074557a9def82499.jpg
#  extracting: train/truck/dump_truck_s_000249_png.rf.c352a23a6876cf99eb96c9f78ced53d7.jpg
#  extracting: train/truck/dump_truck_s_000252_png.rf.6e74a0a0a1d32e7d10d485d77270f34c.jpg
#  extracting: train/truck/dump_truck_s_000257_png.rf.240348321205e4e44f2440e6fe849ebf.jpg
#  extracting: train/truck/dump_truck_s_000258_png.rf.dee033dc92719a64f8f66755e3f996f0.jpg
#  extracting: train/truck/dump_truck_s_000259_png.rf.80810d028702ae231b107ad3d8627602.jpg
#  extracting: train/truck/dump_truck_s_000263_png.rf.e08390df98fed06eee12a0119ca54053.jpg
#  extracting: train/truck/dump_truck_s_000264_png.rf.ab4464e17f3247b294400a5405808d92.jpg
#  extracting: train/truck/dump_truck_s_000265_png.rf.75793fcff4983ea6ef41a838eb75e5b7.jpg
#  extracting: train/truck/dump_truck_s_000267_png.rf.08bf95c6c619cd1d1d19e641b0ab89f0.jpg
#  extracting: train/truck/dump_truck_s_000286_png.rf.5bdf5a0779853a6c2d22653e7f8d1cd1.jpg
#  extracting: train/truck/dump_truck_s_000290_png.rf.804756107b2ca47e3075050171e7e1a3.jpg
#  extracting: train/truck/dump_truck_s_000294_png.rf.ea4c6072f8413a4fbc24119c43239e52.jpg
#  extracting: train/truck/dump_truck_s_000296_png.rf.1d4b0e5db0fc224e1566e7501af50248.jpg
#  extracting: train/truck/dump_truck_s_000300_png.rf.ac0bf7558f39eaa99a5ae2fceb4d02e4.jpg
#  extracting: train/truck/dump_truck_s_000303_png.rf.b8c136cdcc1aeddfb748060afba295bb.jpg
#  extracting: train/truck/dump_truck_s_000305_png.rf.d2a9c5d9a6acc582c922fc8c38b5d5a3.jpg
#  extracting: train/truck/dump_truck_s_000321_png.rf.93cd08507bd005a4f8ed0437340a738e.jpg
#  extracting: train/truck/dump_truck_s_000327_png.rf.e37511f478997cd5c0163b8ac6d8eb39.jpg
#  extracting: train/truck/dump_truck_s_000330_png.rf.3a4318bdc532d605b8cde835b79d28fe.jpg
#  extracting: train/truck/dump_truck_s_000331_png.rf.9dddf926df595bdcc495d43712fbb2a2.jpg
#  extracting: train/truck/dump_truck_s_000336_png.rf.05f55775edf9ed3bcee19d58c532ee7a.jpg
#  extracting: train/truck/dump_truck_s_000342_png.rf.400c2cd2fc7702a71210760bcba5960f.jpg
#  extracting: train/truck/dump_truck_s_000347_png.rf.d465f6a26dd3588bc705255923b3fd1f.jpg
#  extracting: train/truck/dump_truck_s_000350_png.rf.3d5d5239f10a770bb0b3183fe1cf1fdd.jpg
#  extracting: train/truck/dump_truck_s_000351_png.rf.6652f10f945a833b2b6c733e5da3f613.jpg
#  extracting: train/truck/dump_truck_s_000354_png.rf.02251e74a3e483a43ab9ca7dd1363a04.jpg
#  extracting: train/truck/dump_truck_s_000355_png.rf.f4eedc80885677fa00fc0ac24341caba.jpg
#  extracting: train/truck/dump_truck_s_000356_png.rf.d92e3f49356cf3cd0da6d1c2e8e9c05a.jpg
#  extracting: train/truck/dump_truck_s_000363_png.rf.31e94c8a55531981c726512036a4f604.jpg
#  extracting: train/truck/dump_truck_s_000370_png.rf.7eb65ab060a4cfc0ff9f22ec53afbce6.jpg
#  extracting: train/truck/dump_truck_s_000386_png.rf.fa1a7ba437b4d573f0306d2b64cf5326.jpg
#  extracting: train/truck/dump_truck_s_000388_png.rf.b795e6d810547db3ec0cbcb7374c1d4e.jpg
#  extracting: train/truck/dump_truck_s_000389_png.rf.0011dc86237c12cdd29ef762e400ba5a.jpg
#  extracting: train/truck/dump_truck_s_000394_png.rf.e9409567d58ff56e78cc90454f0c1934.jpg
#  extracting: train/truck/dump_truck_s_000395_png.rf.7c1ead69003471d602c58a1db87e3316.jpg
#  extracting: train/truck/dump_truck_s_000403_png.rf.4dc11477705e7626de067934e1e908d8.jpg
#  extracting: train/truck/dump_truck_s_000427_png.rf.ba08c481212e7451d775f6219686d4d3.jpg
#  extracting: train/truck/dump_truck_s_000428_png.rf.7ff0b32b2605b862463613c791c0ac9b.jpg
#  extracting: train/truck/dump_truck_s_000432_png.rf.03600b78fd7c320309794e347ce5a411.jpg
#  extracting: train/truck/dump_truck_s_000437_png.rf.8b35963d279bc19cb617374d67d369e4.jpg
#  extracting: train/truck/dump_truck_s_000438_png.rf.0553f7454228400adb8ea730e2ac43f9.jpg
#  extracting: train/truck/dump_truck_s_000447_png.rf.c255589381fedb41636d384bd2f8d26d.jpg
#  extracting: train/truck/dump_truck_s_000448_png.rf.842e4003334242d637a4f1e3d517c847.jpg
#  extracting: train/truck/dump_truck_s_000452_png.rf.1352c967003f4ddbc7223ffe877bbe14.jpg
#  extracting: train/truck/dump_truck_s_000453_png.rf.54814b4a6ef38ef2acb86aab2759d490.jpg
#  extracting: train/truck/dump_truck_s_000454_png.rf.63973cdcfe819e481f4acca6dc31b5c3.jpg
#  extracting: train/truck/dump_truck_s_000456_png.rf.fa547418d34261fd0b2aebf5aa7e2983.jpg
#  extracting: train/truck/dump_truck_s_000457_png.rf.4560f6abd9289077e7655d602eeb412c.jpg
#  extracting: train/truck/dump_truck_s_000469_png.rf.d42ab95a1105f2c8402fd6f872ad09c0.jpg
#  extracting: train/truck/dump_truck_s_000475_png.rf.7396a857aeeaa40bdc58a0023c351e09.jpg
#  extracting: train/truck/dump_truck_s_000476_png.rf.c63d5859389ebbf7484f615320c4a0cf.jpg
#  extracting: train/truck/dump_truck_s_000477_png.rf.4615602ec1aa7fe7b9520f2b601c9ba5.jpg
#  extracting: train/truck/dump_truck_s_000484_png.rf.33f03d9c6ea09c61a26cc2e41f82f3c0.jpg
#  extracting: train/truck/dump_truck_s_000485_png.rf.9b07384145697a04300948673dadd16f.jpg
#  extracting: train/truck/dump_truck_s_000486_png.rf.58314ad0c02ed03f1c62b77be7e4e18e.jpg
#  extracting: train/truck/dump_truck_s_000488_png.rf.7234797635df8a4a4d62b4e0c6167a3d.jpg
#  extracting: train/truck/dump_truck_s_000499_png.rf.bba5bb816535d3aa5e615f4816c0a582.jpg
#  extracting: train/truck/dump_truck_s_000502_png.rf.a71bbe6a16be8eb611157f2f3e131a59.jpg
#  extracting: train/truck/dump_truck_s_000509_png.rf.b8ed2759c5d3907185c2d23be44aae88.jpg
#  extracting: train/truck/dump_truck_s_000514_png.rf.2605c6f687b83456e5be7299894f23d1.jpg
#  extracting: train/truck/dump_truck_s_000517_png.rf.3262dfe5c2ae068c877fda9bbbee5f94.jpg
#  extracting: train/truck/dump_truck_s_000523_png.rf.258406cf624787396c029aa6ca1a6400.jpg
#  extracting: train/truck/dump_truck_s_000526_png.rf.d89319bdb9cf548df5d8f9af62af6fce.jpg
#  extracting: train/truck/dump_truck_s_000528_png.rf.8253422b0fa687475d61d28ca68b6e12.jpg
#  extracting: train/truck/dump_truck_s_000532_png.rf.942a6a6c87533f83edb38d651b4bc7d4.jpg
#  extracting: train/truck/dump_truck_s_000533_png.rf.258adea68c71825ca0d607310de94dca.jpg
#  extracting: train/truck/dump_truck_s_000536_png.rf.101d0b4a31addd375db52e518b476b34.jpg
#  extracting: train/truck/dump_truck_s_000539_png.rf.aa30477f61f7fd1ea226dc3d3a84eeac.jpg
#  extracting: train/truck/dump_truck_s_000541_png.rf.7b1c6e38249db610c720cbb16033c7be.jpg
#  extracting: train/truck/dump_truck_s_000542_png.rf.0be9fb84a05001c936824ce49cf4c8ee.jpg
#  extracting: train/truck/dump_truck_s_000546_png.rf.12ad38cd1733ae083207ab2ef2abb7c4.jpg
#  extracting: train/truck/dump_truck_s_000547_png.rf.a55892b98da962c9f03895000bb91180.jpg
#  extracting: train/truck/dump_truck_s_000548_png.rf.abd6ccbaaaaf940a6ee7c1447bdcdec1.jpg
#  extracting: train/truck/dump_truck_s_000549_png.rf.08d5ca7b82aa6c73444a7a5389628981.jpg
#  extracting: train/truck/dump_truck_s_000553_png.rf.507628a293a8428af6da25535569eed0.jpg
#  extracting: train/truck/dump_truck_s_000554_png.rf.5cd2d4a0ee1075f2fe1a2bbf022bbabd.jpg
#  extracting: train/truck/dump_truck_s_000557_png.rf.3d7673084442c4cab3d5674fa5d56959.jpg
#  extracting: train/truck/dump_truck_s_000558_png.rf.928fa8846e8294a41448f2ad51804279.jpg
#  extracting: train/truck/dump_truck_s_000560_png.rf.e2b6531e348095ef71565ca5bd4f2486.jpg
#  extracting: train/truck/dump_truck_s_000563_png.rf.9013c6b15fc3ffa1dbb1c0cfb741972e.jpg
#  extracting: train/truck/dump_truck_s_000573_png.rf.acae4c620efc6ed47ceab92a919b3bd7.jpg
#  extracting: train/truck/dump_truck_s_000575_png.rf.9cb75c807d53760a11269aeb163104dc.jpg
#  extracting: train/truck/dump_truck_s_000576_png.rf.92f56da981e7d1c1cbcbb896303cedaa.jpg
#  extracting: train/truck/dump_truck_s_000578_png.rf.44861e34f786b3f55b1e0dc4bd352d3f.jpg
#  extracting: train/truck/dump_truck_s_000579_png.rf.311ca243c4742abf39ab334c4b41043d.jpg
#  extracting: train/truck/dump_truck_s_000582_png.rf.34d6b274a7a4cccae9a01eca9b40b55b.jpg
#  extracting: train/truck/dump_truck_s_000584_png.rf.e0eddcc856974c07ef96ad185e9b68d6.jpg
#  extracting: train/truck/dump_truck_s_000602_png.rf.6b5f1dab91d402edbbc3fa25d6887ffb.jpg
#  extracting: train/truck/dump_truck_s_000622_png.rf.36e15f4a5ec34859f2297edcf2170e06.jpg
#  extracting: train/truck/dump_truck_s_000624_png.rf.0450bfd0758480be4526b8cfd892e85a.jpg
#  extracting: train/truck/dump_truck_s_000625_png.rf.8a0771e132a0212da4bbfb1ba87d6ff6.jpg
#  extracting: train/truck/dump_truck_s_000628_png.rf.c17ec65f661215da5582651b13de24da.jpg
#  extracting: train/truck/dump_truck_s_000629_png.rf.cca5172e719344549babe6e55443e81c.jpg
#  extracting: train/truck/dump_truck_s_000632_png.rf.3b004afbb8843bfe18179c9a9d4332a5.jpg
#  extracting: train/truck/dump_truck_s_000634_png.rf.0a883ae675e0ad2fa930a19f35e12f31.jpg
#  extracting: train/truck/dump_truck_s_000639_png.rf.1c778147dffa40752bf3c6f606fd14c4.jpg
#  extracting: train/truck/dump_truck_s_000647_png.rf.ecffd6ac1526201de4c9226381157dc1.jpg
#  extracting: train/truck/dump_truck_s_000648_png.rf.434d108bbe77f93719747cdadeeb70b5.jpg
#  extracting: train/truck/dump_truck_s_000651_png.rf.6a2487fe4bcf5ced84257496c265013d.jpg
#  extracting: train/truck/dump_truck_s_000654_png.rf.a231b36ba75e78db8c84b30a77c005f2.jpg
#  extracting: train/truck/dump_truck_s_000661_png.rf.35b814ebeb9e1b5ca5244a7745019371.jpg
#  extracting: train/truck/dump_truck_s_000678_png.rf.745a1fadc68d8edfe077fe79af047d11.jpg
#  extracting: train/truck/dump_truck_s_000680_png.rf.9531722d8767614d9496833f8603d64e.jpg
#  extracting: train/truck/dump_truck_s_000681_png.rf.e36fc3db2a0f5f3cd7986012014bbccb.jpg
#  extracting: train/truck/dump_truck_s_000686_png.rf.207c70635fedd1c56d430e6d53cc2dfd.jpg
#  extracting: train/truck/dump_truck_s_000687_png.rf.ddf62fdca87093f512cf629d72500600.jpg
#  extracting: train/truck/dump_truck_s_000690_png.rf.e3719c8667aa778b45642bd4ca7ec75d.jpg
#  extracting: train/truck/dump_truck_s_000692_png.rf.beef4f2188773074d1dc2441533f5a40.jpg
#  extracting: train/truck/dump_truck_s_000706_png.rf.d53727c305ca67e7ed9d81a440eab92d.jpg
#  extracting: train/truck/dump_truck_s_000715_png.rf.feb80fde7222eb2cf504e20c85d4c9de.jpg
#  extracting: train/truck/dump_truck_s_000717_png.rf.b9927d5725af12de53fcbd485cffc369.jpg
#  extracting: train/truck/dump_truck_s_000718_png.rf.f61af21b33a675dd1efa2631eec736d2.jpg
#  extracting: train/truck/dump_truck_s_000720_png.rf.c1e72202a2625563672eba4b7d430706.jpg
#  extracting: train/truck/dump_truck_s_000721_png.rf.289cfd817d01bdfa6ad3fc2d277463af.jpg
#  extracting: train/truck/dump_truck_s_000724_png.rf.ae43fbe33bdf0df97ed5c60f838f2f4e.jpg
#  extracting: train/truck/dump_truck_s_000726_png.rf.60628162e25a35bd5ce3f578a5ab0502.jpg
#  extracting: train/truck/dump_truck_s_000737_png.rf.22ea6d5635c8ef0b70822558d993bba2.jpg
#  extracting: train/truck/dump_truck_s_000740_png.rf.f8bbdd5bd79785a2654d221436f4ec75.jpg
#  extracting: train/truck/dump_truck_s_000758_png.rf.8802ade84c83146844e5dac79c2c1917.jpg
#  extracting: train/truck/dump_truck_s_000759_png.rf.13a320a277ea272df3f73b038f622424.jpg
#  extracting: train/truck/dump_truck_s_000762_png.rf.37ba19f549efda93a00f0c6e80b56eeb.jpg
#  extracting: train/truck/dump_truck_s_000774_png.rf.bcefbb398595606c649486467d14a8e7.jpg
#  extracting: train/truck/dump_truck_s_000775_png.rf.b2268140ac2a470bc9fac2f297d8c258.jpg
#  extracting: train/truck/dump_truck_s_000776_png.rf.aae96f021713db82e201742783f0d998.jpg
#  extracting: train/truck/dump_truck_s_000781_png.rf.2401e9957ffc7c912391654a11bc5c3b.jpg
#  extracting: train/truck/dump_truck_s_000786_png.rf.442f22bba75507ef4a69d744c6f1d33e.jpg
#  extracting: train/truck/dump_truck_s_000793_png.rf.3ccad6c2108a9e378e8d6e03e5671fd1.jpg
#  extracting: train/truck/dump_truck_s_000800_png.rf.28c6d20016c73eefa7dec2bec0471959.jpg
#  extracting: train/truck/dump_truck_s_000802_png.rf.de568c0a22e930ba214144f8fd752ca9.jpg
#  extracting: train/truck/dump_truck_s_000803_png.rf.8d488726a9bd976fe42a2c8ebf6640c6.jpg
#  extracting: train/truck/dump_truck_s_000811_png.rf.04af630eea436ac88bb0b012c973a2c3.jpg
#  extracting: train/truck/dump_truck_s_000812_png.rf.bdcbc0705815090be71a36871862a4de.jpg
#  extracting: train/truck/dump_truck_s_000817_png.rf.a912dff7a4cc1b1dee888c51db5e81be.jpg
#  extracting: train/truck/dump_truck_s_000823_png.rf.7f598654a123d4c637dfeaf59e62da98.jpg
#  extracting: train/truck/dump_truck_s_000829_png.rf.b13e447f4926c00ecd3979c0dcc88dc4.jpg
#  extracting: train/truck/dump_truck_s_000838_png.rf.dc7de89194fbeff88d4fa7283fb18306.jpg
#  extracting: train/truck/dump_truck_s_000841_png.rf.565610f2f8516511d0498d909a2fa148.jpg
#  extracting: train/truck/dump_truck_s_000842_png.rf.470aa2c4c9cb5991b2b2752d79349831.jpg
#  extracting: train/truck/dump_truck_s_000843_png.rf.9b2d698139f497b0669bb8399f18417b.jpg
#  extracting: train/truck/dump_truck_s_000846_png.rf.c6941954b20c408c8550558693e70792.jpg
#  extracting: train/truck/dump_truck_s_000848_png.rf.74072bd90a82c2673355fd0fa5296830.jpg
#  extracting: train/truck/dump_truck_s_000851_png.rf.07dce11945fdc301126376516920dab7.jpg
#  extracting: train/truck/dump_truck_s_000859_png.rf.14b5fd64d030973bb91b07adcb5dfbe2.jpg
#  extracting: train/truck/dump_truck_s_000860_png.rf.ec06e8c7990871daa0ec51ec9d281ac8.jpg
#  extracting: train/truck/dump_truck_s_000861_png.rf.96caa219928dbda6cfa7f9339f227e91.jpg
#  extracting: train/truck/dump_truck_s_000863_png.rf.e47570660b268ca3497b309391dbaa8e.jpg
#  extracting: train/truck/dump_truck_s_000866_png.rf.7686b9ff1723764f97baa5cdde9f68fd.jpg
#  extracting: train/truck/dump_truck_s_000867_png.rf.1333067a86b6a8a4741e9ceb16082535.jpg
#  extracting: train/truck/dump_truck_s_000873_png.rf.6b41837fdffa7721e900129449ef5f1b.jpg
#  extracting: train/truck/dump_truck_s_000874_png.rf.10ca7a754bbc5d1c0ca486a24c0f9f8e.jpg
#  extracting: train/truck/dump_truck_s_000879_png.rf.e653f2c939d77fbc7253ab6a04baa43c.jpg
#  extracting: train/truck/dump_truck_s_000881_png.rf.462464b1567e49ac0324b885f6951226.jpg
#  extracting: train/truck/dump_truck_s_000882_png.rf.e63405ee2b514e3e8d5b77759ff5edd4.jpg
#  extracting: train/truck/dump_truck_s_000883_png.rf.5902f6961f23843ad3c2e179710a8dda.jpg
#  extracting: train/truck/dump_truck_s_000885_png.rf.83b09bc4902cf2c4ecd5cbdb0d872edd.jpg
#  extracting: train/truck/dump_truck_s_000895_png.rf.f9acfec3d31f04f425d004ad99f8bda1.jpg
#  extracting: train/truck/dump_truck_s_000916_png.rf.5ee65a86d5535c69026df0b952ea2555.jpg
#  extracting: train/truck/dump_truck_s_000917_png.rf.585783d2c17027b06063d56ee38886c5.jpg
#  extracting: train/truck/dump_truck_s_000919_png.rf.5b93dee1495cd12219e8b51a10321fbb.jpg
#  extracting: train/truck/dump_truck_s_000931_png.rf.3e78cecf8cc8b47e88025d7855522abf.jpg
#  extracting: train/truck/dump_truck_s_000934_png.rf.b7bdbc08b3ab5ede82a5947c69a47d8f.jpg
#  extracting: train/truck/dump_truck_s_000936_png.rf.72b0020df75d8fd30d29deaaa24afbb0.jpg
#  extracting: train/truck/dump_truck_s_000939_png.rf.4021718f51e50c95cacb5fad91dda6f8.jpg
#  extracting: train/truck/dump_truck_s_000940_png.rf.9797bf87092eba9180d5bdb26c448172.jpg
#  extracting: train/truck/dump_truck_s_000942_png.rf.b521c3af429f3dc534ea3826ca6bd8f4.jpg
#  extracting: train/truck/dump_truck_s_000956_png.rf.ff64d99d71fed69b92eb9056737da7a6.jpg
#  extracting: train/truck/dump_truck_s_000957_png.rf.5a026c4c36987d2ddcf2ab22c495cb63.jpg
#  extracting: train/truck/dump_truck_s_000959_png.rf.c8d13a8155ac5693c4731157cf81a708.jpg
#  extracting: train/truck/dump_truck_s_000968_png.rf.cf3a1beba4fc0d20a677cc007f304be3.jpg
#  extracting: train/truck/dump_truck_s_000973_png.rf.28dd3e7ef44734ec33e3cc11f2eda58a.jpg
#  extracting: train/truck/dump_truck_s_000974_png.rf.07cab89952034f94fcd8b983e041f5f8.jpg
#  extracting: train/truck/dump_truck_s_000984_png.rf.6eb1d0cec104e7b1e2fe8616a053e830.jpg
#  extracting: train/truck/dump_truck_s_000985_png.rf.21df0331276ef3255e443c09b3a87f16.jpg
#  extracting: train/truck/dump_truck_s_000986_png.rf.5baaa362cade1601d0ca021d0844d077.jpg
#  extracting: train/truck/dump_truck_s_000987_png.rf.852d787119b6580e1aea4d28b95482b4.jpg
#  extracting: train/truck/dump_truck_s_000988_png.rf.a28880f456144e0c86ba1077397bee57.jpg
#  extracting: train/truck/dump_truck_s_000990_png.rf.42f487b376758e04736531c89a34f031.jpg
#  extracting: train/truck/dump_truck_s_000992_png.rf.ef16a3f6aff51b44f5a58985c78ef63e.jpg
#  extracting: train/truck/dump_truck_s_000993_png.rf.888f808d9c78ac80e162aea35f7727d6.jpg
#  extracting: train/truck/dump_truck_s_000994_png.rf.6cdc0fc36635bf42a14ba17d0bcf8c25.jpg
#  extracting: train/truck/dump_truck_s_000995_png.rf.0c35960911a0d4d49473bad7da2c5e0d.jpg
#  extracting: train/truck/dump_truck_s_000996_png.rf.adddfc0ff3f598b2a07f99fee3ff71ac.jpg
#  extracting: train/truck/dump_truck_s_001001_png.rf.41dbd5e076cdaadaeda2a5de30c0c418.jpg
#  extracting: train/truck/dump_truck_s_001002_png.rf.002a74a0715d839cd06a26359374079f.jpg
#  extracting: train/truck/dump_truck_s_001004_png.rf.3fa43536eb18cbb70893cfc7c656bc92.jpg
#  extracting: train/truck/dump_truck_s_001009_png.rf.6c8d5135c32f19e9b18ec30400a7e9fe.jpg
#  extracting: train/truck/dump_truck_s_001017_png.rf.1624eb99ee4c16e5efde3f5065b724c9.jpg
# ...
#  extracting: train/truck/trucking_rig_s_001664_png.rf.edd64c0257aaa23022ca5e6da0ab6969.jpg
#  extracting: train/truck/trucking_rig_s_001666_png.rf.c7b00aecd5763c1e0ecffa7527ae4e95.jpg
#  extracting: train/truck/trucking_rig_s_001667_png.rf.8376a5c1c574e99e5f113694bbfdcaed.jpg
#  extracting: train/truck/trucking_rig_s_001668_png.rf.e539779516514c7b448a85e3cf50c3b1.jpg
#  extracting: train/truck/trucking_rig_s_001669_png.rf.a48d4e7f6b2f4a402cb1fbc42eef8dbd.jpg
#  extracting: train/truck/trucking_rig_s_001671_png.rf.f948a9a9a9d5b7b061856c1447b1012e.jpg
#  extracting: train/truck/trucking_rig_s_001672_png.rf.6b58841220e6fb79f7234e55257ec4f4.jpg
#  extracting: train/truck/trucking_rig_s_001673_png.rf.525d248288a96183c3e6ed39e0ca32d2.jpg
#  extracting: train/truck/trucking_rig_s_001674_png.rf.a489b0e6927a41367d66d088d08d59ca.jpg
#  extracting: train/truck/trucking_rig_s_001675_png.rf.fc181391e160a255623cebc3ff9dadc7.jpg
#  extracting: train/truck/trucking_rig_s_001677_png.rf.4c4694c83acc0cf6c69add5aeeaad901.jpg
#  extracting: train/truck/trucking_rig_s_001679_png.rf.bdb01c12537e90821890cc5b96fb7e67.jpg
#  extracting: train/truck/trucking_rig_s_001682_png.rf.dd0ac14d5a1004ad03d118440d8dca96.jpg
#  extracting: train/truck/trucking_rig_s_001684_png.rf.15ebff3f32c0419761a1032ef8e8e9cd.jpg
#  extracting: train/truck/trucking_rig_s_001685_png.rf.f66794e719247d19740b10f0761ff8c7.jpg
#  extracting: train/truck/trucking_rig_s_001687_png.rf.5dece52be18437f8bcc23ac0d0d45177.jpg
#  extracting: train/truck/trucking_rig_s_001688_png.rf.8045ef7e7dbc5f60df907be76a20d8ee.jpg
#  extracting: train/truck/trucking_rig_s_001689_png.rf.2dd8b19302555c2c313d722590faf7d2.jpg
#  extracting: train/truck/van_s_000165_png.rf.6f9bcf45660b7f730ca518ceb6767b0d.jpg
#  extracting: train/truck/wrecker_s_000005_png.rf.53769274acd5640aa3e88fe0939afa81.jpg
#  extracting: train/truck/wrecker_s_000026_png.rf.bad9ce74593aa28de15fca5e69d1f5c6.jpg
#  extracting: train/truck/wrecker_s_000043_png.rf.8d06e2a23b50bd006eab0200cb739fdb.jpg
#  extracting: train/truck/wrecker_s_000048_png.rf.8f7ed6e27f73a27fca107f52c3da0364.jpg
#  extracting: train/truck/wrecker_s_000056_png.rf.658dd2f1c8d21f48acf3c4adce2109ae.jpg
#  extracting: train/truck/wrecker_s_000079_png.rf.b2b93e4e3c57e70b7e0eef0736c2d7f5.jpg
#  extracting: train/truck/wrecker_s_000151_png.rf.e004ae9dc51b904801d5720447538b84.jpg
#  extracting: train/truck/wrecker_s_000180_png.rf.9a596096f3a305f917a910120eb4b991.jpg
#  extracting: train/truck/wrecker_s_000185_png.rf.4de4310b4d4f417c1f7cc10b10f838fd.jpg
#  extracting: train/truck/wrecker_s_000208_png.rf.e15a5308f765b15f3dcecc4727c46551.jpg
#  extracting: train/truck/wrecker_s_000215_png.rf.3e24e89ea8c0cc35fcd32e668430a99f.jpg
#  extracting: train/truck/wrecker_s_000218_png.rf.20c325739ae44f42b6b40db0d1ad7d93.jpg
#  extracting: train/truck/wrecker_s_000227_png.rf.4f12b482d8099206fd088ac34db2bc24.jpg
#  extracting: train/truck/wrecker_s_000324_png.rf.0b7c37d63692e36dfae72192e89e9ab2.jpg
#  extracting: train/truck/wrecker_s_000325_png.rf.d5d64f915f81c62ee4c4be166074d82a.jpg
#  extracting: train/truck/wrecker_s_000326_png.rf.8c755205a960e71e6649566f8fbbd605.jpg
#  extracting: train/truck/wrecker_s_000330_png.rf.5a534770972c4e34caf613e922c5fe70.jpg
#  extracting: train/truck/wrecker_s_000331_png.rf.aed2e4fa084c3d6804cae29865bb5b5b.jpg
#  extracting: train/truck/wrecker_s_000369_png.rf.df9823c0c9ae7b30533617d9f23a38f2.jpg
#  extracting: train/truck/wrecker_s_000376_png.rf.669fa85bb273b6002ba96c1c9784cc86.jpg
#  extracting: train/truck/wrecker_s_000431_png.rf.01d12612e452ff7693b946836491f71c.jpg
#  extracting: train/truck/wrecker_s_000432_png.rf.7b6ac96720911b8e497ec634ef19279e.jpg
#  extracting: train/truck/wrecker_s_000483_png.rf.091d6fb07f11d94351bab05a73de9f30.jpg
#  extracting: train/truck/wrecker_s_000519_png.rf.92d827a7acaca9bdd5ac294472da1f04.jpg
#  extracting: train/truck/wrecker_s_000598_png.rf.e844d2c10cb1594375247ec6421aef37.jpg
#  extracting: train/truck/wrecker_s_000599_png.rf.e632faf79b839ec7f8ca6650956a3262.jpg
#  extracting: train/truck/wrecker_s_000608_png.rf.020ba9575a772e750d9a99c5eee1ddcc.jpg
#  extracting: train/truck/wrecker_s_000614_png.rf.67e4a5157b05e12997791cd0b66d1a2c.jpg
#  extracting: train/truck/wrecker_s_000617_png.rf.7a01ccdf75ee294783645aeea36e8bc5.jpg
#  extracting: train/truck/wrecker_s_000619_png.rf.99ae7f5f7951c557052a60fb9e386dd7.jpg
#  extracting: train/truck/wrecker_s_000630_png.rf.ac96325f08c3e87fcf96d24837606f48.jpg
#  extracting: train/truck/wrecker_s_000632_png.rf.a478645edd94691acd1bccd8a49952d1.jpg
#  extracting: train/truck/wrecker_s_000641_png.rf.aa6db0d92d51e3b5c0f42fbf67a52d51.jpg
#  extracting: train/truck/wrecker_s_000664_png.rf.c712dfee1b9db05fff204199ece10560.jpg
#  extracting: train/truck/wrecker_s_000684_png.rf.518dcd95af51fdbe2e98d8416b31fa64.jpg
#  extracting: train/truck/wrecker_s_000718_png.rf.5849cc168677d68f6ba50fdd748c6b4b.jpg
#  extracting: train/truck/wrecker_s_000722_png.rf.2894c5bb8fea94b0b310e3fd95f9d1cf.jpg
#  extracting: train/truck/wrecker_s_000723_png.rf.35fa190c2dd03fbbd39407a5752d61a7.jpg
#  extracting: train/truck/wrecker_s_000736_png.rf.cf826602a5567b231ae9e0138046c6d0.jpg
#  extracting: train/truck/wrecker_s_000737_png.rf.7c95288b7a1d1f8a16c1581cc0648387.jpg
#  extracting: train/truck/wrecker_s_000777_png.rf.94e73534749fbc5a40289c6e31f077da.jpg
#  extracting: train/truck/wrecker_s_000792_png.rf.099f566eef13ed0f4c81e6c366e68af5.jpg
#  extracting: train/truck/wrecker_s_000793_png.rf.4ab8fa6a4c75d01a09714fbfd970305e.jpg
#  extracting: train/truck/wrecker_s_000797_png.rf.e330d6cf2a371fdccf11bd4d1f0c10a6.jpg
#  extracting: train/truck/wrecker_s_000801_png.rf.673ec1e72bd84ab85418d538aa0d269a.jpg
#  extracting: train/truck/wrecker_s_000874_png.rf.f84da66bc28f38d7b0c3213ba37196e8.jpg
#  extracting: train/truck/wrecker_s_000877_png.rf.e63be893f0cc11bee3f1b4d7e306df68.jpg
#  extracting: train/truck/wrecker_s_000878_png.rf.bccd0cb6d27ae4967f28a70e41952d67.jpg
#  extracting: train/truck/wrecker_s_000893_png.rf.7ac88a7a10e9ce6be5c63dcdeb3fefc7.jpg
#  extracting: train/truck/wrecker_s_000932_png.rf.93d9cdff5f7b5a09980c5bd938aa9f20.jpg
#  extracting: train/truck/wrecker_s_000941_png.rf.e692f9773ef6b6baf5b7c0bb4b2f0bec.jpg
#  extracting: train/truck/wrecker_s_000942_png.rf.3cce6fffe29f0aebe40fbcfdc0a934b1.jpg
#  extracting: train/truck/wrecker_s_000943_png.rf.5b3a6e864e1bd188567e1ea4b6c979bc.jpg
#  extracting: train/truck/wrecker_s_000949_png.rf.6c600fc18e4573377089bcf84832b388.jpg
#  extracting: train/truck/wrecker_s_000957_png.rf.2da826567f740ccbdcefcd8c064cad22.jpg
#  extracting: train/truck/wrecker_s_001037_png.rf.95e8020a3a15293c23049b27b670730f.jpg
#  extracting: train/truck/wrecker_s_001046_png.rf.890f5b36f0ea2c493739428a3ffc23bb.jpg
#  extracting: train/truck/wrecker_s_001101_png.rf.378ec9a879d99cc276e87f91a4eef7ce.jpg
#  extracting: train/truck/wrecker_s_001102_png.rf.9d51798756d2de0a1a0686e7f4e68a2e.jpg
#  extracting: train/truck/wrecker_s_001124_png.rf.3c147921d3ee524eb50e9e6621ab9f64.jpg
#  extracting: train/truck/wrecker_s_001139_png.rf.6901bd9f73d4d152c9651731c9d0b506.jpg
#  extracting: train/truck/wrecker_s_001162_png.rf.1f61f5556a0c3ff8c442d983bbd296de.jpg
#  extracting: train/truck/wrecker_s_001163_png.rf.b80ad07d16d10e9ab097ca649945a262.jpg
#  extracting: train/truck/wrecker_s_001193_png.rf.e9f29b044301b0ef8e6084b807fd7ad2.jpg
#  extracting: train/truck/wrecker_s_001194_png.rf.94b0fe0498fcdc238f898a50cd2ce906.jpg
#  extracting: train/truck/wrecker_s_001195_png.rf.2b1389e067f2f9a7b02a558678728998.jpg
#  extracting: train/truck/wrecker_s_001225_png.rf.c81018587c304e618cce996a5c1eae4f.jpg
#  extracting: train/truck/wrecker_s_001310_png.rf.6aa68273a9d997693acea2beaa37631d.jpg
#  extracting: train/truck/wrecker_s_001348_png.rf.c3e132fdf0b5ba5e6d0ef3ece000a5d4.jpg
#  extracting: train/truck/wrecker_s_001349_png.rf.03ce48ee3345447611d5a0d74cfd6c18.jpg
#  extracting: train/truck/wrecker_s_001386_png.rf.d5028ce1256d46163a3176476a37c8ff.jpg
#  extracting: train/truck/wrecker_s_001407_png.rf.7b0bc8e851aa1244d80f1dd013dbe305.jpg
#  extracting: train/truck/wrecker_s_001415_png.rf.d886df9608bbc74fa27808aacf5fe580.jpg
#  extracting: train/truck/wrecker_s_001420_png.rf.77c87bc27da3ce70abb3d5fb07a55811.jpg
#  extracting: train/truck/wrecker_s_001422_png.rf.d309ef8ee85c330ae6ef57683cc314da.jpg
#  extracting: train/truck/wrecker_s_001438_png.rf.746770ea6581675d76fa1923a012c815.jpg
#  extracting: train/truck/wrecker_s_001473_png.rf.889d54f70a803d9cc9578a56538d108d.jpg
#  extracting: train/truck/wrecker_s_001478_png.rf.bc4a2d25600ba8ae5c5887fa4d32533b.jpg
#  extracting: train/truck/wrecker_s_001479_png.rf.ab31a1445e0140693fb9a9c7b2c9acb3.jpg
#  extracting: train/truck/wrecker_s_001490_png.rf.0113f33aa58d69cbd07e5edf027ad81f.jpg
#  extracting: train/truck/wrecker_s_001492_png.rf.55eced61f621b41b4616b4afdc4b68f4.jpg
#  extracting: train/truck/wrecker_s_001557_png.rf.992aed808e38986740523ce93c5a7f58.jpg
#  extracting: train/truck/wrecker_s_001619_png.rf.550eb2543ecc8a6a78c2c51c443c9c1d.jpg
#  extracting: train/truck/wrecker_s_001620_png.rf.a7ebedb6526f6b4bd9d5742236988078.jpg
#  extracting: train/truck/wrecker_s_001626_png.rf.9ea3426b27b9bcdd7890f8fcef5bb5a0.jpg
#  extracting: train/truck/wrecker_s_001652_png.rf.e61f100212512d043d7488e3ff62fe9c.jpg
#  extracting: train/truck/wrecker_s_001688_png.rf.6dee1aea6c4120f27d00e2de5189f58e.jpg
#  extracting: train/truck/wrecker_s_001697_png.rf.e228b8ec0b2453115933be4649aa0922.jpg
#  extracting: train/truck/wrecker_s_001764_png.rf.d2fc69499d67b1114639d6fda4dbad9f.jpg
#  extracting: train/truck/wrecker_s_001787_png.rf.dad6f2e6b8b4f66d62ab5c9e400580e8.jpg
#  extracting: train/truck/wrecker_s_001789_png.rf.2ffdc9fb73024dde992bcda7a38f50ba.jpg
#  extracting: train/truck/wrecker_s_001821_png.rf.481b7273e56af39d1c38e311a72e4b63.jpg
#  extracting: train/truck/wrecker_s_001822_png.rf.5224fcdcd020b89d2236046c2a0cc439.jpg
#  extracting: train/truck/wrecker_s_001823_png.rf.901e1a111bd0c27b3e0f5f423690c4fb.jpg
#  extracting: train/truck/wrecker_s_001824_png.rf.38f48062b298faaa26063b802a7f155b.jpg
#  extracting: train/truck/wrecker_s_001825_png.rf.7c838c31189060c2546741292ee7158a.jpg
#  extracting: train/truck/wrecker_s_001851_png.rf.3ba9181fe7b50b8487dda5b9819179d1.jpg
#  extracting: train/truck/wrecker_s_001855_png.rf.826b77bc5e2893335f05e59e15f7884c.jpg
#  extracting: train/truck/wrecker_s_001858_png.rf.e592736a6f6b36913929d10e5fb17100.jpg
#  extracting: train/truck/wrecker_s_001867_png.rf.f91ce3ea0580d291a9f6b9cc91f74c90.jpg
#  extracting: train/truck/wrecker_s_001869_png.rf.5a5331f5d686da2365ce9f74fcd6e15e.jpg
#  extracting: train/truck/wrecker_s_001878_png.rf.8b0262f17ebe2490109dae971a6fa0e7.jpg
#  extracting: train/truck/wrecker_s_001881_png.rf.c5ab64866853c07edc7e7cf4c4f4c312.jpg
#  extracting: train/truck/wrecker_s_001887_png.rf.444135a6d5e050b91bb25ab0b6c0763f.jpg
#  extracting: train/truck/wrecker_s_001892_png.rf.d1fd3292e1755114897aa024b822b65b.jpg
#  extracting: train/truck/wrecker_s_001897_png.rf.9425eb937df5f009d77e3513d7f248f8.jpg
#  extracting: train/truck/wrecker_s_001898_png.rf.4590b93d91ddfb70dfa3573439f0fb09.jpg
#  extracting: train/truck/wrecker_s_001908_png.rf.81d03a5c335d46a2edde57fa248b027a.jpg
#  extracting: train/truck/wrecker_s_001909_png.rf.cdf0bae81a679c6a05ecffc4c1813f09.jpg
#  extracting: train/truck/wrecker_s_001953_png.rf.847437f5768e508ef6e7e272dc9af1b4.jpg
#  extracting: train/truck/wrecker_s_001960_png.rf.6eee8fde864d4626dbedb9674e78475b.jpg
#  extracting: train/truck/wrecker_s_001962_png.rf.c88e913b9f7d5c5b55fbb84e14cede98.jpg
#  extracting: train/truck/wrecker_s_001980_png.rf.0a6bfec088b7a7946abbe8ab0154fd4c.jpg
#  extracting: train/truck/wrecker_s_001982_png.rf.d4252d09d297a9252e2430670e79440e.jpg
#  extracting: train/truck/wrecker_s_001985_png.rf.006d3f207e18ffc9c0b7e4b76baa05f4.jpg
#  extracting: train/truck/wrecker_s_002006_png.rf.70ab324cfea0063bb241cba7073c6a71.jpg
#  extracting: train/truck/wrecker_s_002049_png.rf.f9c92d24797ce0f730e97260c2fb13a9.jpg
#  extracting: train/truck/wrecker_s_002054_png.rf.ba01d4533f6b801ce59a88c2e9e78413.jpg
#  extracting: train/truck/wrecker_s_002064_png.rf.6a846c3f3178cbd9d19cf666b04509ba.jpg
#  extracting: train/truck/wrecker_s_002067_png.rf.d88e868a3c1112d80adc5be85661df84.jpg
#  extracting: train/truck/wrecker_s_002086_png.rf.5f5c0d4cfed7a2c93549cd447f250c33.jpg
#  extracting: train/truck/wrecker_s_002091_png.rf.87939a8524c98535ff83f71a0dcdf387.jpg
#  extracting: train/truck/wrecker_s_002120_png.rf.490f0af17e28f1492e5eb1aa0a6dd234.jpg
#  extracting: train/truck/wrecker_s_002121_png.rf.50cf27a663e4161bfb14098f3e5158fd.jpg
#  extracting: train/truck/wrecker_s_002137_png.rf.d7b3f0eea200bb6cd4f1323b51b82aee.jpg
#  extracting: train/truck/wrecker_s_002150_png.rf.74e37b1bc063194157aed7e472847c8e.jpg
#  extracting: train/truck/wrecker_s_002156_png.rf.64cfd76793372971d2dc6f3b8d0ef5ae.jpg
#  extracting: train/truck/wrecker_s_002157_png.rf.b5f1579dca7dd17c4086acbf6dfae4e2.jpg
#  extracting: train/truck/wrecker_s_002186_png.rf.9a7d7d7cf203473040de5440248f4395.jpg
#  extracting: train/truck/wrecker_s_002195_png.rf.2db52456181461f2bde9f619b8b98249.jpg
#  extracting: train/truck/wrecker_s_002217_png.rf.036af5814165bddaed662d9e1da659b4.jpg
#  extracting: train/truck/wrecker_s_002227_png.rf.9802387cd45076f6a19c9cb159ee7d40.jpg
#  extracting: train/truck/wrecker_s_002228_png.rf.f7a8c9722a300bd89126564576985305.jpg
#  extracting: train/truck/wrecker_s_002231_png.rf.7c9d441ca3edec9847030795f12870f0.jpg
#  extracting: train/truck/wrecker_s_002236_png.rf.a9d9a4d1e30d6bcd6c21056a12fe9e2c.jpg
#  extracting: train/truck/wrecker_s_002242_png.rf.a2b35649d3f2187c1b96158f4ea1f479.jpg
#  extracting: train/truck/wrecker_s_002248_png.rf.39b7ac8664aeeb715ea9189f37bcf49f.jpg
#  extracting: train/truck/wrecker_s_002249_png.rf.b7c4c0c43d288969c5eb2db62e014288.jpg
#  extracting: train/truck/wrecker_s_002251_png.rf.1b6420f32cf96954a335dbe79d785192.jpg
#  extracting: train/truck/wrecker_s_002282_png.rf.298627007d919620f71871f140c90078.jpg
#  extracting: train/truck/wrecker_s_002292_png.rf.a19aa80a06930c01c64189fae44735b0.jpg
#  extracting: train/truck/wrecker_s_002294_png.rf.33dd171609fc2bf1e0769a329f13a559.jpg
#  extracting: train/truck/wrecker_s_002295_png.rf.3313f290323e6c02bd6251a0ac025bf9.jpg
#  extracting: train/truck/wrecker_s_002298_png.rf.98079ee94cef83bbf481a35da4bfeb15.jpg
#  extracting: train/truck/wrecker_s_002299_png.rf.83360c6544fe2adf1799b269e4ae90da.jpg
#  extracting: train/truck/wrecker_s_002302_png.rf.66545093c22220397dfdd75d7aa911d1.jpg
#  extracting: train/truck/wrecker_s_002312_png.rf.f8ef90ab7e56736b387b2deff71d7bd1.jpg
#  extracting: train/truck/wrecker_s_002318_png.rf.1c7044e74e04b03edbca82acb323aeea.jpg
#  extracting: train/truck/wrecker_s_002319_png.rf.8ffe35acd7468ada0329cd40e2a11185.jpg
#  extracting: train/truck/wrecker_s_002320_png.rf.30a1fe001a94e61f2bb59fc6120ddaa8.jpg
#  extracting: train/truck/wrecker_s_002324_png.rf.9fd114a3929c009580f427e2d43133b2.jpg
#  extracting: train/truck/wrecker_s_002325_png.rf.3986e0e877ab740a3fa3ba8196bb9891.jpg
#  extracting: train/truck/wrecker_s_002326_png.rf.23875eee845bcc7967c9f69d133dc1a2.jpg
#  extracting: train/truck/wrecker_s_002365_png.rf.b473e427c38fdef0e52b31afae7d10b3.jpg
#  extracting: train/truck/wrecker_s_002367_png.rf.8667132b1f5607d439aa222115a4e08c.jpg
#  extracting: train/truck/wrecker_s_002373_png.rf.d083629e3cd4dfcfd67f3aa6679e8e9f.jpg
#  extracting: train/truck/wrecker_s_002376_png.rf.a1e8b2af6a49726d211c0f36cb4157b7.jpg
#  extracting: train/truck/wrecker_s_002380_png.rf.ed14dbf57494cf8b8866e20dcc4f2cbb.jpg
#  extracting: train/truck/wrecker_s_002388_png.rf.5cc98995ff3ad3b91e39561db7de82db.jpg
#  extracting: train/truck/wrecker_s_002395_png.rf.2dc94d661e052615c86eb0c957d50c18.jpg
#  extracting: train/truck/wrecker_s_002410_png.rf.78eb47cfc6f26502305553d4ee38d497.jpg

# %% [markdown]
# ### Inspect the Data
# Let's inspect the data. The folder we downloaded and extracted from Kaggle has 12 subfolders, each of which corresponds to one type of seedling with its respective images inside. These will be our labels for the classification task.
#
# If we print the lengths of the contents of these folders we can see that every folder contains a different amount of images. The differences are great, see e.g. that the 'Loose Silky-bent' has the most images (762) while the 'Common Wheat' the fewest (253). We will see later if this amounts to differences in the prediction accuracy.

# %%
import os
labels = os.listdir("train")
print("No. of labels: {}".format(len(labels)))
print("-----------------")

for label in labels:
    print("{}, {} files".format(label, len(os.listdir("train/"+label))))
# Out:
# No. of labels: 10
# -----------------
# automobile, 6000 files
# dog, 6000 files
# horse, 6000 files
# ship, 6000 files
# airplane, 6000 files
# cat, 6000 files
# frog, 6000 files
# bird, 6000 files
# deer, 6097 files
# truck, 6000 files

# %% [markdown]
# Let's have a look at those images. For each of the 10 labels, we will print one random seedling.

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

fig, ax = plt.subplots(nrows=2, ncols=2)
fig.tight_layout()
cnt = 0
for row in ax:
    for col in row:
        image_name = np.random.choice(os.listdir("train/" + labels[cnt]))
        im = Image.open("train/{}/{}".format(labels[cnt],image_name))
        col.imshow(im)
        col.set_title(labels[cnt])
        col.axis('off')
        cnt += 1
plt.show()

# %% [markdown]
# Alright, they look good with a wide array of images!

# %% [markdown]
# ## Creating the Fastai Model

# %% [markdown]
# We can now create the CNN model using the `Fastai` library. Since its major update to v1, it got a lot clearer and consistent, so we only need to import the vision module and accuracy for our metric.

# %%
from fastai.vision.all import *
from fastai.metrics import accuracy

# %% [markdown]
# `Fastai` has a really nice class for handling everything related to the input images for vision tasks. It is called [`ImageDataBunch`](https://docs.fast.ai/vision.data.html#ImageDataBunch) and has different functions, respective of the different ways data can be presented to the network. Since our images are placed in folders whose names correspond to the image labels, we will use the `ImageDataBunch.from_folder()` function to create an object that contains our image data. This is super useful and makes it incredibly easy to read the data into our model, as you will see in a bit.
#
# What's even more handy is that `Fastai` can automatically split our data into train and validation sets, so we don't even need to create these on our own.
#
# The only hyperparameters we need now are the **path-variable** pointing to our data set, the **size of the inputs** and the **batch size** for each gradient descent iteration. To make matters simple, the `ImageDataBunch` object will scale all images to a size*size squared image unless otherwise instructed.
#
# A quick note on image size: the bigger an image, the more details the CNN will be able to pick out of it. At the same time, a bigger image means longer computation times. On the same note it might be that your GPU runs out of memory for a too large batch size. You can half the batch size if this is the case.

# %%
path = "train/"
# size = 224 -> Les images son de 32x32 i ResNet32 és el tamany que vol.
bs = 64

# %% [markdown]
# We will create a variable called `data` in which we place the `ImageDataBunch` object. We create this object with the `from_folder()` function that we discussed above. Among the path to our data, the image and batch size, it also takes:
# * a function argument called `get_transforms()` which returns a list of available image transformations upon call.
# * a parameter `valid_pct` which controls the percentage of images that will be randomly chosen to be in the validation set
# * a parameter `flip_vert` which controls vertical flips and 90° turns in addition to just horizontal flips. (Since our plant images are taken from above, we can perform those without a problem, which would not be feasible on e.g. face data.)

# %%
data = ImageDataLoaders.from_folder(path,
                                  valid_pct=0.2, bs=bs, batch_tfms=[Normalize.from_stats(*imagenet_stats)])

# %%
# data = ImageDataBunch.from_folder(path, ds_tfms=get_transforms(do_flip=True, flip_vert=True),
 #                                 valid_pct=0.2, size=size, bs=bs)

# %% [markdown]
# To normalize the data in our object, we simply call `normalize()` on the object. It is possible to use ImageNet, CIFAR or MNIST stats as templates here, and if left empty this function will simply grab a batch of data from our object and compute the stats on it (mean and standard-deviation) and normalize the data accordingly. Since we will be using a ResNet architecture for our model which was trained on ImageNet, we will be using the ImageNet stats. DEPRECATED !! ARA ES FA DINS DE LA INSTRUCCIO ANTERIOR!

# %%
#data.normalize(imagenet_stats)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-c885932acb73> in <cell line: 0>()
# ----> 1 data.normalize(imagenet_stats)
#
# /usr/local/lib/python3.11/dist-packages/fastcore/basics.py in __getattr__(self, k)
#     534         if self._component_attr_filter(k):
#     535             attr = getattr(self,self._default,None)
# --> 536             if attr is not None: return getattr(attr,k)
#     537         raise AttributeError(k)
#     538     def __dir__(self): return custom_dir(self,self._dir())
#
# /usr/local/lib/python3.11/dist-packages/fastcore/basics.py in __getattr__(self, k)
#     534         if self._component_attr_filter(k):
#     535             attr = getattr(self,self._default,None)
# --> 536             if attr is not None: return getattr(attr,k)
#     537         raise AttributeError(k)
#     538     def __dir__(self): return custom_dir(self,self._dir())
#
# /usr/local/lib/python3.11/dist-packages/fastai/data/core.py in __getattr__(self, k)
#     450         return res if is_indexer(it) else list(zip(*res))
#     451
# --> 452     def __getattr__(self,k): return gather_attrs(self, k, 'tls')
#     453     def __dir__(self): return super().__dir__() + gather_attr_names(self, 'tls')
#     454     def __len__(self): return len(self.tls[0])
#
# /usr/local/lib/python3.11/dist-packages/fastcore/transform.py in gather_attrs(o, k, nm)
#     173     att = getattr(o,nm)
#     174     res = [t for t in att.attrgot(k) if t is not None]
# --> 175     if not res: raise AttributeError(k)
#     176     return res[0] if len(res)==1 else L(res)
#     177
#
# AttributeError: normalize

# %% [markdown]
# That's it, two lines of code for optimizing our dataset for training, adding different kinds of transformations and normalization! I would kindly ask you to stop here for a moment and just take a second to appreciate the beauty of this. The beauty of high-level libraries; just two lines of code and we have increased the diversity of our dataset tremendously. I can already hear my ugly batchnorm code crying in the trashbin.
#
# All that is left now is to create the actual network and train it, which could not be more simple.
#
# `Fastai` supplies us with a function called [`create_cnn()`](https://docs.fast.ai/vision.learner.html#create_cnn) from its vision module. This function creates what is called a `learner` object, which we'll put into a properly named variable. See here that we specify the ResNet architecture as our base model for transfer learning. Upon call, the trained architecture will be downloaded via the `Fastai` API and stored locally.
#
# We will use accuracy for our metric. If you check the [docs](https://docs.fast.ai/metrics.html) you can see a list of other metrics which are availabe. Defining the callback function `ShowGraph` simply tells the learner that it should return a graph for whatever it does, which seems very useful to me for seeing whether the model is still improving.

# %%
learner = cnn_learner(data, models.resnet18, metrics=[accuracy])#, callback_fns=ShowGraph)
# Out:
# /usr/local/lib/python3.11/dist-packages/fastai/vision/learner.py:303: UserWarning: `cnn_learner` has been renamed to `vision_learner` -- please update your code
#   warn("`cnn_learner` has been renamed to `vision_learner` -- please update your code")
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 166MB/s]

# %% [markdown]
# ### Finding the learning rate
#
# The learner object we create comes with a build-in function to find the optimal learning rate, or range of learning rates, for training. It achieves this by fitting the model for a few epochs and saving for which learning rates the loss decreases the most.
#
# We want to choose a learning rate, for which the loss is still decreasing, i.e. we do not want the learning rate with the minimum loss, but with the steepest slope.
#
# In the following plot, which is stored in the recorder object of our learner, we can see that this is the case for learning rates between 0.001 and 0.01.

# %%
learner.lr_find()
learner.recorder.plot()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# /usr/local/lib/python3.11/dist-packages/fastai/learner.py:53: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state = torch.load(file, map_location=device, **torch_load_kwargs)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-dfd2171f1eb8> in <cell line: 0>()
#       1 learner.lr_find()
# ----> 2 learner.recorder.plot()
#
# /usr/local/lib/python3.11/dist-packages/fastcore/basics.py in __getattr__(self, k)
#     534         if self._component_attr_filter(k):
#     535             attr = getattr(self,self._default,None)
# --> 536             if attr is not None: return getattr(attr,k)
#     537         raise AttributeError(k)
#     538     def __dir__(self): return custom_dir(self,self._dir())
#
# /usr/local/lib/python3.11/dist-packages/fastcore/basics.py in __getattr__(self, k)
#     534         if self._component_attr_filter(k):
#     535             attr = getattr(self,self._default,None)
# --> 536             if attr is not None: return getattr(attr,k)
#     537         raise AttributeError(k)
#     538     def __dir__(self): return custom_dir(self,self._dir())
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in __getattr__(self, name)
#    1929             if name in modules:
#    1930                 return modules[name]
# -> 1931         raise AttributeError(
#    1932             f"'{type(self).__name__}' object has no attribute '{name}'"
#    1933         )
#
# AttributeError: 'Sequential' object has no attribute 'plot'

# %% [markdown]
# ### First fit and evaluation
# Now let's fit our model for 8 epochs, with a learning rate between 0.001 and 0.01

# %%
learner.fit_one_cycle(8, slice(1e-3, 1e-2))
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.517718</td>
#       <td>1.342577</td>
#       <td>0.526000</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.074444</td>
#       <td>0.973268</td>
#       <td>0.660454</td>
#       <td>00:59</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.968269</td>
#       <td>0.846450</td>
#       <td>0.706631</td>
#       <td>00:59</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.877109</td>
#       <td>0.787583</td>
#       <td>0.725518</td>
#       <td>00:59</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.831194</td>
#       <td>0.777577</td>
#       <td>0.725601</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.781236</td>
#       <td>0.726142</td>
#       <td>0.745403</td>
#       <td>00:57</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.719526</td>
#       <td>0.718745</td>
#       <td>0.748315</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.714483</td>
#       <td>0.712875</td>
#       <td>0.752059</td>
#       <td>00:59</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# That already looks good! The loss is decreasing a lot in the first few 1/5th of iterations, and less but continously afterwards.
#
# Let's see where the algorithm is making the most mistakes:

# %%
interpreter = ClassificationInterpretation.from_learner(learner)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
interpreter.most_confused(min_val=2)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# [('dog', 'cat', 192),
#  ('cat', 'dog', 153),
#  ('truck', 'automobile', 119),
#  ('automobile', 'truck', 102),
#  ('bird', 'deer', 98),
#  ('deer', 'horse', 97),
#  ('dog', 'horse', 90),
#  ('cat', 'deer', 80),
#  ('horse', 'deer', 75),
#  ('airplane', 'ship', 73),
#  ('ship', 'airplane', 73),
#  ('bird', 'frog', 71),
#  ('bird', 'airplane', 68),
#  ('cat', 'frog', 66),
#  ('cat', 'horse', 66),
#  ('frog', 'deer', 55),
#  ('frog', 'bird', 54),
#  ('cat', 'bird', 53),
#  ('horse', 'dog', 53),
#  ('bird', 'cat', 52),
#  ('deer', 'cat', 52),
#  ('deer', 'bird', 51),
#  ('horse', 'cat', 51),
#  ('frog', 'cat', 50),
#  ('dog', 'deer', 49),
#  ('bird', 'dog', 47),
#  ('airplane', 'bird', 41),
#  ('dog', 'bird', 39),
#  ('truck', 'airplane', 39),
#  ('bird', 'horse', 38),
#  ('ship', 'automobile', 38),
#  ('deer', 'dog', 37),
#  ('deer', 'frog', 36),
#  ('ship', 'truck', 36),
#  ('airplane', 'truck', 30),
#  ('automobile', 'airplane', 30),
#  ('dog', 'frog', 30),
#  ('automobile', 'ship', 29),
#  ('deer', 'airplane', 27),
#  ('frog', 'dog', 27),
#  ('truck', 'ship', 26),
#  ('cat', 'airplane', 25),
#  ('airplane', 'automobile', 23),
#  ('airplane', 'horse', 22),
#  ('truck', 'horse', 22),
#  ('airplane', 'deer', 20),
#  ('horse', 'bird', 20),
#  ('airplane', 'cat', 19),
#  ('automobile', 'frog', 19),
#  ('ship', 'deer', 18),
#  ('truck', 'cat', 18),
#  ('cat', 'truck', 15),
#  ('bird', 'ship', 14),
#  ('horse', 'truck', 14),
#  ('automobile', 'horse', 12),
#  ('cat', 'ship', 12),
#  ('truck', 'bird', 11),
#  ('cat', 'automobile', 10),
#  ('frog', 'automobile', 10),
#  ('ship', 'bird', 10),
#  ('ship', 'cat', 10),
#  ('truck', 'dog', 10),
#  ('bird', 'automobile', 9),
#  ('frog', 'horse', 9),
#  ('horse', 'airplane', 9),
#  ('truck', 'frog', 9),
#  ('dog', 'airplane', 8),
#  ('frog', 'ship', 8),
#  ('truck', 'deer', 8),
#  ('airplane', 'frog', 7),
#  ('deer', 'ship', 7),
#  ('frog', 'truck', 7),
#  ('automobile', 'bird', 6),
#  ('ship', 'horse', 6),
#  ('automobile', 'cat', 5),
#  ('horse', 'ship', 5),
#  ('ship', 'frog', 5),
#  ('airplane', 'dog', 4),
#  ('automobile', 'deer', 4),
#  ('bird', 'truck', 4),
#  ('deer', 'automobile', 4),
#  ('dog', 'automobile', 4),
#  ('frog', 'airplane', 4),
#  ('horse', 'automobile', 4),
#  ('horse', 'frog', 4),
#  ('automobile', 'dog', 3),
#  ('dog', 'ship', 3),
#  ('ship', 'dog', 3),
#  ('deer', 'truck', 2),
#  ('dog', 'truck', 2)]

# %% [markdown]
# This shows us that the algorithm confuses a few of our class examples, but it's doing well, overall.

# %% [markdown]
# ## Improving the Model

# %% [markdown]
# ### Unfreezing and fine-tuning
# Before we unfreeze the layers and learn again, we save the weights (SAVE) so we can go back in case we mess up.
# GASTEM EXPORT PA PILLAR TOT EL MODEL

# %%
learner.export('stage-1-bo')

#learner.save('stage-1')
#learner.load('stage-1')

# %%
learner.unfreeze()

# %%
learner.fit_one_cycle(12, slice(1e-5, 1e-4))
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.684842</td>
#       <td>0.705760</td>
#       <td>0.755637</td>
#       <td>01:02</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.668771</td>
#       <td>0.668357</td>
#       <td>0.766204</td>
#       <td>01:04</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.620486</td>
#       <td>0.633405</td>
#       <td>0.777269</td>
#       <td>01:04</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.541700</td>
#       <td>0.617124</td>
#       <td>0.790748</td>
#       <td>01:02</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.479210</td>
#       <td>0.611292</td>
#       <td>0.793993</td>
#       <td>01:02</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.388654</td>
#       <td>0.610106</td>
#       <td>0.795158</td>
#       <td>01:01</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.345568</td>
#       <td>0.626783</td>
#       <td>0.795574</td>
#       <td>01:05</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.292476</td>
#       <td>0.638110</td>
#       <td>0.796572</td>
#       <td>01:04</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.252536</td>
#       <td>0.646628</td>
#       <td>0.795241</td>
#       <td>01:01</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.228107</td>
#       <td>0.661088</td>
#       <td>0.795407</td>
#       <td>01:02</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.200374</td>
#       <td>0.657307</td>
#       <td>0.796822</td>
#       <td>01:02</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.199297</td>
#       <td>0.657942</td>
#       <td>0.796905</td>
#       <td>01:01</td>
#     </tr>
#   </tbody>
# </table>

# %%
torch.save(learner.model, 'stage-2-pytorch')

#learner.export('stage-2-bo')

#learner.save('stage-2')

# %% [markdown]
# We will stick to this, because the validation error is getting worse than the testing error, and it looks like this tendency will only increase. The model would start to **overfit the training data** if we continue training from this point onwards!
#
# Good job, we successfully trained a state-of-the-art image classifier for a custom dataset, achieving 96.5% accuracy in just a handful of lines of code!

# %%
interpreter = ClassificationInterpretation.from_learner(learner)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
interpreter.most_confused(min_val=2)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# [('dog', 'cat', 185),
#  ('cat', 'dog', 158),
#  ('truck', 'automobile', 97),
#  ('automobile', 'truck', 79),
#  ('bird', 'deer', 69),
#  ('cat', 'frog', 64),
#  ('horse', 'deer', 64),
#  ('cat', 'deer', 63),
#  ('bird', 'cat', 59),
#  ('deer', 'horse', 58),
#  ('deer', 'bird', 55),
#  ('bird', 'dog', 52),
#  ('horse', 'dog', 52),
#  ('airplane', 'ship', 50),
#  ('bird', 'frog', 50),
#  ('dog', 'horse', 50),
#  ('ship', 'airplane', 50),
#  ('frog', 'cat', 49),
#  ('bird', 'airplane', 47),
#  ('cat', 'bird', 47),
#  ('dog', 'bird', 45),
#  ('cat', 'horse', 44),
#  ('deer', 'cat', 42),
#  ('frog', 'bird', 41),
#  ('dog', 'deer', 40),
#  ('horse', 'cat', 40),
#  ('airplane', 'bird', 37),
#  ('truck', 'airplane', 34),
#  ('deer', 'frog', 31),
#  ('frog', 'deer', 29),
#  ('airplane', 'truck', 28),
#  ('dog', 'frog', 27),
#  ('ship', 'truck', 27),
#  ('cat', 'airplane', 26),
#  ('automobile', 'airplane', 25),
#  ('truck', 'ship', 25),
#  ('airplane', 'automobile', 22),
#  ('airplane', 'cat', 22),
#  ('bird', 'horse', 22),
#  ('deer', 'airplane', 21),
#  ('ship', 'automobile', 19),
#  ('deer', 'dog', 17),
#  ('automobile', 'frog', 16),
#  ('frog', 'dog', 16),
#  ('horse', 'bird', 16),
#  ('ship', 'cat', 15),
#  ('truck', 'cat', 15),
#  ('truck', 'horse', 15),
#  ('airplane', 'horse', 14),
#  ('bird', 'ship', 14),
#  ('airplane', 'deer', 13),
#  ('automobile', 'ship', 13),
#  ('frog', 'ship', 13),
#  ('horse', 'truck', 13),
#  ('ship', 'deer', 12),
#  ('cat', 'truck', 11),
#  ('airplane', 'frog', 10),
#  ('cat', 'ship', 10),
#  ('truck', 'frog', 10),
#  ('cat', 'automobile', 9),
#  ('dog', 'airplane', 9),
#  ('bird', 'automobile', 8),
#  ('automobile', 'cat', 7),
#  ('frog', 'automobile', 7),
#  ('frog', 'horse', 7),
#  ('truck', 'bird', 7),
#  ('horse', 'frog', 6),
#  ('ship', 'bird', 6),
#  ('truck', 'deer', 6),
#  ('automobile', 'horse', 5),
#  ('bird', 'truck', 5),
#  ('deer', 'automobile', 5),
#  ('deer', 'ship', 5),
#  ('dog', 'ship', 5),
#  ('frog', 'airplane', 5),
#  ('ship', 'dog', 5),
#  ('ship', 'frog', 5),
#  ('truck', 'dog', 5),
#  ('automobile', 'deer', 4),
#  ('deer', 'truck', 4),
#  ('dog', 'automobile', 4),
#  ('frog', 'truck', 4),
#  ('horse', 'airplane', 4),
#  ('automobile', 'dog', 3),
#  ('dog', 'truck', 3),
#  ('horse', 'automobile', 3),
#  ('horse', 'ship', 3),
#  ('airplane', 'dog', 2)]
