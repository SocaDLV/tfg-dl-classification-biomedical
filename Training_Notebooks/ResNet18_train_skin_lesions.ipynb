# %% [markdown]
# Flowers Classification
#
#
# Dataset [here](https://public.roboflow.ai/classification/flowers)

# %% [markdown]
# ## Intro

# %% [markdown]
# ### About Fastai
# If you haven't heard of `Fastai` yet I recommend taking a look at their [homepage](https://www.fast.ai/). In their mission statement it is stated that not only do they want to accelerate and help deep learning research, they also want to decrease the entry barriers for everyone. This line is from their introduction of `PyTorch` for `Fastai` back in September 2017 [(Source)](https://www.fast.ai/2017/09/08/introducing-pytorch-for-fastai/):
#
#     Everybody should be able to use deep learning to solve their problems with no more education than it takes to use a smart phone. Therefore, each year our main research goal is to be able to teach a wider range of deep learning applications, that run faster, and are more accurate, to people with less prerequisites.
#
# You can feel this ambition even if you watch `Fastai`'s 2019 course, and it's something that gives me a good feeling about the direction the field is headed. As it often happens in research, knowledge and tools are only accessible to a certain minority. This is even more pronounced in deep learning research, where you need huge amounts of RAM in powerful GPUs to solve a lot of problems (check this unrelated [video](https://www.youtube.com/watch?v=-P28LKWTzrI) on GPU vs CPU).

# %% [markdown]
# ### Setting up Google Colab
# To avoid redundancy online, please check this [Medium post](https://towardsdatascience.com/fast-ai-lesson-1-on-google-colab-free-gpu-d2af89f53604) by [Manikanta Yadunanda](https://towardsdatascience.com/@manikantayadunanda) for a quick introduction on how to use the Google Colaboratory (Colab) with `Fastai`. Since this introduction was written, Google has included official `Fastai` and `PyTorch` support in Colab. You can check with the following line of code if all of the important `pip` packages are installed. If not, uncomment the last line and use it to install `Fastai` and `PyTorch` for Python 3.6.x and CUDA 9.x.

# %%
# Check if fastai and pytorch are installed
# !pip list | grep -e fastai -e torch -e torchvision
# Out:
# fastai                                2.7.19
# torch                                 2.6.0+cu124
# torchao                               0.10.0
# torchaudio                            2.6.0+cu124
# torchdata                             0.11.0
# torchsummary                          1.5.1
# torchtune                             0.6.1
# torchvision                           0.21.0+cu124

# %%
# If not, uncomment this line and run to install them
#!pip install torch torchvision fastai

# %% [markdown]
# ### Cloning this Notebook
# To access this notebook and run the computations yourself, you can simply import it directly from my GitHub repository. Just go to File... Open Notebook..., select the GitHub tab and enter 'verrannt/Tutorials' in the search bar. Select the 'fastai-plant-seedlings-classification.ipynb' and you're done. Simple as that. After you checked that Colab is configured for `Fastai` support, you can continue with the data preperation part.

# %% [markdown]
# ## Data Preperation

# %% [markdown]
# ### Get the Data
#
# We'll grab our data from Roboflow.
#
# Select `Export`, and "Show Download Code".

# %%
# !curl -L "https://app.roboflow.com/ds/vETD35pmu8?key=zOrJV7ToDk" > roboflow.zip; unzip roboflow.zip; rm roboflow.zip
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
#  extracting: train/cowpox/CWP_14_01_3_jpg.rf.ee1a6274802e32c539ecc205fab45133.jpg
#  extracting: train/cowpox/CWP_14_01_4_jpg.rf.9b62464473ebec08a3dbe6bc3dbc7d0d.jpg
#  extracting: train/cowpox/CWP_14_01_6_jpg.rf.081f7a6cb9a497b66937b11bdccd15e0.jpg
#  extracting: train/cowpox/CWP_14_01_9_jpg.rf.b9602bd22c181cf92c097fa583930aac.jpg
#  extracting: train/cowpox/CWP_15_01_10_jpg.rf.1b4f5cc5d192a195534879532897101c.jpg
#  extracting: train/cowpox/CWP_15_01_12_jpg.rf.08d1f178c3ec50495bac8e0ff2f81f89.jpg
#  extracting: train/cowpox/CWP_15_01_13_jpg.rf.7d785e1314687fd3ade153e75871e840.jpg
#  extracting: train/cowpox/CWP_15_01_1_jpg.rf.07e9c70f0ba8b92d0f32cd868ae3b982.jpg
#  extracting: train/cowpox/CWP_15_01_2_jpg.rf.7c5a0db79b242c0785a97632e6e16ad4.jpg
#  extracting: train/cowpox/CWP_15_01_5_jpg.rf.2b00adc362d15b46bbb8b430fff3ac3f.jpg
#  extracting: train/cowpox/CWP_15_01_7_jpg.rf.b236b858623f49031829fb9154a5130e.jpg
#  extracting: train/cowpox/CWP_15_01_9_jpg.rf.476fa980c1a91502883c5846c33be257.jpg
#  extracting: train/cowpox/CWP_15_01_jpg.rf.2a8d91c6b54618ec17fbdced5dc0158d.jpg
#  extracting: train/cowpox/CWP_16_01_10_jpg.rf.fb566f5f2493b55c3ef09854e6c878ef.jpg
#  extracting: train/cowpox/CWP_16_01_11_jpg.rf.85774bd32317d208e2943c8d878a422e.jpg
#  extracting: train/cowpox/CWP_16_01_13_jpg.rf.b7634dd37a7220cbcf1f4773b6fb1d50.jpg
#  extracting: train/cowpox/CWP_16_01_1_jpg.rf.4f96114ace16d9d19b33a2ea470cfb05.jpg
#  extracting: train/cowpox/CWP_16_01_2_jpg.rf.806f8ae351767fcf2f5e0932355b16a0.jpg
#  extracting: train/cowpox/CWP_16_01_3_jpg.rf.4cacc9975a1a82013f23c09d2679ad50.jpg
#  extracting: train/cowpox/CWP_16_01_4_jpg.rf.9cdcca0a5483fb663775220f606ff171.jpg
#  extracting: train/cowpox/CWP_16_01_5_jpg.rf.6742e76c8a7b07ff76ce94a950f34feb.jpg
#  extracting: train/cowpox/CWP_16_01_6_jpg.rf.dceddabbbd43b4c7b5cb8bd6dba73397.jpg
#  extracting: train/cowpox/CWP_16_01_7_jpg.rf.a1d44fd2a1dce2d90a7bf9ee77fa25e0.jpg
#  extracting: train/cowpox/CWP_16_01_8_jpg.rf.714bac43be31f944d786083857727dd9.jpg
#  extracting: train/cowpox/CWP_16_01_9_jpg.rf.bfefd39ac6f137fbfc6bcd82ddd41ec4.jpg
#  extracting: train/cowpox/CWP_17_01_12_jpg.rf.6ff58ebe91ecb8a608686f60bba554e9.jpg
#  extracting: train/cowpox/CWP_17_01_3_jpg.rf.c2c6cfe64c062c4e5a471f584ee751de.jpg
#  extracting: train/cowpox/CWP_17_01_4_jpg.rf.d348ad42eb02d230bdfc14a8d53a9b86.jpg
#  extracting: train/cowpox/CWP_17_01_5_jpg.rf.b002256bb2df5516ef63b5208f53d6f4.jpg
#  extracting: train/cowpox/CWP_17_01_6_jpg.rf.07e4ef56d7dfe4f1bcbdf994b5ab9412.jpg
#  extracting: train/cowpox/CWP_17_01_7_jpg.rf.8e43bab80dc5ecaccf3e95d133ee5ae1.jpg
#  extracting: train/cowpox/CWP_17_01_9_jpg.rf.ff8428c620c13d51255906c7b86b37be.jpg
#  extracting: train/cowpox/CWP_17_01_ORIGINAL_jpg.rf.3486e83cd79e1511b1884c85b2c61ea2.jpg
#  extracting: train/cowpox/CWP_17_01_jpg.rf.6788846374171404a6a0ec386bcf006a.jpg
#  extracting: train/cowpox/CWP_18_01_10_jpg.rf.b765b1d94e0880c949001fb7feeb6f17.jpg
#  extracting: train/cowpox/CWP_18_01_12_jpg.rf.c7c273083dba73117dad1e6b9b7d68bd.jpg
#  extracting: train/cowpox/CWP_18_01_13_jpg.rf.4414a88d3c9cc3ca59f3696e7819d9b2.jpg
#  extracting: train/cowpox/CWP_18_01_1_jpg.rf.5a573bcaace04252786b708123aac923.jpg
#  extracting: train/cowpox/CWP_18_01_3_jpg.rf.b2f70f04b6a11e0df1583d04e334abbf.jpg
#  extracting: train/cowpox/CWP_18_01_4_jpg.rf.b3a551a7a9e8393b342de565f4e9e7f8.jpg
#  extracting: train/cowpox/CWP_18_01_5_jpg.rf.7be32c2333fcd8d3b376bd1faea26646.jpg
#  extracting: train/cowpox/CWP_18_01_6_jpg.rf.d469b8eba80796b8eee75926e0ead25b.jpg
#  extracting: train/cowpox/CWP_18_01_7_jpg.rf.d7ea93acc6a4c033ba89571681e6f9a9.jpg
#  extracting: train/cowpox/CWP_18_01_8_jpg.rf.436ce9743de2b7f1848b496ce8fd0547.jpg
#  extracting: train/cowpox/CWP_18_01_9_jpg.rf.de41562765fdda0f3c5b2298c0082ce4.jpg
#  extracting: train/cowpox/CWP_18_01_jpg.rf.a5fd9488d8a67e7ea4d3a3c8f041aa81.jpg
#  extracting: train/cowpox/CWP_19_01_10_jpg.rf.c757febcb19a894537cbb86a1c2f0357.jpg
#  extracting: train/cowpox/CWP_19_01_11_jpg.rf.5e5db38bb7acb292f096f215d90adcf6.jpg
#  extracting: train/cowpox/CWP_19_01_12_jpg.rf.88678bb45cdc32663a2daedc2cb681b1.jpg
#  extracting: train/cowpox/CWP_19_01_13_jpg.rf.57a6c637f764cb16eee9621b2ce62955.jpg
#  extracting: train/cowpox/CWP_19_01_1_jpg.rf.b1b7d3efc50795a5450fc8d93636eda3.jpg
#  extracting: train/cowpox/CWP_19_01_2_jpg.rf.65f2fb4504715a0871b0af54b239bcd4.jpg
#  extracting: train/cowpox/CWP_19_01_3_jpg.rf.f45ce85a825fb1d557ab8ebfdbb6f971.jpg
#  extracting: train/cowpox/CWP_19_01_4_jpg.rf.3b9a45c2646f15e6af8a772736a8e5c2.jpg
#  extracting: train/cowpox/CWP_19_01_5_jpg.rf.6b0c6a0d611d81555fc41a43bc706e06.jpg
#  extracting: train/cowpox/CWP_19_01_6_jpg.rf.768cad235f2a9c73e7c0ded7495431e5.jpg
#  extracting: train/cowpox/CWP_19_01_7_jpg.rf.6f1d3d76498219a41549b9ab1b82c087.jpg
#  extracting: train/cowpox/CWP_19_01_8_jpg.rf.76fcd4187368a456e0df2c5217553703.jpg
#  extracting: train/cowpox/CWP_19_01_9_jpg.rf.ad2403b1324db13a70af116404fe9100.jpg
#  extracting: train/cowpox/CWP_19_01_jpg.rf.7131b8f4d7add38d0261bde639d62c46.jpg
#  extracting: train/cowpox/CWP_20_01_10_jpg.rf.7863c982ec7a136cdae0a3f1593d0f55.jpg
#  extracting: train/cowpox/CWP_20_01_13_jpg.rf.e6926d189ce448c4cf8b8df8aa45f179.jpg
#  extracting: train/cowpox/CWP_20_01_1_jpg.rf.8b763051d79124658b335ad81fb50477.jpg
#  extracting: train/cowpox/CWP_20_01_3_jpg.rf.c1db1d1f6513122e4244af175d521c4b.jpg
#  extracting: train/cowpox/CWP_20_01_4_jpg.rf.45b046a75d9c35f3fc9b49c930d45307.jpg
#  extracting: train/cowpox/CWP_20_01_6_jpg.rf.09f666ffd85f248fa3df7c943432a716.jpg
#  extracting: train/cowpox/CWP_20_01_7_jpg.rf.4ae5118d2549e7ffd4e577141d44aa6a.jpg
#  extracting: train/cowpox/CWP_20_01_8_jpg.rf.2de24f5a58a4c785d92a8922effa6dcd.jpg
#  extracting: train/cowpox/CWP_20_01_9_jpg.rf.f8c6dd466e424e40bd3c3d3898c60c00.jpg
#  extracting: train/cowpox/CWP_20_01_jpg.rf.7fbfdf9717f103790065d31bd805b701.jpg
#  extracting: train/cowpox/CWP_21_01_10_jpg.rf.ac9b05a48ad6477c6c92473b5424f0d7.jpg
#  extracting: train/cowpox/CWP_21_01_11_jpg.rf.7e811698ea270e1fc320052be5b97bcc.jpg
#  extracting: train/cowpox/CWP_21_01_12_jpg.rf.36724ebff4e267237cb5d2280fb022a6.jpg
#  extracting: train/cowpox/CWP_21_01_13_jpg.rf.006ad8d3554831227b8699b2b070b11c.jpg
#  extracting: train/cowpox/CWP_21_01_1_jpg.rf.b8ed70458ae3c86a660d4c197f7b7cb1.jpg
#  extracting: train/cowpox/CWP_21_01_2_jpg.rf.114781b758ff32d942b2fa32e7f770bf.jpg
#  extracting: train/cowpox/CWP_21_01_5_jpg.rf.89bddb5f7fb3aa22669a7503134491a3.jpg
#  extracting: train/cowpox/CWP_21_01_7_jpg.rf.64add459062c07ca7d694f4a978e78d9.jpg
#  extracting: train/cowpox/CWP_21_01_8_jpg.rf.4d7defabd575eb148c961c35d2bbfeed.jpg
#  extracting: train/cowpox/CWP_21_01_9_jpg.rf.bd04c79b811324b6f1159d3d6c66f477.jpg
#  extracting: train/cowpox/CWP_21_01_jpg.rf.f8e4ed48f4feb97d8a4b0a39df159a04.jpg
#  extracting: train/cowpox/CWP_22_01_10_jpg.rf.909323298ec51eb1a233b0f3dba4c1c8.jpg
#  extracting: train/cowpox/CWP_22_01_11_jpg.rf.c87184c54777cb5ae16e6bb35efed1bc.jpg
#  extracting: train/cowpox/CWP_22_01_12_jpg.rf.1ebac56bae54ddc54ef053696f271085.jpg
#  extracting: train/cowpox/CWP_22_01_13_jpg.rf.70c601f9d409192bb27528db00137b5d.jpg
#  extracting: train/cowpox/CWP_22_01_1_jpg.rf.0c3d4a9156579c2f35fa762b0e5a1798.jpg
#  extracting: train/cowpox/CWP_22_01_3_jpg.rf.c43f99e1621cb79f2109da64f9091fd2.jpg
#  extracting: train/cowpox/CWP_22_01_4_jpg.rf.066056f7860ae880d31d32eceed0d080.jpg
#  extracting: train/cowpox/CWP_22_01_6_jpg.rf.2b1081047a33cae09c8f6f6c3fe8f3cd.jpg
#  extracting: train/cowpox/CWP_22_01_7_jpg.rf.b5cfc2a278f74287b87f176908d57fcf.jpg
#  extracting: train/cowpox/CWP_22_01_8_jpg.rf.32763325d0b6ddb29578c57e2035b6dc.jpg
#  extracting: train/cowpox/CWP_22_01_9_jpg.rf.56fbc180dc18b5fc5f0e22f4999cd783.jpg
#  extracting: train/cowpox/CWP_22_01_jpg.rf.506376e4fa34754e427711ef88bd06e6.jpg
#  extracting: train/cowpox/CWP_22_02_11_jpg.rf.8309c2ad4e1204dc76093c65301c809f.jpg
#  extracting: train/cowpox/CWP_22_02_12_jpg.rf.38db319b45443c0852c1d6b21761639e.jpg
#  extracting: train/cowpox/CWP_22_02_13_jpg.rf.6fe0dbd604b4792631c08b922d060237.jpg
#  extracting: train/cowpox/CWP_22_02_1_jpg.rf.735329f8b56ad59d9029c0c132fc8ce9.jpg
#  extracting: train/cowpox/CWP_22_02_2_jpg.rf.c8070e69862c61264636bb7735ea37ed.jpg
#  extracting: train/cowpox/CWP_22_02_3_jpg.rf.4c6dcda73c7e4405c53e46073d4041ad.jpg
#  extracting: train/cowpox/CWP_22_02_4_jpg.rf.adac6f051723ffd27bf7df143522c9df.jpg
#  extracting: train/cowpox/CWP_22_02_5_jpg.rf.0aeb74449159edb05efca217159fc10a.jpg
#  extracting: train/cowpox/CWP_22_02_6_jpg.rf.e11787038f0a2a9b5a5dee21388b7860.jpg
#  extracting: train/cowpox/CWP_22_02_8_jpg.rf.54b0ce1a5b7c554caed77baea8aaa157.jpg
#  extracting: train/cowpox/CWP_22_02_9_jpg.rf.493aae2c9c69a3fa7b6f7e8c421fc15e.jpg
#  extracting: train/cowpox/CWP_22_02_jpg.rf.ce1a2cb5449e5798982a74416464a75f.jpg
#  extracting: train/cowpox/CWP_23_01_10_jpg.rf.cd017f2983bcab6835cef761ae5a2d66.jpg
#  extracting: train/cowpox/CWP_23_01_11_jpg.rf.43663af528bf11d50dfffe248dce325d.jpg
#  extracting: train/cowpox/CWP_23_01_12_jpg.rf.7aa0f815bbade97f790a71ed69fff0ce.jpg
#  extracting: train/cowpox/CWP_23_01_13_jpg.rf.cd360e3b0e81956b270ff4df361027b9.jpg
#  extracting: train/cowpox/CWP_23_01_1_jpg.rf.2b5365a25011a1c8e32fb537961bf4fc.jpg
#  extracting: train/cowpox/CWP_23_01_3_jpg.rf.17700172b8e3ef1493c84abe0fd043ab.jpg
#  extracting: train/cowpox/CWP_23_01_4_jpg.rf.050d9f10ff8e107d702c0285c5cc1430.jpg
#  extracting: train/cowpox/CWP_23_01_5_jpg.rf.c56e61b452d75c675d61d405891e7088.jpg
#  extracting: train/cowpox/CWP_23_01_6_jpg.rf.322b25fcaecb156615909aaa7bb16081.jpg
#  extracting: train/cowpox/CWP_23_01_7_jpg.rf.9f1c08310d0ae4a643b5c5cd8f86dd01.jpg
#  extracting: train/cowpox/CWP_23_01_8_jpg.rf.50c306381a393a2897b9c30a6d888507.jpg
#  extracting: train/cowpox/CWP_23_01_9_jpg.rf.d2f729173228117903b371fad809f97e.jpg
#  extracting: train/cowpox/CWP_23_01_jpg.rf.991777457f55a0dc35b45002052c10fa.jpg
#  extracting: train/cowpox/CWP_24_01_10_jpg.rf.62ce30dc30173cc2948e26c5309841f2.jpg
#  extracting: train/cowpox/CWP_24_01_12_jpg.rf.cc24df0ef7f7345c8dcce33ad55cd34e.jpg
#  extracting: train/cowpox/CWP_24_01_13_jpg.rf.aa595039b325f5a3f720d45696a13d5a.jpg
#  extracting: train/cowpox/CWP_24_01_1_jpg.rf.5c2a7bd76807ac5f910dc3d6e4aec43a.jpg
#  extracting: train/cowpox/CWP_24_01_2_jpg.rf.271e2c4bc73ce07f9751eef0b046260c.jpg
#  extracting: train/cowpox/CWP_24_01_3_jpg.rf.477ef483773899062b5908ce0a3fb521.jpg
#  extracting: train/cowpox/CWP_24_01_6_jpg.rf.646a3c2c13b661e31ce8d7b142b545dc.jpg
#  extracting: train/cowpox/CWP_24_01_7_jpg.rf.660fcd4d98a30a7e72eeccb165a5d184.jpg
#  extracting: train/cowpox/CWP_24_01_jpg.rf.2a0d132671664770c78ea262190f0aeb.jpg
#  extracting: train/cowpox/CWP_25_01_10_jpg.rf.a0bd34398a779c7da1e4a1ae2a99cbfa.jpg
#  extracting: train/cowpox/CWP_25_01_12_jpg.rf.09907b8db0c28cc7b5919d970927593d.jpg
#  extracting: train/cowpox/CWP_25_01_13_jpg.rf.87607b71c3142e78954fe150bfd74725.jpg
#  extracting: train/cowpox/CWP_25_01_1_jpg.rf.6ca12917b0f5a9f98f7786fa69f6c129.jpg
#  extracting: train/cowpox/CWP_25_01_2_jpg.rf.4ca6da4b05cb054d5a8a92a07d38486e.jpg
#  extracting: train/cowpox/CWP_25_01_3_jpg.rf.ed75d02ebdc3fd1477de6b19d457d84d.jpg
#  extracting: train/cowpox/CWP_25_01_4_jpg.rf.de7116dce25677b0687ae98e129e8ec8.jpg
#  extracting: train/cowpox/CWP_25_01_5_jpg.rf.a95db1bde5ed8ce8b4ef62c52baa6799.jpg
#  extracting: train/cowpox/CWP_25_01_6_jpg.rf.835129d231a7060622f8606eec976943.jpg
#  extracting: train/cowpox/CWP_25_01_7_jpg.rf.beeb1fb4508cc3f7005a12cc1af8cac7.jpg
#  extracting: train/cowpox/CWP_25_01_8_jpg.rf.0e69e834a4f717a5be4ec39134fc926a.jpg
#  extracting: train/cowpox/CWP_25_01_9_jpg.rf.f7ac5b3ebcb4f5ca1df6aa4fb3cfff51.jpg
#  extracting: train/cowpox/CWP_25_01_jpg.rf.ac65d522b33d7d8bdbcefa3bd7719e83.jpg
#  extracting: train/cowpox/CWP_26_01_10_jpg.rf.33ba57c7d6a219c50663ebfd61541b1c.jpg
#  extracting: train/cowpox/CWP_26_01_11_jpg.rf.5a3b57fb6aa7db3a67a28a4eceac79ec.jpg
#  extracting: train/cowpox/CWP_26_01_12_jpg.rf.73ccc6923ec3254fc18227c5cf600a24.jpg
#  extracting: train/cowpox/CWP_26_01_13_jpg.rf.3b9d75cf75cf5fbe34b8785c98b19d48.jpg
#  extracting: train/cowpox/CWP_26_01_2_jpg.rf.65a13432af40e4b2f293eceb5f8a1659.jpg
#  extracting: train/cowpox/CWP_26_01_4_jpg.rf.06a31238309ab32ed6789c352594cca8.jpg
#  extracting: train/cowpox/CWP_26_01_5_jpg.rf.b0197b312bf9df2ed35d0cd5b14f6166.jpg
#  extracting: train/cowpox/CWP_26_01_6_jpg.rf.386a2cdc5aadb2b6e11757f27f51e407.jpg
#  extracting: train/cowpox/CWP_26_01_7_jpg.rf.392fbea5a3fc926b7723a5fb74fbe05a.jpg
#  extracting: train/cowpox/CWP_26_01_9_jpg.rf.80e020bb8d03bc2711191d30da3c49af.jpg
#  extracting: train/cowpox/CWP_26_01_jpg.rf.1b3c6a65b8e1954492e94a7034b885c5.jpg
#  extracting: train/cowpox/CWP_27_01_10_jpg.rf.76d43f2671403f9290b835334e095889.jpg
#  extracting: train/cowpox/CWP_27_01_11_jpg.rf.173913ff5a4083610137d1211f4d3eae.jpg
#  extracting: train/cowpox/CWP_27_01_12_jpg.rf.315c5ef16b9a127634f6a96cbd1e78d5.jpg
#  extracting: train/cowpox/CWP_27_01_13_jpg.rf.1b241cc83fcaf272a5c8b43a03dc59cb.jpg
#  extracting: train/cowpox/CWP_27_01_1_jpg.rf.3a4dc5feebcad48975158de411949899.jpg
#  extracting: train/cowpox/CWP_27_01_2_jpg.rf.998ed9d0a04d5ef030e04e2560e3dfbb.jpg
#  extracting: train/cowpox/CWP_27_01_3_jpg.rf.b63cfe5be4a3c30386322bbe846dbecf.jpg
#  extracting: train/cowpox/CWP_27_01_4_jpg.rf.a7b4bc56dd0343f35058ac57a129bd91.jpg
#  extracting: train/cowpox/CWP_27_01_7_jpg.rf.f53449d670181d463e6341ad71c38b85.jpg
#  extracting: train/cowpox/CWP_27_01_9_jpg.rf.0ab5bc7dc312c7877968bd3d823fe5b6.jpg
#  extracting: train/cowpox/CWP_28_01_10_jpg.rf.ed645cf54140b9eee3aa92dfedf55a71.jpg
#  extracting: train/cowpox/CWP_28_01_11_jpg.rf.864d033112c5c7eb030a2ccab72f9601.jpg
#  extracting: train/cowpox/CWP_28_01_12_jpg.rf.b832f66f065bf4b00299dd18ff03bef1.jpg
#  extracting: train/cowpox/CWP_28_01_13_jpg.rf.e78ee056c4e6ebe318b0987f64471946.jpg
#  extracting: train/cowpox/CWP_28_01_1_jpg.rf.a232e4c179011de12d43f71795cb3a78.jpg
#  extracting: train/cowpox/CWP_28_01_2_jpg.rf.f03c8e628327b60dbe1f7750ba5f20a8.jpg
#  extracting: train/cowpox/CWP_28_01_4_jpg.rf.b0708af5707a37267fd122d23d2dfed7.jpg
#  extracting: train/cowpox/CWP_28_01_6_jpg.rf.919274251655bd599429ea1d1cc546af.jpg
#  extracting: train/cowpox/CWP_28_01_8_jpg.rf.e5f79b5aaf16968bcc0632b0502a1032.jpg
#  extracting: train/cowpox/CWP_28_01_9_jpg.rf.01e8ff2301fd3fd41ebb7835d07dd1ee.jpg
#  extracting: train/cowpox/CWP_28_02_11_jpg.rf.58751044f59ba7155fa26727cfff2cfd.jpg
#  extracting: train/cowpox/CWP_28_02_12_jpg.rf.d930c44b4e2ccd98a0b0e140660fd858.jpg
#  extracting: train/cowpox/CWP_28_02_13_jpg.rf.11cea331c4ed0bfbc5299e413a46605a.jpg
#  extracting: train/cowpox/CWP_28_02_1_jpg.rf.ce94f400f96e991a9d5816234635c517.jpg
#  extracting: train/cowpox/CWP_28_02_2_jpg.rf.cdeb43c2a5f2e0a1b4758395a0a18bd8.jpg
#  extracting: train/cowpox/CWP_28_02_3_jpg.rf.27aa316f407202b1ba9e1fbdcf41377a.jpg
#  extracting: train/cowpox/CWP_28_02_4_jpg.rf.e6aecd56fd3eb6b206f346b454ff3967.jpg
#  extracting: train/cowpox/CWP_28_02_5_jpg.rf.4659b3d4d1c83d06662d95d1216a80b5.jpg
#  extracting: train/cowpox/CWP_28_02_6_jpg.rf.52e7f81af8ca742b19877354432e8cd2.jpg
#  extracting: train/cowpox/CWP_28_02_7_jpg.rf.e256e95182b1065d40cf257a78625a0b.jpg
#  extracting: train/cowpox/CWP_28_02_8_jpg.rf.54b14d71504e51c10bedb4e120206f50.jpg
#  extracting: train/cowpox/CWP_28_02_9_jpg.rf.6a20fd6203cbdede70480697cb028ff9.jpg
#  extracting: train/cowpox/CWP_28_02_jpg.rf.a9a3e186eabe288b86ae36ed57479108.jpg
#  extracting: train/cowpox/CWP_29_01_10_jpg.rf.19e777aa61d2eb2b4331adcb64f5a4fa.jpg
#  extracting: train/cowpox/CWP_29_01_11_jpg.rf.8a6d89101aa12ca4a29c3a8a18e81c90.jpg
#  extracting: train/cowpox/CWP_29_01_12_jpg.rf.296828ae0b392e021c76c9aea9c30c33.jpg
#  extracting: train/cowpox/CWP_29_01_13_jpg.rf.9a88e4e58458153fa0f09c4a3dc2358e.jpg
#  extracting: train/cowpox/CWP_29_01_2_jpg.rf.395ac41e249370bdd4db6917bd8ce4cd.jpg
#  extracting: train/cowpox/CWP_29_01_3_jpg.rf.7e573610506198f11c6817565b55179f.jpg
#  extracting: train/cowpox/CWP_29_01_4_jpg.rf.48f262f7b44eec213bae5deb4acda3c2.jpg
#  extracting: train/cowpox/CWP_29_01_5_jpg.rf.63cd08813b02f82c09e37e0c726c0b27.jpg
#  extracting: train/cowpox/CWP_29_01_6_jpg.rf.c1f708ce2ac16ecca63c0dd11337a14a.jpg
#  extracting: train/cowpox/CWP_29_01_7_jpg.rf.e123d8fd1e78e618ba2411d04089144d.jpg
#  extracting: train/cowpox/CWP_29_01_8_jpg.rf.f8907687d95c091467dbbf194c063756.jpg
#  extracting: train/cowpox/CWP_29_01_9_jpg.rf.583767d08827159d5881269df1592398.jpg
#  extracting: train/cowpox/CWP_29_01_jpg.rf.763b8cd54660433c468cc398f55c0ec5.jpg
#  extracting: train/cowpox/CWP_29_02_10_jpg.rf.169d91368a219d0447d2988f1fab1d09.jpg
#  extracting: train/cowpox/CWP_29_02_11_jpg.rf.688b880921c5c9e1d3616bf91a777600.jpg
#  extracting: train/cowpox/CWP_29_02_12_jpg.rf.854464eb95013871d318ed2f99ad6eba.jpg
#  extracting: train/cowpox/CWP_29_02_13_jpg.rf.aee1e79c08a6ea60dcb5a2604fad297d.jpg
#  extracting: train/cowpox/CWP_29_02_1_jpg.rf.bef9b8d3d8a796787a53a72af861d3ce.jpg
#  extracting: train/cowpox/CWP_29_02_2_jpg.rf.220afb014d824cd25d8dc0805451d2d5.jpg
#  extracting: train/cowpox/CWP_29_02_4_jpg.rf.e2b9928b16c80dd288ba02c03ed3530d.jpg
#  extracting: train/cowpox/CWP_29_02_5_jpg.rf.7859ed04d7053306d63c2054fa4cd481.jpg
#  extracting: train/cowpox/CWP_29_02_6_jpg.rf.7a853b50b22d25b1a1dd244cb89077b8.jpg
#  extracting: train/cowpox/CWP_29_02_jpg.rf.68627d8e796792076b6e30df3c8d63fa.jpg
#  extracting: train/cowpox/CWP_30_01_10_jpg.rf.87190dea751601935523c0bb9ea0d1ca.jpg
#  extracting: train/cowpox/CWP_30_01_11_jpg.rf.4cae84e3ebecb044de8a1ad1c71280df.jpg
#  extracting: train/cowpox/CWP_30_01_12_jpg.rf.ad9d6dba67d5930402bf3b2cc430fa90.jpg
#  extracting: train/cowpox/CWP_30_01_1_jpg.rf.8ab3cb0afd65aace25b4a53478a700d7.jpg
#  extracting: train/cowpox/CWP_30_01_2_jpg.rf.3b593c9d0c1b5db7daa4b9723fcc7dba.jpg
#  extracting: train/cowpox/CWP_30_01_3_jpg.rf.08bc1005718ab222205a6d7e9fdf1157.jpg
#  extracting: train/cowpox/CWP_30_01_4_jpg.rf.bad8c209f9111fba70e090f38b8713bf.jpg
#  extracting: train/cowpox/CWP_30_01_5_jpg.rf.adb6efa108a08fcbf9783f917fa4ad23.jpg
#  extracting: train/cowpox/CWP_30_01_6_jpg.rf.7b866c342957f082b1f7bac126d568e2.jpg
#  extracting: train/cowpox/CWP_30_01_7_jpg.rf.49d34769c5346ac888036fa33ed609fa.jpg
#  extracting: train/cowpox/CWP_30_01_8_jpg.rf.cf28c46b4f72bee44ee207467938f309.jpg
#  extracting: train/cowpox/CWP_30_01_9_jpg.rf.e3b01d07a828ff117e9a2b91916bf232.jpg
#  extracting: train/cowpox/CWP_30_01_ORIGINAL_jpg.rf.49f472f32895731baee54d80c9b874dd.jpg
#  extracting: train/cowpox/CWP_31_01_10_jpg.rf.666317303d52b286881e062799fdba4d.jpg
#  extracting: train/cowpox/CWP_31_01_1_jpg.rf.f9fd55bd99f12efd30b345226654ed1a.jpg
#  extracting: train/cowpox/CWP_31_01_2_jpg.rf.46fb396f7f8fbb8818713e075553df0a.jpg
#  extracting: train/cowpox/CWP_31_01_3_jpg.rf.6dafae65c0eee23345d246dec1274280.jpg
#  extracting: train/cowpox/CWP_31_01_4_jpg.rf.86a6c4a0519388f2b32471312907bf94.jpg
#  extracting: train/cowpox/CWP_31_01_5_jpg.rf.c0623dd1ce742ccdb0d00078ddeb3885.jpg
#  extracting: train/cowpox/CWP_31_01_6_jpg.rf.fad197fe7b20003c572a8f4539e79ecb.jpg
#  extracting: train/cowpox/CWP_31_01_7_jpg.rf.36ae15a79d2986c218a106af8e58dee8.jpg
#  extracting: train/cowpox/CWP_31_01_8_jpg.rf.70d58d3843af5a7fe3a25f7ebcd42b6d.jpg
#  extracting: train/cowpox/CWP_31_01_9_jpg.rf.03cfaf5e7b82e11598c7a5dc7bbc4584.jpg
#  extracting: train/cowpox/CWP_31_01_jpg.rf.fecc31b91e131ea3b4c877d15c59d944.jpg
#  extracting: train/cowpox/CWP_32_01_10_jpg.rf.ed1c4bfc35c4ccf78a7f61cac4adbf90.jpg
#  extracting: train/cowpox/CWP_32_01_12_jpg.rf.8c2cbd6fb4ef7ee3c6bc20b65a21eceb.jpg
#  extracting: train/cowpox/CWP_32_01_13_jpg.rf.ee458eb20a8f665cb54441833cf87bcb.jpg
#  extracting: train/cowpox/CWP_32_01_1_jpg.rf.a59472818f5d5b2247eec1a5416c1caa.jpg
#  extracting: train/cowpox/CWP_32_01_3_jpg.rf.6f33aaeb89a2be9b331722458a772c5f.jpg
#  extracting: train/cowpox/CWP_32_01_4_jpg.rf.2067f9d4f25d6794f617c501bbccc807.jpg
#  extracting: train/cowpox/CWP_32_01_5_jpg.rf.6607819d0588dbae78f26ab849581d97.jpg
#  extracting: train/cowpox/CWP_32_01_7_jpg.rf.09ed5b1bb67f0be8c5af5b167ebbb529.jpg
#  extracting: train/cowpox/CWP_32_01_8_jpg.rf.3a60b98ae274512fcc22d826ffb84e26.jpg
#  extracting: train/cowpox/CWP_32_01_9_jpg.rf.f886240f56526eb9fc7471686f3bb8c7.jpg
#  extracting: train/cowpox/CWP_32_01_jpg.rf.dfb6c0853261bb02d1366e727138cdd6.jpg
#  extracting: train/cowpox/CWP_33_01_10_jpg.rf.ce6a8afdf51e634a335e8571c9cea7dc.jpg
#  extracting: train/cowpox/CWP_33_01_12_jpg.rf.77c6b6eb63a52382aa5fc061f94e4db4.jpg
#  extracting: train/cowpox/CWP_33_01_13_jpg.rf.a2b697b2b73b92e1e88765291e470e59.jpg
#  extracting: train/cowpox/CWP_33_01_1_jpg.rf.164304fac7474e80da16d02e3bc8d3d5.jpg
#  extracting: train/cowpox/CWP_33_01_2_jpg.rf.db4a8df10596fc34bd31eab28bcbd557.jpg
#  extracting: train/cowpox/CWP_33_01_3_jpg.rf.d4c57d11a9c620ef2c0c8c6f185dec71.jpg
#  extracting: train/cowpox/CWP_33_01_4_jpg.rf.184971130ae35362b9973385786bbdcd.jpg
#  extracting: train/cowpox/CWP_33_01_5_jpg.rf.d5f3fb9f8ca35a8fb6bc8920bce998f5.jpg
#  extracting: train/cowpox/CWP_33_01_6_jpg.rf.ed894f27f9bcda48f23cc15da8de06ac.jpg
#  extracting: train/cowpox/CWP_33_01_8_jpg.rf.d61e9f186cf36781bf275dc794f6a4df.jpg
#  extracting: train/cowpox/CWP_33_02_10_jpg.rf.f41dd89a7d0ed2527d4fcaca9ddb6cf7.jpg
#  extracting: train/cowpox/CWP_33_02_11_jpg.rf.281fd36e7865f94b27ac86fb1fe1c1a3.jpg
#  extracting: train/cowpox/CWP_33_02_13_jpg.rf.18f29637a52b89f9bc66128f6d3cabe4.jpg
#  extracting: train/cowpox/CWP_33_02_1_jpg.rf.c2dc88f721281e3b453aa324b4b5006b.jpg
#  extracting: train/cowpox/CWP_33_02_2_jpg.rf.c8c95a261cbf4e4b0685e1133709b552.jpg
#  extracting: train/cowpox/CWP_33_02_3_jpg.rf.8f9dc54123a49e85beb8e1258c7c2be6.jpg
#  extracting: train/cowpox/CWP_33_02_4_jpg.rf.c6bebb5af90e986db9bde6ff74f9cc94.jpg
#  extracting: train/cowpox/CWP_33_02_5_jpg.rf.2acf88ce550eac9424ab151802365138.jpg
#  extracting: train/cowpox/CWP_33_02_6_jpg.rf.febcf4dd3734222a80c47751290858cf.jpg
#  extracting: train/cowpox/CWP_33_02_7_jpg.rf.6da14176cf0943392fb224e6cb4d3136.jpg
#  extracting: train/cowpox/CWP_33_02_8_jpg.rf.b47c5de99d87c6988140f470e7241108.jpg
#  extracting: train/cowpox/CWP_33_02_jpg.rf.b37ff6ff287b5959810e193092bdeac1.jpg
#  extracting: train/cowpox/CWP_33_03_10_jpg.rf.91e7942b16df17c166d9cafec571212c.jpg
#  extracting: train/cowpox/CWP_33_03_11_jpg.rf.4ccb6ce5d1b29586405e2acc66c2fbb8.jpg
#  extracting: train/cowpox/CWP_33_03_13_jpg.rf.4064f26a9b180becfdb0d63f29fe9018.jpg
#  extracting: train/cowpox/CWP_33_03_2_jpg.rf.f985373c0baba0f8e87a1b55f690bf6e.jpg
#  extracting: train/cowpox/CWP_33_03_3_jpg.rf.a86f55c9d3258c69397db69ba62c27d6.jpg
#  extracting: train/cowpox/CWP_33_03_4_jpg.rf.c239d550a7ff2b6cdc0cb849b92196ff.jpg
#  extracting: train/cowpox/CWP_33_03_5_jpg.rf.d5063008601eae1b395758479b16fe04.jpg
#  extracting: train/cowpox/CWP_33_03_6_jpg.rf.490246e5dd4bea44067408b65ff852de.jpg
#  extracting: train/cowpox/CWP_33_03_7_jpg.rf.398a5422f3f289fa0adbfdd3d0e905de.jpg
#  extracting: train/cowpox/CWP_33_03_8_jpg.rf.b836af4329226857e2fdce84a80adc75.jpg
#  extracting: train/cowpox/CWP_33_03_9_jpg.rf.bbd1e8e7139f8894358192480fbeef49.jpg
#  extracting: train/cowpox/CWP_33_04_10_jpg.rf.263cb5fe2810f9263b8be45404058b00.jpg
#  extracting: train/cowpox/CWP_33_04_11_jpg.rf.f748ba43a12a406da969cdb21232c8f1.jpg
#  extracting: train/cowpox/CWP_33_04_12_jpg.rf.1aa85d2d8bcf5f370629f67b98dd4d44.jpg
#  extracting: train/cowpox/CWP_33_04_1_jpg.rf.aa111fd514f9082ecbb1ac85749c9843.jpg
#  extracting: train/cowpox/CWP_33_04_2_jpg.rf.fd8649d011041a54dad0408435c0fc72.jpg
#  extracting: train/cowpox/CWP_33_04_3_jpg.rf.924290c89c9648acd11d2bbca2ae4db9.jpg
#  extracting: train/cowpox/CWP_33_04_4_jpg.rf.72dc4936b6823f64c8c0c31963ebd7cf.jpg
#  extracting: train/cowpox/CWP_33_04_5_jpg.rf.ec5cdbf077d4757458d6dd1d6662d5dc.jpg
#  extracting: train/cowpox/CWP_33_04_7_jpg.rf.2ab7a1e61fed4c0c3eb07d7e807038ef.jpg
#  extracting: train/cowpox/CWP_33_04_9_jpg.rf.2e6ef34d068067523f2cf85ced099c21.jpg
#  extracting: train/cowpox/CWP_33_04_ORIGINAL_jpg.rf.62dba95abe3216564e1e18e44139ffbd.jpg
#  extracting: train/cowpox/CWP_33_04_jpg.rf.8b19eef8b4f54a8181058e69886b6001.jpg
#  extracting: train/cowpox/CWP_33_05_10_jpg.rf.37372b09935669b14e03fe921c67374e.jpg
#  extracting: train/cowpox/CWP_33_05_11_jpg.rf.93c2b185761096b6594e1e26ef75b646.jpg
#  extracting: train/cowpox/CWP_33_05_12_jpg.rf.aecdd85da182da8f7d538bedca1fd346.jpg
#  extracting: train/cowpox/CWP_33_05_13_jpg.rf.9516d11d181c9b4ad5cdab2bf07b1b61.jpg
#  extracting: train/cowpox/CWP_33_05_1_jpg.rf.c870b50b262b33e70091a8f4f6d76abc.jpg
#  extracting: train/cowpox/CWP_33_05_2_jpg.rf.fe8a35a7b2859c59cccaad4abb0933b3.jpg
#  extracting: train/cowpox/CWP_33_05_3_jpg.rf.a9057358d5aafd6f7303420d61fef3b6.jpg
#  extracting: train/cowpox/CWP_33_05_4_jpg.rf.ced52cfacec9dd1366d80f373438f12b.jpg
#  extracting: train/cowpox/CWP_33_05_5_jpg.rf.15d1aa35cc44f7b0bc0840c3dff1fb5e.jpg
#  extracting: train/cowpox/CWP_33_05_6_jpg.rf.67de8a490ae76f8e12363d4c88beb9bf.jpg
#  extracting: train/cowpox/CWP_33_05_7_jpg.rf.45645232d97c2f1b314919f0ddf66932.jpg
#  extracting: train/cowpox/CWP_33_05_9_jpg.rf.0a5ed5ab349a1ad85a2b90c81827149f.jpg
#  extracting: train/cowpox/CWP_33_06_11_jpg.rf.805c353e5422711b66cff4c6edc1db54.jpg
#  extracting: train/cowpox/CWP_33_06_12_jpg.rf.3563d0a0d24d9ed36358c90bd9bc7d7a.jpg
#  extracting: train/cowpox/CWP_33_06_13_jpg.rf.a97fe2a16a2966eb23494fea3e9a29b6.jpg
#  extracting: train/cowpox/CWP_33_06_1_jpg.rf.2ee95141b696bd877b7d91b62f41e694.jpg
#  extracting: train/cowpox/CWP_33_06_2_jpg.rf.85880c74d8e26e83ef3132ed05b36432.jpg
#  extracting: train/cowpox/CWP_33_06_3_jpg.rf.6b82cbe76a21431fdfb5644b77e6ef0a.jpg
#  extracting: train/cowpox/CWP_33_06_4_jpg.rf.fd09150f559099d84751fb7515430a8d.jpg
#  extracting: train/cowpox/CWP_33_06_5_jpg.rf.1fef1b1d682b23cd3497591939ab277f.jpg
#  extracting: train/cowpox/CWP_33_06_6_jpg.rf.a1300b5f0cae991b36a9e6dab9fb1d42.jpg
#  extracting: train/cowpox/CWP_33_06_7_jpg.rf.2eb7d54032c6ea11c64cc9bb68f6c06c.jpg
#  extracting: train/cowpox/CWP_33_06_8_jpg.rf.781213a9a885ba7bb45b807406158c1b.jpg
#  extracting: train/cowpox/CWP_33_06_9_jpg.rf.e0a5f7a74f419e84339ae00472afccb3.jpg
#  extracting: train/cowpox/CWP_33_06_jpg.rf.74eb5884801edc2ccca4b8e2cb1a0df9.jpg
#  extracting: train/cowpox/CWP_33_07_10_jpg.rf.d86a2b7baef0ff50738101a35ede2405.jpg
#  extracting: train/cowpox/CWP_33_07_11_jpg.rf.fe547091a30f027e27578b11089d9e39.jpg
#  extracting: train/cowpox/CWP_33_07_13_jpg.rf.c6f1a6ec843323d65494cc9b6f8da39a.jpg
#  extracting: train/cowpox/CWP_33_07_1_jpg.rf.6b536a2c5ef1b96c70a8843fefda9063.jpg
#  extracting: train/cowpox/CWP_33_07_2_jpg.rf.5e13e65bc59e2aba8dbad70aeb71f7cc.jpg
#  extracting: train/cowpox/CWP_33_07_3_jpg.rf.48f9bca9a23f530b890d0aea20996ab8.jpg
#  extracting: train/cowpox/CWP_33_07_4_jpg.rf.cd889ff056c23d1c22f53f03818be478.jpg
#  extracting: train/cowpox/CWP_33_07_5_jpg.rf.792d0a8f03fd0f73ee56d03da39377aa.jpg
#  extracting: train/cowpox/CWP_33_07_6_jpg.rf.86f7b04beefda264669cfa456f42fec8.jpg
#  extracting: train/cowpox/CWP_33_07_8_jpg.rf.2d6d8f1abbbc3003a6d869dc6d16b213.jpg
#  extracting: train/cowpox/CWP_33_07_jpg.rf.b8bf64f9eef48b4256592bd1e0f44999.jpg
#  extracting: train/cowpox/CWP_34_01_11_jpg.rf.ec6739b9ed3aec2d4f925a3f86d4eaf7.jpg
#  extracting: train/cowpox/CWP_34_01_12_jpg.rf.94264a60a358fd58a2bac570da23884d.jpg
#  extracting: train/cowpox/CWP_34_01_13_jpg.rf.de4c528d39a93e374baeab4b6b36f5cc.jpg
#  extracting: train/cowpox/CWP_34_01_1_jpg.rf.614423192c2f36af3782854a5e701001.jpg
#  extracting: train/cowpox/CWP_34_01_2_jpg.rf.16a0911944c71f4647710b0cd3282ce9.jpg
#  extracting: train/cowpox/CWP_34_01_3_jpg.rf.6195f030ed11a99244a7ca485a8c6739.jpg
#  extracting: train/cowpox/CWP_34_01_4_jpg.rf.2e948ce5f25db22839129ee4f27b6b36.jpg
#  extracting: train/cowpox/CWP_34_01_5_jpg.rf.d45895f907e80a41c46e4af7b240fce8.jpg
#  extracting: train/cowpox/CWP_34_01_6_jpg.rf.d775edb14505401b5a824749fc4d6fca.jpg
#  extracting: train/cowpox/CWP_34_01_8_jpg.rf.052ca633ce2f65481b6ba1e9a37fb0cb.jpg
#  extracting: train/cowpox/CWP_34_01_jpg.rf.8c933105ac93c281001a61655130f425.jpg
#  extracting: train/cowpox/CWP_35_01_10_jpg.rf.d505b5cbecc7e47b87a0bd2da7a9ac9a.jpg
#  extracting: train/cowpox/CWP_35_01_12_jpg.rf.92e3c1a245d0ceb74d21bff40e0ae1b6.jpg
#  extracting: train/cowpox/CWP_35_01_13_jpg.rf.8061e87bcfef0d62f6fa32a6b63b321d.jpg
#  extracting: train/cowpox/CWP_35_01_1_jpg.rf.29ccf3d18ebc888b475e5ed3ae2be493.jpg
#  extracting: train/cowpox/CWP_35_01_2_jpg.rf.0fd520ccf821601e1b496455831e6d5e.jpg
#  extracting: train/cowpox/CWP_35_01_3_jpg.rf.62dfcd3f9b53ab52c887c1d6897b9cf3.jpg
#  extracting: train/cowpox/CWP_35_01_4_jpg.rf.fd6c898c5882c61fcac176f9b82d53fe.jpg
#  extracting: train/cowpox/CWP_35_01_6_jpg.rf.888d3149b894fd3e02c0a7bbfcbe2b88.jpg
#  extracting: train/cowpox/CWP_35_01_7_jpg.rf.fdd4e28cadca2be861cb231529ef5abd.jpg
#  extracting: train/cowpox/CWP_35_01_8_jpg.rf.db4b629c333098c20b399dc931ef3bfe.jpg
#  extracting: train/cowpox/CWP_35_01_9_jpg.rf.3e0b13e05d666da1b45100eb0bd33f83.jpg
#  extracting: train/cowpox/CWP_35_01_jpg.rf.e5d827fe00c0c12cb9e616adb863990d.jpg
#  extracting: train/cowpox/CWP_36_01_10_jpg.rf.f8ca67a127b538e64f95d97d1b3b70a5.jpg
#  extracting: train/cowpox/CWP_36_01_11_jpg.rf.d95790621bd3443a2291bced59ed1d51.jpg
#  extracting: train/cowpox/CWP_36_01_12_jpg.rf.f915ef40a7e5954ca22052aac38350cc.jpg
#  extracting: train/cowpox/CWP_36_01_13_jpg.rf.b118505d9a0f1f29eb472bde149e533c.jpg
#  extracting: train/cowpox/CWP_36_01_1_jpg.rf.ead7e258a8aef2f217eeb2bba7f18eca.jpg
#  extracting: train/cowpox/CWP_36_01_2_jpg.rf.d13fb68a299ab5b3e2bb0b3eff2a5b82.jpg
#  extracting: train/cowpox/CWP_36_01_3_jpg.rf.cb385930c7c94e6473047cb445b38828.jpg
#  extracting: train/cowpox/CWP_36_01_4_jpg.rf.24219eac5bf877d1a2c0ff5d13ac550b.jpg
#  extracting: train/cowpox/CWP_36_01_5_jpg.rf.b11f8f41b8c47b4907c8526d34d30168.jpg
#  extracting: train/cowpox/CWP_36_01_6_jpg.rf.2e6274979895ae9798edb18c11d405d5.jpg
#  extracting: train/cowpox/CWP_36_01_7_jpg.rf.3187440b59e4ee9b31e4e1bc0e787cab.jpg
#  extracting: train/cowpox/CWP_36_01_9_jpg.rf.04a0c0bf16d48f6eb8a62af830c488d9.jpg
#  extracting: train/cowpox/CWP_36_01_jpg.rf.2d356442f7e198b1a79bc2f8c4017a9e.jpg
#  extracting: train/cowpox/CWP_37_01_10_jpg.rf.af1b3f2fa326f59464cfea3c93a59687.jpg
#  extracting: train/cowpox/CWP_37_01_12_jpg.rf.92fc388439cb35afa35bd244748ce975.jpg
#  extracting: train/cowpox/CWP_37_01_13_jpg.rf.99f56131c89d71a3474c7819f902fabe.jpg
#  extracting: train/cowpox/CWP_37_01_2_jpg.rf.bb379e149ad9876aced696cf8dff59c7.jpg
#  extracting: train/cowpox/CWP_37_01_3_jpg.rf.a7a4fc2ef12a0fb4cd7a16e5e86a2f85.jpg
#  extracting: train/cowpox/CWP_37_01_4_jpg.rf.bbc0d4e2aa611bc9fbfda1afdd56b492.jpg
#  extracting: train/cowpox/CWP_37_01_5_jpg.rf.a74d0252c57ba897a1d066f35f32a4ae.jpg
#  extracting: train/cowpox/CWP_37_01_7_jpg.rf.e8ac3fc816244a3fe6204e5c366806f8.jpg
#  extracting: train/cowpox/CWP_37_01_8_jpg.rf.aecde9426e2b455db46c370af3f1e933.jpg
#  extracting: train/cowpox/CWP_37_01_9_jpg.rf.8fa67357e32a28fc4db52eb42ea24735.jpg
#  extracting: train/cowpox/CWP_37_01_jpg.rf.9b1dbdc1a58fc590497a48cf99e08706.jpg
#  extracting: train/cowpox/CWP_37_02_11_jpg.rf.36b0be83b455bdd491ffc77b89bf3e69.jpg
#  extracting: train/cowpox/CWP_37_02_12_jpg.rf.865aed1f80187c4f8366cf92eecc5dc6.jpg
#  extracting: train/cowpox/CWP_37_02_13_jpg.rf.12b835c3fa490059fde4f76455030c23.jpg
#  extracting: train/cowpox/CWP_37_02_1_jpg.rf.1257e6591ff43acd4331693ca239677b.jpg
#  extracting: train/cowpox/CWP_37_02_2_jpg.rf.59cf502115354ef71fc596b5a89270c9.jpg
#  extracting: train/cowpox/CWP_37_02_3_jpg.rf.0f63de164392988d202d662bb4421cf3.jpg
#  extracting: train/cowpox/CWP_37_02_4_jpg.rf.41d91c2649cc5e6c12f9fe45d7ea5005.jpg
#  extracting: train/cowpox/CWP_37_02_5_jpg.rf.95ea06fafd4ee5c150cdf72469636646.jpg
#  extracting: train/cowpox/CWP_37_02_6_jpg.rf.d25cae879a14536d9e03071b99cde209.jpg
#  extracting: train/cowpox/CWP_37_02_7_jpg.rf.f9a72266036dd8d1b0440b49b927be61.jpg
#  extracting: train/cowpox/CWP_37_02_8_jpg.rf.4b7207cba3b72b8f64aa19b9a8dc4a85.jpg
#  extracting: train/cowpox/CWP_37_02_9_jpg.rf.3b21cc0bc15b8c83f21fdf9e59794dfd.jpg
#  extracting: train/cowpox/CWP_37_02_jpg.rf.bb62c4fdb49276648a7f8be30d560cf3.jpg
#  extracting: train/cowpox/CWP_37_03_10_jpg.rf.40332b143eab5c731c8160866f8ad09d.jpg
#  extracting: train/cowpox/CWP_37_03_12_jpg.rf.98b67dfcd45237843633fc437092b448.jpg
#  extracting: train/cowpox/CWP_37_03_13_jpg.rf.5d0437a8f0efb0c9c59d54d341fab823.jpg
#  extracting: train/cowpox/CWP_37_03_1_jpg.rf.424f218f0495411df29623d085d4be32.jpg
#  extracting: train/cowpox/CWP_37_03_2_jpg.rf.f1dfbbf48b2fa0088d371d07c9742ef6.jpg
#  extracting: train/cowpox/CWP_37_03_3_jpg.rf.93a9abd4606b3ee175cd2be4f9ce5eb0.jpg
#  extracting: train/cowpox/CWP_37_03_4_jpg.rf.b19caceb09604b2abe0a716a7b6c78d5.jpg
#  extracting: train/cowpox/CWP_37_03_5_jpg.rf.0ba5db39a1dd06ac897cb40d8502acdb.jpg
#  extracting: train/cowpox/CWP_37_03_6_jpg.rf.8c7ec710f993348ed37e8fa248d7ab0e.jpg
#  extracting: train/cowpox/CWP_37_03_7_jpg.rf.75748e127a097255de158caebc9032fc.jpg
#  extracting: train/cowpox/CWP_37_03_8_jpg.rf.fa8acbf250e3b0b2c55150feb19211a0.jpg
#  extracting: train/cowpox/CWP_37_03_9_jpg.rf.809ebc01a5a145aaf44490bd581fb268.jpg
#  extracting: train/cowpox/CWP_37_04_10_jpg.rf.6c70bf690582ed223ac17a297cfb8653.jpg
#  extracting: train/cowpox/CWP_37_04_11_jpg.rf.23525e2df670352e691e831c0412020e.jpg
#  extracting: train/cowpox/CWP_37_04_12_jpg.rf.44deee8482e3156724be9456f2ef9bca.jpg
#  extracting: train/cowpox/CWP_37_04_1_jpg.rf.278271d79aadb2fb613fa7821036151e.jpg
#  extracting: train/cowpox/CWP_37_04_2_jpg.rf.4eeac95ea130c7299d6327bb32e0ab40.jpg
#  extracting: train/cowpox/CWP_37_04_3_jpg.rf.8b6e6c4f86eeae58f19191053da2cc83.jpg
#  extracting: train/cowpox/CWP_37_04_4_jpg.rf.1e764fa4be439695ba4575b74ef0de62.jpg
#  extracting: train/cowpox/CWP_37_04_6_jpg.rf.2a4efd13116510ecce3f16e22b9b6785.jpg
#  extracting: train/cowpox/CWP_37_04_7_jpg.rf.5147c038e32e281233b9502667286c3d.jpg
#  extracting: train/cowpox/CWP_37_04_8_jpg.rf.c29d3fc3bdc1e39b460949cde0d28dea.jpg
#  extracting: train/cowpox/CWP_37_04_ORIGINAL_jpg.rf.08ac37b2505fa789e38236bbf0c423ba.jpg
#  extracting: train/cowpox/CWP_37_04_jpg.rf.2a86bfce2dfc0fae335dcc613d2b66fe.jpg
#  extracting: train/cowpox/CWP_37_05_10_jpg.rf.818df2ca7ee53e7d7d37aaba87b17ae3.jpg
#  extracting: train/cowpox/CWP_37_05_11_jpg.rf.23a75cca3e7a4df58162a56acaaa4ff5.jpg
#  extracting: train/cowpox/CWP_37_05_12_jpg.rf.6444cf527d11eb860983dfb3a201f3b7.jpg
#  extracting: train/cowpox/CWP_37_05_13_jpg.rf.20b9933cd2fa64c9b57a5f1925c7decc.jpg
#  extracting: train/cowpox/CWP_37_05_1_jpg.rf.4900f8d4068325d0dddd70708a739a16.jpg
#  extracting: train/cowpox/CWP_37_05_2_jpg.rf.1a5472569b30b77efbb75d85697aee88.jpg
#  extracting: train/cowpox/CWP_37_05_3_jpg.rf.c2d776b450f7ee55e50df29f42195ac0.jpg
#  extracting: train/cowpox/CWP_37_05_5_jpg.rf.0e13d2561ac36bd37aef4bb494f0ddc2.jpg
#  extracting: train/cowpox/CWP_37_05_6_jpg.rf.03cebb1d2297b0371b88c8c464c78747.jpg
#  extracting: train/cowpox/CWP_37_05_9_jpg.rf.c3c5fa6e8b99a7beb6c5fdf30bae1396.jpg
#  extracting: train/cowpox/CWP_37_06_10_jpg.rf.503663f645d22c369577ffbed59f9f66.jpg
#  extracting: train/cowpox/CWP_37_06_11_jpg.rf.7367ab79e0259c1ffe2efed6b90cc707.jpg
#  extracting: train/cowpox/CWP_37_06_13_jpg.rf.c15f1d9d3de53edeacdefed1251f4f19.jpg
#  extracting: train/cowpox/CWP_37_06_1_jpg.rf.f4f79f67691bcb5b378e1e2bea19ec26.jpg
#  extracting: train/cowpox/CWP_37_06_2_jpg.rf.6185e63e30c80ac2f741271565970848.jpg
#  extracting: train/cowpox/CWP_37_06_3_jpg.rf.f1054b03c5e41e7df34a82d9f419e8b8.jpg
#  extracting: train/cowpox/CWP_37_06_4_jpg.rf.339a0ab4adeac5108e2388a8f319c766.jpg
#  extracting: train/cowpox/CWP_37_06_5_jpg.rf.e6e38df64c4dc3f9debef0d692e30551.jpg
#  extracting: train/cowpox/CWP_37_06_6_jpg.rf.6fa30880ce51bf58f6dd083f7222c099.jpg
#  extracting: train/cowpox/CWP_37_06_7_jpg.rf.329278ff01e128d10752a5990f05e20b.jpg
#  extracting: train/cowpox/CWP_37_06_8_jpg.rf.e25654e1bc6219026445b42bcb75309d.jpg
#  extracting: train/cowpox/CWP_37_06_9_jpg.rf.f8e09e22d611b3efabf3e1e5a207cb97.jpg
#  extracting: train/cowpox/CWP_37_06_jpg.rf.6da6a53c1bac9b334c016d4469103be1.jpg
#  extracting: train/cowpox/CWP_37_07_10_jpg.rf.4733d737eb4e8e96a546d008f3b27572.jpg
#  extracting: train/cowpox/CWP_37_07_11_jpg.rf.9241dbd782a3cdd7589d1dfe4af2c26d.jpg
#  extracting: train/cowpox/CWP_37_07_12_jpg.rf.194406737d2a7d0bfc8685585fc03edc.jpg
#  extracting: train/cowpox/CWP_37_07_1_jpg.rf.ae6fa28842fbf283209fa8039fd92d68.jpg
#  extracting: train/cowpox/CWP_37_07_2_jpg.rf.4ef90724733ab5d5bc32fd9dd9d027cf.jpg
#  extracting: train/cowpox/CWP_37_07_4_jpg.rf.d0055142f108394c0f884fdebf8e636f.jpg
#  extracting: train/cowpox/CWP_37_07_5_jpg.rf.27a17ee89285c51ca058de5fce0cee8b.jpg
#  extracting: train/cowpox/CWP_37_07_6_jpg.rf.acebedd0c6756562e2f2039fd7df570e.jpg
#  extracting: train/cowpox/CWP_37_07_8_jpg.rf.30df45598174089b83defc3893e87698.jpg
#  extracting: train/cowpox/CWP_37_07_9_jpg.rf.84963b8e640fe053362175cdc6af5159.jpg
#  extracting: train/cowpox/CWP_37_07_ORIGINAL_jpg.rf.c518e7187007682264fa951855967dfb.jpg
#  extracting: train/cowpox/CWP_37_07_jpg.rf.532ad6f4a343a2f618ef8dca878567ab.jpg
#  extracting: train/cowpox/CWP_37_08_10_jpg.rf.8815de6a15c55c06904e9874aaa33a85.jpg
#  extracting: train/cowpox/CWP_37_08_11_jpg.rf.2f3f810446395721083c500dff580e42.jpg
#  extracting: train/cowpox/CWP_37_08_12_jpg.rf.4db3c84bfd6b069a2add1fd5eeedb928.jpg
#  extracting: train/cowpox/CWP_37_08_13_jpg.rf.d30e9fe166a75d4750cb0982f73d447c.jpg
#  extracting: train/cowpox/CWP_37_08_1_jpg.rf.f9b34a118c374fec0d914d82ea639723.jpg
#  extracting: train/cowpox/CWP_37_08_2_jpg.rf.ca5ed6ad47e239d8b0d885d3d762d0ac.jpg
#  extracting: train/cowpox/CWP_37_08_5_jpg.rf.d274235f0a7bd006607ecfc206e689a4.jpg
#  extracting: train/cowpox/CWP_37_08_6_jpg.rf.28477c99bc5cc54f5addb66b32adc2c8.jpg
#  extracting: train/cowpox/CWP_37_08_7_jpg.rf.a518a082a54eaae7ed37633a8ed9fa14.jpg
#  extracting: train/cowpox/CWP_37_08_8_jpg.rf.c07bffb31baff7c218089153cc83bb6e.jpg
#  extracting: train/cowpox/CWP_37_08_jpg.rf.75e8d2c210306249a7140e636a0cc128.jpg
#  extracting: train/cowpox/CWP_37_09_10_jpg.rf.0ca9e904010987e6fc074832f2e45400.jpg
#  extracting: train/cowpox/CWP_37_09_11_jpg.rf.577554899f4ea68cfdf29829faebb92e.jpg
#  extracting: train/cowpox/CWP_37_09_12_jpg.rf.56ee66ef62c70d3ff59b6de4db40c0c7.jpg
#  extracting: train/cowpox/CWP_37_09_13_jpg.rf.086d40e0b698f45599ee762a1c9ec850.jpg
#  extracting: train/cowpox/CWP_37_09_1_jpg.rf.3c4682f4e43c721609c71bb8138ea624.jpg
#  extracting: train/cowpox/CWP_37_09_2_jpg.rf.6ed4f94ab93d96e06ed44f27490c9ced.jpg
#  extracting: train/cowpox/CWP_37_09_3_jpg.rf.b77d01b2dcee8eda8c57ad728979581e.jpg
#  extracting: train/cowpox/CWP_37_09_4_jpg.rf.c375dfac0e7d33a49fb144a46727d4f0.jpg
#  extracting: train/cowpox/CWP_37_09_5_jpg.rf.d4ae61b59db1ec9c93fa2971a346c1c4.jpg
#  extracting: train/cowpox/CWP_37_09_6_jpg.rf.602797bb8072e1ecf614e92b8815d14e.jpg
#  extracting: train/cowpox/CWP_37_09_7_jpg.rf.830ae3c4003a8345e425424c24fe0668.jpg
#  extracting: train/cowpox/CWP_37_09_8_jpg.rf.07ae592cb971dbf902815913422142d3.jpg
#  extracting: train/cowpox/CWP_37_09_9_jpg.rf.aefed7b78dc6bb2660aa3b9ae00f1962.jpg
#  extracting: train/cowpox/CWP_37_09_jpg.rf.fb608e940eb5b1c0abb7242fcf22c8fd.jpg
#  extracting: train/cowpox/CWP_38_01_10_jpg.rf.f8ec78a2bd4b31e78c697f6afd1e64f6.jpg
#  extracting: train/cowpox/CWP_38_01_11_jpg.rf.3d45e76e25d117a41c6e9528340908aa.jpg
#  extracting: train/cowpox/CWP_38_01_12_jpg.rf.5a5e5bcd522dd49a2cab6bb134c1f6e8.jpg
#  extracting: train/cowpox/CWP_38_01_13_jpg.rf.3051b088ff6ea4d6e635199d78e7f291.jpg
#  extracting: train/cowpox/CWP_38_01_1_jpg.rf.a33a87235ab4c461a914bd4b5add3e78.jpg
#  extracting: train/cowpox/CWP_38_01_3_jpg.rf.b9d11f7a7937b181fe219808b4074b1f.jpg
#  extracting: train/cowpox/CWP_38_01_4_jpg.rf.855d27fc8fddb1337b429f5c4db2afbc.jpg
#  extracting: train/cowpox/CWP_38_01_5_jpg.rf.99cd941e9947024fb6c138def2a4aaa7.jpg
#  extracting: train/cowpox/CWP_38_01_7_jpg.rf.209e35117541e8d246b35eff5578693a.jpg
#  extracting: train/cowpox/CWP_38_01_8_jpg.rf.b62efb3924535b0dbba98a45438b7308.jpg
#  extracting: train/cowpox/CWP_38_01_9_jpg.rf.e4b761ab8aecce3b0a26b7039ca9a458.jpg
#  extracting: train/cowpox/CWP_38_01_jpg.rf.58445f51cbaf3560d6262885ced3b30d.jpg
#  extracting: train/cowpox/CWP_38_02_10_jpg.rf.927dc0558e910de90c98c2880f6d70a1.jpg
#  extracting: train/cowpox/CWP_38_02_11_jpg.rf.15cb92bd021154319d9c3b389c7bb2ce.jpg
#  extracting: train/cowpox/CWP_38_02_12_jpg.rf.5d56dfecd7a37307bec83b61ac260ad6.jpg
#  extracting: train/cowpox/CWP_38_02_13_jpg.rf.7989a08cbf49429c5923a7144bb4da8c.jpg
#  extracting: train/cowpox/CWP_38_02_2_jpg.rf.87b52b2600c0f8a2f1eca7c9b5cc24e5.jpg
#  extracting: train/cowpox/CWP_38_02_3_jpg.rf.3bffcd8c1f65713bf9aea10254206f3a.jpg
#  extracting: train/cowpox/CWP_38_02_4_jpg.rf.500e8b32fedb02c33b21d9fc02e988a8.jpg
#  extracting: train/cowpox/CWP_38_02_6_jpg.rf.b4df79b74e13b141723be09f97f7b88e.jpg
#  extracting: train/cowpox/CWP_38_02_8_jpg.rf.272e9fc095a1c4f40714d779cf2de145.jpg
#  extracting: train/cowpox/CWP_38_02_9_jpg.rf.fe0acf6e15fde0c6982ebfa950db6af8.jpg
#  extracting: train/cowpox/CWP_38_02_jpg.rf.efee03d84839120efd74b0830e19f74b.jpg
#  extracting: train/cowpox/CWP_39_01_11_jpg.rf.d5d55e7c202fc6672a5ce0dab078cbc7.jpg
#  extracting: train/cowpox/CWP_39_01_12_jpg.rf.1bf1bf76bd71a4b4e6215ef8af774678.jpg
#  extracting: train/cowpox/CWP_39_01_13_jpg.rf.e12d0d60e940231f3439877d30bde005.jpg
#  extracting: train/cowpox/CWP_39_01_1_jpg.rf.472869c029f20640fbe5e4bcd25c08e1.jpg
#  extracting: train/cowpox/CWP_39_01_4_jpg.rf.df5641cb798fd79442df101a72db2565.jpg
#  extracting: train/cowpox/CWP_39_01_6_jpg.rf.bdd6ec431ef584372cf4bf579aae37fa.jpg
#  extracting: train/cowpox/CWP_39_01_7_jpg.rf.c338c195606085f8c848be12fe0d8f15.jpg
#  extracting: train/cowpox/CWP_39_01_8_jpg.rf.39237ee014511a4f1f1530ea36dee5ad.jpg
#  extracting: train/cowpox/CWP_39_01_9_jpg.rf.83538061962182b680c40a4f376bdd9a.jpg
#  extracting: train/cowpox/CWP_39_01_jpg.rf.3ed110ed339b93e8344a4385ae55019c.jpg
#  extracting: train/cowpox/CWP_40_01_10_jpg.rf.028f1d8c709a2e6028dede1a1ec884eb.jpg
#  extracting: train/cowpox/CWP_40_01_11_jpg.rf.27edc86f05835956d9134de7eb683993.jpg
#  extracting: train/cowpox/CWP_40_01_12_jpg.rf.b0e3c14c080355ede972b362f2b7d9a9.jpg
#  extracting: train/cowpox/CWP_40_01_13_jpg.rf.7710f6a1b7c5938bca038e48c0813966.jpg
#  extracting: train/cowpox/CWP_40_01_1_jpg.rf.3cdaf0fba776592bbdc43d30d98cd5cc.jpg
#  extracting: train/cowpox/CWP_40_01_2_jpg.rf.99a59ec40aaa0c942acef81acc0ec69e.jpg
#  extracting: train/cowpox/CWP_40_01_3_jpg.rf.2938fb3ea86b3bf45808b312ea2e8972.jpg
#  extracting: train/cowpox/CWP_40_01_4_jpg.rf.63d7191890c10550713392cb11eac188.jpg
#  extracting: train/cowpox/CWP_40_01_5_jpg.rf.2fab0f751a110267f6107edbd66002d7.jpg
#  extracting: train/cowpox/CWP_40_01_6_jpg.rf.5a5098aa95bb20d817a1b540eac0c0c5.jpg
#  extracting: train/cowpox/CWP_40_01_9_jpg.rf.81cc95a948656e37c0d16eee5e38f713.jpg
#  extracting: train/cowpox/CWP_40_01_jpg.rf.9df5af52d74b647ea927c6192d275048.jpg
#  extracting: train/cowpox/CWP_40_02_10_jpg.rf.3a84420944ddcc547132d19a6c8b6e7c.jpg
#  extracting: train/cowpox/CWP_40_02_11_jpg.rf.c055bfe4600354d3519d8ea6ef2d9cc8.jpg
#  extracting: train/cowpox/CWP_40_02_12_jpg.rf.ba67fc732c3aec55bb690de12fa66846.jpg
#  extracting: train/cowpox/CWP_40_02_2_jpg.rf.51c940ccf52ddb6fc6b376c465091bf6.jpg
#  extracting: train/cowpox/CWP_40_02_3_jpg.rf.b6909237e735f61e31b53ef691fb6b59.jpg
#  extracting: train/cowpox/CWP_40_02_4_jpg.rf.e9c2e447ef3cdecd3651e65e6a5bf26b.jpg
#  extracting: train/cowpox/CWP_40_02_5_jpg.rf.350c97488506688168676ca861d61444.jpg
#  extracting: train/cowpox/CWP_40_02_6_jpg.rf.ff1d64ab849d5df4f23282b4a124776e.jpg
#  extracting: train/cowpox/CWP_40_02_7_jpg.rf.495a9475f648ec97bab6be2482e3b9e2.jpg
#  extracting: train/cowpox/CWP_40_02_8_jpg.rf.a5ef1908f24362214a28237ba88c9634.jpg
#  extracting: train/cowpox/CWP_40_02_9_jpg.rf.6d39c93adebc2a620a86190c2b1d6936.jpg
#  extracting: train/cowpox/CWP_40_02_ORIGINAL_jpg.rf.cf663b46308b8835930986ffe93df57b.jpg
#  extracting: train/cowpox/CWP_40_02_jpg.rf.b76bceef02ea33d0fa207f93f258ef8d.jpg
#  extracting: train/cowpox/CWP_40_03_10_jpg.rf.fee365d75fe9845cfc66385f87f01f96.jpg
#  extracting: train/cowpox/CWP_40_03_12_jpg.rf.207015c8d714da963840e121aea2f30f.jpg
#  extracting: train/cowpox/CWP_40_03_13_jpg.rf.370c132ec359a67c3ff949a65525f222.jpg
#  extracting: train/cowpox/CWP_40_03_1_jpg.rf.ce889868fd95e4051d29ff6e6a826de0.jpg
#  extracting: train/cowpox/CWP_40_03_3_jpg.rf.7c42e1dea28699312eea23bf8d3dc412.jpg
#  extracting: train/cowpox/CWP_40_03_5_jpg.rf.9022af9e85869fb88536eb47457fad5d.jpg
#  extracting: train/cowpox/CWP_40_03_6_jpg.rf.380d063347beced6aec85c47671bfde0.jpg
#  extracting: train/cowpox/CWP_40_03_8_jpg.rf.75c0c2af66db2d3c03b0d4e77d4a4636.jpg
#  extracting: train/cowpox/CWP_40_03_9_jpg.rf.be6b7e9cb6b4c23d9d9839bd801eab37.jpg
#  extracting: train/cowpox/CWP_40_03_jpg.rf.97451d62b32873d183c9bc0acd59d38b.jpg
#  extracting: train/cowpox/CWP_40_04_10_jpg.rf.baeef336250da57ee389775cab550bbd.jpg
#  extracting: train/cowpox/CWP_40_04_11_jpg.rf.1d13df74e1ae32f303c6120feae5e443.jpg
#  extracting: train/cowpox/CWP_40_04_12_jpg.rf.5535079a3ab32df7e00a42068d22a8c3.jpg
#  extracting: train/cowpox/CWP_40_04_13_jpg.rf.f471c16f5aa634b950f2e1a0c4fcbfcd.jpg
#  extracting: train/cowpox/CWP_40_04_1_jpg.rf.11d0b408b5f7ffcfad13f4ead55eebc0.jpg
#  extracting: train/cowpox/CWP_40_04_2_jpg.rf.b1a83d3ba81aeefcd97cef7cd32a0dbd.jpg
#  extracting: train/cowpox/CWP_40_04_3_jpg.rf.99d218de3768fb78c4681ca37f0abd7a.jpg
#  extracting: train/cowpox/CWP_40_04_4_jpg.rf.1e3aa76df0a9da01d22c48b9dd81266c.jpg
#  extracting: train/cowpox/CWP_40_04_5_jpg.rf.f4a3c58aa1c33fd5db63521938383879.jpg
#  extracting: train/cowpox/CWP_40_04_6_jpg.rf.44c717f1d4a39104931b681846a9d4bb.jpg
#  extracting: train/cowpox/CWP_40_04_7_jpg.rf.9f702801280e3b5a5d387442137af274.jpg
#  extracting: train/cowpox/CWP_40_04_9_jpg.rf.e80334276b88d515301a343d59bf1119.jpg
#  extracting: train/cowpox/CWP_40_04_jpg.rf.5d6b74f8b101b517291963b3aaa0360b.jpg
#  extracting: train/cowpox/CWP_41_01_10_jpg.rf.1b127013b5e32e45604d93f2ea6730cd.jpg
#  extracting: train/cowpox/CWP_41_01_11_jpg.rf.62fc710089d7ab14d9b85d67b7767d0d.jpg
#  extracting: train/cowpox/CWP_41_01_12_jpg.rf.9dbecc3266ec467b363b04edfbd8c3b6.jpg
#  extracting: train/cowpox/CWP_41_01_13_jpg.rf.d585be902d0c28a0873a7b49ad6b75a4.jpg
#  extracting: train/cowpox/CWP_41_01_2_jpg.rf.8787dfda272f9d72481e91144e4839f4.jpg
#  extracting: train/cowpox/CWP_41_01_3_jpg.rf.f1643e7bb2fc75a5882fd540830b4ad3.jpg
#  extracting: train/cowpox/CWP_41_01_4_jpg.rf.6ccc62e06e71bdcead9f2834adc25647.jpg
#  extracting: train/cowpox/CWP_41_01_6_jpg.rf.07f4cb4125b1379bf753b454c002b898.jpg
#  extracting: train/cowpox/CWP_41_01_7_jpg.rf.5fa3f989c399fbe658c6744b3c0f5df1.jpg
#  extracting: train/cowpox/CWP_41_01_9_jpg.rf.3c13bf55180b1cffb753a5c79499a82a.jpg
#  extracting: train/cowpox/CWP_41_01_jpg.rf.29a889b6f19a40ed235d71e74a0e1037.jpg
#  extracting: train/cowpox/CWP_41_02_10_jpg.rf.fd8641d8b2d2262cdec51d3286863ae4.jpg
#  extracting: train/cowpox/CWP_41_02_11_jpg.rf.045f6442d5bc37bbb0d4f60fbe30bfa8.jpg
#  extracting: train/cowpox/CWP_41_02_13_jpg.rf.6139b97138f682e22979e3e004088cfa.jpg
#  extracting: train/cowpox/CWP_41_02_3_jpg.rf.d4bbec56ccd1791d891d992e7b29ddb3.jpg
#  extracting: train/cowpox/CWP_41_02_4_jpg.rf.70595d190c7b8acbaada46a5a0da34cc.jpg
#  extracting: train/cowpox/CWP_41_02_5_jpg.rf.8b5fd11b5d2cbc04a29b3db16963fe5a.jpg
#  extracting: train/cowpox/CWP_41_02_6_jpg.rf.ecba4a0228c947e7fc8f9142d73e78b7.jpg
#  extracting: train/cowpox/CWP_41_02_7_jpg.rf.c43ad25aa2798a627a5a4df371540446.jpg
#  extracting: train/cowpox/CWP_41_02_8_jpg.rf.d515cfb4abfef3c55913c411f66719cf.jpg
#  extracting: train/cowpox/CWP_41_02_9_jpg.rf.ae0feac5fd03974f103889986189367e.jpg
# ...
#  extracting: train/melanoma/ISIC_0071651_jpg.rf.c08aa2816522ada85b356f0cd7a80dd2.jpg
#  extracting: train/melanoma/ISIC_0071666_jpg.rf.e1e31ad96cee37271ab42baec6f85eb4.jpg
#  extracting: train/melanoma/ISIC_0071668_jpg.rf.48e073ca5c789840b54e58e94b8b71df.jpg
#  extracting: train/melanoma/ISIC_0071673_jpg.rf.0e3e66ed88700b76cf1591b01f927543.jpg
#  extracting: train/melanoma/ISIC_0071681_jpg.rf.526c5fc6ea014c2946b8e145464c9ce2.jpg
#  extracting: train/melanoma/ISIC_0071693_jpg.rf.cf9674f1ce940039371a8bb0b9f4fdcd.jpg
#  extracting: train/melanoma/ISIC_0071699_jpg.rf.b7ccd402b460e0b75205978afea43b86.jpg
#  extracting: train/melanoma/ISIC_0071700_jpg.rf.c288d0d7be025bda153a4c422a814c44.jpg
#  extracting: train/melanoma/ISIC_0071707_jpg.rf.affc6eeec0816c4985acbc9a1e50766c.jpg
#  extracting: train/melanoma/ISIC_0071710_jpg.rf.d3d3e90024dbe5f7b943b1f679ec7311.jpg
#  extracting: train/melanoma/ISIC_0071712_jpg.rf.dfe8380ea34f1cfc51f3eaa610883c42.jpg
#  extracting: train/melanoma/ISIC_0071713_jpg.rf.b08138dfc1c1e1385e76fa7f18968b61.jpg
#  extracting: train/melanoma/ISIC_0071722_jpg.rf.cc82a90f19623d9af0961f05fdd16501.jpg
#  extracting: train/melanoma/ISIC_0071725_jpg.rf.ef615e4874dd608413c5bb005223fae2.jpg
#  extracting: train/melanoma/ISIC_0071726_jpg.rf.87de9473056c6df5416937c15f956a09.jpg
#  extracting: train/melanoma/ISIC_0071765_jpg.rf.d2b1db7ebf8ab078187cbef6916a6ed1.jpg
#  extracting: train/melanoma/ISIC_0071767_jpg.rf.64098d212c69f895cc266e71965bfe00.jpg
#  extracting: train/melanoma/ISIC_0071771_jpg.rf.2dd2a96d6bf431d11217a55efb1ce125.jpg
#  extracting: train/melanoma/ISIC_0071776_jpg.rf.e993072ce012295a67c9f2435964856c.jpg
#  extracting: train/melanoma/ISIC_0071778_jpg.rf.941b69b8182879cc05444c874a79837f.jpg
#  extracting: train/melanoma/ISIC_0071782_jpg.rf.ecc41d43d07020cee951afc8df876f48.jpg
#  extracting: train/melanoma/ISIC_0071783_jpg.rf.60b408dc9eb7593851976f47ac9a3747.jpg
#  extracting: train/melanoma/ISIC_0071788_jpg.rf.da68e21bdce2fc47ec0c5049bb3fa179.jpg
#  extracting: train/melanoma/ISIC_0071797_jpg.rf.6a90357d5cb8977f7bb29dabaac5cc96.jpg
#  extracting: train/melanoma/ISIC_0071800_jpg.rf.63b262d3ceaad41c39d171f5a1ec476f.jpg
#  extracting: train/melanoma/ISIC_0071808_jpg.rf.d703a7a8da7042e62322fafcccb1eb9b.jpg
#  extracting: train/melanoma/ISIC_0071815_jpg.rf.86b89e222a75164a7539127ac52e2d9f.jpg
#  extracting: train/melanoma/ISIC_0071826_jpg.rf.504cd51776333a5528303fb6fc341dd2.jpg
#  extracting: train/melanoma/ISIC_0071827_jpg.rf.09538fb9bccb01564ef301746e5bb415.jpg
#  extracting: train/melanoma/ISIC_0071857_jpg.rf.4b824e45a8f4d9f0dfa165046bed3a8e.jpg
#  extracting: train/melanoma/ISIC_0071865_jpg.rf.33bde80bc169ff933a48101ecb484498.jpg
#  extracting: train/melanoma/ISIC_0071869_jpg.rf.b39a230d453896524e3bbc50e054bad6.jpg
#  extracting: train/melanoma/ISIC_0071875_jpg.rf.412aee971b92dc3bebdaf344eb62858a.jpg
#  extracting: train/melanoma/ISIC_0071892_jpg.rf.c45e60d93fe04a642df4eb999779a3bd.jpg
#  extracting: train/melanoma/ISIC_0071901_jpg.rf.618e3f4fba34a4a53dc2ca61cac1b175.jpg
#  extracting: train/melanoma/ISIC_0071910_jpg.rf.069bbd67b8b0e33dc38892ad9503d55c.jpg
#  extracting: train/melanoma/ISIC_0071913_jpg.rf.faa4d8eac01e718d5e9d3f734466a5b0.jpg
#  extracting: train/melanoma/ISIC_0071916_jpg.rf.6605c8ef95d27a1ca0d9c9567e164bcb.jpg
#  extracting: train/melanoma/ISIC_0071931_jpg.rf.52d9397811379b6e764ab4369d67b344.jpg
#  extracting: train/melanoma/ISIC_0071944_jpg.rf.1cbf2407b2b279cf0114e3e8aaaec7eb.jpg
#  extracting: train/melanoma/ISIC_0071951_jpg.rf.e72ea31451927b4af9d612f6fbeb0380.jpg
#  extracting: train/melanoma/ISIC_0071957_jpg.rf.fa9b6d8fb00d61d37d2f0312660340df.jpg
#  extracting: train/melanoma/ISIC_0071959_jpg.rf.71f5cfaf6e9ecc49a9765a248bb8b86e.jpg
#  extracting: train/melanoma/ISIC_0071972_jpg.rf.c6588afa6003a8dffb11d21a97e0c547.jpg
#  extracting: train/melanoma/ISIC_0071992_jpg.rf.1de731a36d99f51f86d64ded087c827e.jpg
#  extracting: train/melanoma/ISIC_0071996_jpg.rf.a97db0952ad0b74e40f3b4fd489beecc.jpg
#  extracting: train/melanoma/ISIC_0071997_jpg.rf.56ff451236497f2609c37c09c8e70dcf.jpg
#  extracting: train/melanoma/ISIC_0072002_jpg.rf.1ff802ac0caae518cb6303725e5f0f10.jpg
#  extracting: train/melanoma/ISIC_0072004_jpg.rf.39d4c70831d03727bb42d2c57f7167ce.jpg
#  extracting: train/melanoma/ISIC_0072010_jpg.rf.fb3e14b627f816b3b418230e3e31020d.jpg
#  extracting: train/melanoma/ISIC_0072021_jpg.rf.68168d1aed6b96f270b10e326cda009c.jpg
#  extracting: train/melanoma/ISIC_0072025_jpg.rf.14009c336299ff588784e9ccd4f8b3fa.jpg
#  extracting: train/melanoma/ISIC_0072030_jpg.rf.e50b5f9a8357f39621b23e6b096d05e4.jpg
#  extracting: train/melanoma/ISIC_0072041_jpg.rf.b151a13a8562464ab1d275c3b392b129.jpg
#  extracting: train/melanoma/ISIC_0072051_jpg.rf.ab1567efecf6d8d0ef453ad9ba763033.jpg
#  extracting: train/melanoma/ISIC_0072061_jpg.rf.7eef9c1a4c23a103ad83bc70147321ae.jpg
#  extracting: train/melanoma/ISIC_0072063_jpg.rf.4bc75c16b199baac54a255599c60618a.jpg
#  extracting: train/melanoma/ISIC_0072077_jpg.rf.fac3c01d0cd34379d087e5ed80730eb3.jpg
#  extracting: train/melanoma/ISIC_0072078_jpg.rf.348f7821497ee4cdcbc919d1b94d6916.jpg
#  extracting: train/melanoma/ISIC_0072087_jpg.rf.48061047923f74a51ce5e425df7cd5ab.jpg
#  extracting: train/melanoma/ISIC_0072093_jpg.rf.4c39ee86e43ae2cebf0cf31e0525f924.jpg
#  extracting: train/melanoma/ISIC_0072109_jpg.rf.0e4d829a6d433306ec6d8560d90b3f1b.jpg
#  extracting: train/melanoma/ISIC_0072111_jpg.rf.f83f06faeb743752351f83f04283a250.jpg
#  extracting: train/melanoma/ISIC_0072143_jpg.rf.73f2609b5279c84847e9d891439d8098.jpg
#  extracting: train/melanoma/ISIC_0072151_jpg.rf.67d95beb2b56b023fbc85e9236153b96.jpg
#  extracting: train/melanoma/ISIC_0072157_jpg.rf.ba053798ecb801242eb91843b53fe8aa.jpg
#  extracting: train/melanoma/ISIC_0072171_jpg.rf.897a1d90d027d9b34574d5d15664414c.jpg
#  extracting: train/melanoma/ISIC_0072175_jpg.rf.f4f268ee9461f8edb5d17edf41049dc4.jpg
#  extracting: train/melanoma/ISIC_0072182_jpg.rf.62124de53955fef5f4eafdc0464016ed.jpg
#  extracting: train/melanoma/ISIC_0072194_jpg.rf.d05f80d705def7fc835a609e3cf1d4c6.jpg
#  extracting: train/melanoma/ISIC_0072195_jpg.rf.afadb3c8cb660cd7c41c11d675c58e29.jpg
#  extracting: train/melanoma/ISIC_0072204_jpg.rf.8635f3d08a4a6dee0b64b02e751cc7dc.jpg
#  extracting: train/melanoma/ISIC_0072215_jpg.rf.8ce3a0e7c3eb90b0a00b3a7077da1af6.jpg
#  extracting: train/melanoma/ISIC_0072223_jpg.rf.e29e9050ce0094d1031f7ce2e87901dd.jpg
#  extracting: train/melanoma/ISIC_0072241_jpg.rf.81d0f4e294bf41b232c072d3dcd87969.jpg
#  extracting: train/melanoma/ISIC_0072252_jpg.rf.166efdb376036717ea7b9e8d08d9671b.jpg
#  extracting: train/melanoma/ISIC_0072271_jpg.rf.983d4b2e95f74fe465571522ffce66fe.jpg
#  extracting: train/melanoma/ISIC_0072286_jpg.rf.ea2ae35bfa8865997284a1062b63ac70.jpg
#  extracting: train/melanoma/ISIC_0072287_jpg.rf.23e8affde6a91966ffc5d7a7f18fdbca.jpg
#  extracting: train/melanoma/ISIC_0072292_jpg.rf.27cae26799eb042a4f8276593f190620.jpg
#  extracting: train/melanoma/ISIC_0072294_jpg.rf.1981f13042cbddcc9627ac3fb4a324c4.jpg
#  extracting: train/melanoma/ISIC_0072299_jpg.rf.8dececa75591de1e51b22c6bea655702.jpg
#  extracting: train/melanoma/ISIC_0072301_jpg.rf.cccac5f046e02d623199afaa847e55a5.jpg
#  extracting: train/melanoma/ISIC_0072348_jpg.rf.63a528dd98610f5198f5fd528a4bc0cc.jpg
#  extracting: train/melanoma/ISIC_0072358_jpg.rf.26ceb91d9b29ea26dc845861e3bfbb19.jpg
#  extracting: train/melanoma/ISIC_0072360_jpg.rf.d4e04512a7a10610ee9794e12f9264c0.jpg
#  extracting: train/melanoma/ISIC_0072363_jpg.rf.f154901fa245a3b2098f41fdf0dbcefb.jpg
#  extracting: train/melanoma/ISIC_0072371_jpg.rf.019f2863d4ba2de3ccd64aa8c6b0ad0d.jpg
#  extracting: train/melanoma/ISIC_0072373_jpg.rf.1e22bb9fd55f6ba25a0904842b6bfa81.jpg
#  extracting: train/melanoma/ISIC_0072374_jpg.rf.1829d56eb703fe1cdd3bd79228ae5935.jpg
#  extracting: train/melanoma/ISIC_0072375_jpg.rf.02715833c09d08afe4a5cf624a334d28.jpg
#  extracting: train/melanoma/ISIC_0072377_jpg.rf.75ed65fd622a5825ddf876c495e277ba.jpg
#  extracting: train/melanoma/ISIC_0072380_jpg.rf.bf8899c30cd458832fb4f67b28aea690.jpg
#  extracting: train/melanoma/ISIC_0072382_jpg.rf.284278efe16f91419d5d20a78c86947b.jpg
#  extracting: train/melanoma/ISIC_0072383_jpg.rf.bc41f05bcc931e676b57ef0172ead640.jpg
#  extracting: train/melanoma/ISIC_0072405_jpg.rf.06f7835511c0af7e4aecda1777afe311.jpg
#  extracting: train/melanoma/ISIC_0072418_jpg.rf.c352eb61faf5b214baf0775d6f8acb99.jpg
#  extracting: train/melanoma/ISIC_0072424_jpg.rf.77c1cb8ad7ea7d772855e0622dff89cb.jpg
#  extracting: train/melanoma/ISIC_0072429_jpg.rf.9c7eff79d8fd9e5666495b2bc3d0b33b.jpg
#  extracting: train/melanoma/ISIC_0072439_jpg.rf.4d813545b074846a9e5fe52ce1c05934.jpg
#  extracting: train/melanoma/ISIC_0072440_jpg.rf.6ebe25c2bdd5830f6b6200d04e0f5f21.jpg
#  extracting: train/melanoma/ISIC_0072441_jpg.rf.a84ad3dbe49cd20b08894519e9ae3008.jpg
#  extracting: train/melanoma/ISIC_0072454_jpg.rf.3dcaea5a196372a7a6b64c270be07946.jpg
#  extracting: train/melanoma/ISIC_0072459_jpg.rf.cba87e7a1ee2735e6d5f7431a1e705dc.jpg
#  extracting: train/melanoma/ISIC_0072473_jpg.rf.9467fb842dc90e8901b779abb1999de9.jpg
#  extracting: train/melanoma/ISIC_0072495_jpg.rf.c39253124723fb793e61eb1bfc05a06b.jpg
#  extracting: train/melanoma/ISIC_0072496_jpg.rf.11bb31c157fde5eb2d1e8743fe4e2b04.jpg
#  extracting: train/melanoma/ISIC_0072507_jpg.rf.b527328622ed639e0d55e3b6215c8aa5.jpg
#  extracting: train/melanoma/ISIC_0072508_jpg.rf.8eba0de5e75c9a6e17a7efc11919b3a8.jpg
#  extracting: train/melanoma/ISIC_0072516_jpg.rf.4e45fbf6d1a19725e4ed9143a07fd105.jpg
#  extracting: train/melanoma/ISIC_0072522_jpg.rf.fc773a9e3ab45f2062628e793373b6a2.jpg
#  extracting: train/melanoma/ISIC_0072523_jpg.rf.3db960c422a31023c2b515c22a66d35b.jpg
#  extracting: train/melanoma/ISIC_0072531_jpg.rf.07b95365e8e1042d002fc5523ccb72cd.jpg
#  extracting: train/melanoma/ISIC_0072534_jpg.rf.afbdd69432c5c97785d15c4247bb2036.jpg
#  extracting: train/melanoma/ISIC_0072535_jpg.rf.61bd15d1f5b1df154c6bc23cc7746a94.jpg
#  extracting: train/melanoma/ISIC_0072542_jpg.rf.20e9ce6ca4569df1f238fac03ea8b673.jpg
#  extracting: train/melanoma/ISIC_0072559_jpg.rf.6e09df9eb92992e32f626216d0d23e80.jpg
#  extracting: train/melanoma/ISIC_0072564_jpg.rf.7c3bdc73f6e9622d3791a46059a0d0bf.jpg
#  extracting: train/melanoma/ISIC_0072568_jpg.rf.da301860f4d99d5e754d8ab38f4641ad.jpg
#  extracting: train/melanoma/ISIC_0072574_jpg.rf.d8fe64bf9b3f1ac819bc4f6e1ef2a25b.jpg
#  extracting: train/melanoma/ISIC_0072582_jpg.rf.26409eccbf996791a3a41b4244ab5ab9.jpg
#  extracting: train/melanoma/ISIC_0072585_jpg.rf.3570098483f256e65fdb515709965371.jpg
#  extracting: train/melanoma/ISIC_0072586_jpg.rf.b7a44b0df8b631b310b283d18f641ed2.jpg
#  extracting: train/melanoma/ISIC_0072594_jpg.rf.453c63f32d2724d138f33ae854ae2c84.jpg
#  extracting: train/melanoma/ISIC_0072595_jpg.rf.aae8a17d2af94416bfe37cdfd84eabf7.jpg
#  extracting: train/melanoma/ISIC_0072601_jpg.rf.4d33ae6e88eb389d6d3e714100fe9680.jpg
#  extracting: train/melanoma/ISIC_0072612_jpg.rf.f9996c891b53f45c31df8ecbc1a945ee.jpg
#  extracting: train/melanoma/ISIC_0072624_jpg.rf.d060fef589e13b3c457c3912abb1e6f0.jpg
#  extracting: train/melanoma/ISIC_0072626_jpg.rf.c3ebc2dda5768c3003814b8fad463890.jpg
#  extracting: train/melanoma/ISIC_0072641_jpg.rf.0b9b810d5c803abda32a62b527d29462.jpg
#  extracting: train/melanoma/ISIC_0072691_jpg.rf.f36543296b0727c8c0bb2f24c81445f3.jpg
#  extracting: train/melanoma/ISIC_0072694_jpg.rf.7ad5c2ee79de4b0177d404b16f244f16.jpg
#  extracting: train/melanoma/ISIC_0072713_jpg.rf.ed523fa0683780b5f5f26fcdf10ccafd.jpg
#  extracting: train/melanoma/ISIC_0072714_jpg.rf.4d074e56fcc65cc6fd444dbf0f2ddb4a.jpg
#  extracting: train/melanoma/ISIC_0072730_jpg.rf.aaf814c257235188a6d00ddf4a3ecfee.jpg
#  extracting: train/melanoma/ISIC_0072733_jpg.rf.570af5a5c4406f6cf72a76e5c51f6afc.jpg
#  extracting: train/melanoma/ISIC_0072738_jpg.rf.3223e39c0b2175dc6bed23ac758876dc.jpg
#  extracting: train/melanoma/ISIC_0072748_jpg.rf.8fff8d63b2ce7339283f447141b89a9c.jpg
#  extracting: train/melanoma/ISIC_0072755_jpg.rf.490e55107ad95ea5c885dce6c1ec0d45.jpg
#  extracting: train/melanoma/ISIC_0072768_jpg.rf.570f683410e26991cc581b7386f234d3.jpg
#  extracting: train/melanoma/ISIC_0072786_jpg.rf.23e1262611c88e361c202a9dc42b0be2.jpg
#  extracting: train/melanoma/ISIC_0072799_jpg.rf.c9c623b6063515c33030c0a2019a59e5.jpg
#  extracting: train/melanoma/ISIC_0072820_jpg.rf.6940ef2982618a49c799f47a8d0722e3.jpg
#  extracting: train/melanoma/ISIC_0072825_jpg.rf.2d28b20ecf9e64d8032d0a020b8d8138.jpg
#  extracting: train/melanoma/ISIC_0072827_jpg.rf.ac6a36f9f6da6f90ac05a9ae12fd5fa4.jpg
#  extracting: train/melanoma/ISIC_0072843_jpg.rf.46c272c478c08e322ebc38783a6ad550.jpg
#  extracting: train/melanoma/ISIC_0072865_jpg.rf.af9673c6dd3134fe266bd58e8eb21674.jpg
#  extracting: train/melanoma/ISIC_0072868_jpg.rf.b4dc94539e3c51290739143d314418fc.jpg
#  extracting: train/melanoma/ISIC_0072872_jpg.rf.1b84083a9c0d1561c268ed5985c84ec0.jpg
#  extracting: train/melanoma/ISIC_0072887_jpg.rf.262ad8dde6043978702be9e6143b82cf.jpg
#  extracting: train/melanoma/ISIC_0072896_jpg.rf.560d40d2dc88310b653676a5e6d306c3.jpg
#  extracting: train/melanoma/ISIC_0072909_jpg.rf.6bdbb1118a295942ebf77eb4e59b4702.jpg
#  extracting: train/melanoma/ISIC_0072917_jpg.rf.c186625c0298431df920489163925f66.jpg
#  extracting: train/melanoma/ISIC_0072923_jpg.rf.2bbf041eccc00738881980344a0ed093.jpg
#  extracting: train/melanoma/ISIC_0072924_jpg.rf.a5f0209fa4e103fa46ee8971ee1a675c.jpg
#  extracting: train/melanoma/ISIC_0072953_jpg.rf.04d822b2da49fbcd01fdccda70abcbf7.jpg
#  extracting: train/melanoma/ISIC_0072976_jpg.rf.06f6bf9000101f65373082af2720eccc.jpg
#  extracting: train/melanoma/ISIC_0072977_jpg.rf.d0a117e649931d88e7c0e08aa846baed.jpg
#  extracting: train/melanoma/ISIC_0072983_jpg.rf.8f691c8e458f9e1949a8656e7a753117.jpg
#  extracting: train/melanoma/ISIC_0072985_jpg.rf.7fdeccab9454d5eafece482b96d8ca3a.jpg
#  extracting: train/melanoma/ISIC_0072989_jpg.rf.24977e4086946e189b75f047f1c9e753.jpg
#  extracting: train/melanoma/ISIC_0072991_jpg.rf.f794545f804f8c814759c8538dd73e6e.jpg
#  extracting: train/melanoma/ISIC_0073016_jpg.rf.9146c41e8143ef05ea3b5490639d029f.jpg
#  extracting: train/melanoma/ISIC_0073018_jpg.rf.daa063011436a0a66d81a336ee0e35a4.jpg
#  extracting: train/melanoma/ISIC_0073032_jpg.rf.f1cbff23fe8e0428432695c4dca7306e.jpg
#  extracting: train/melanoma/ISIC_0073038_jpg.rf.9f8a1f6bdec4dfd107ea083f6b030b5c.jpg
#  extracting: train/melanoma/ISIC_0073044_jpg.rf.823a8a391827e1388911477ba88e4779.jpg
#  extracting: train/melanoma/ISIC_0073054_jpg.rf.ce7b58e6fba6f1452d071b5a682ab6b3.jpg
#  extracting: train/melanoma/ISIC_0073065_jpg.rf.991a3e12a389e9b29707eabfbd80c8aa.jpg
#  extracting: train/melanoma/ISIC_0073075_jpg.rf.cbaaed318e05f36738c928301927bb1b.jpg
#  extracting: train/melanoma/ISIC_0073097_jpg.rf.de71389021b21d6740548cdab6f34841.jpg
#  extracting: train/melanoma/ISIC_0073115_jpg.rf.794b80cb66a91240afce3cc7afe91b30.jpg
#  extracting: train/melanoma/ISIC_0073119_jpg.rf.3e87dbdcf48ac538af8f7f27bb2ba7ff.jpg
#  extracting: train/melanoma/ISIC_0073136_jpg.rf.cb2f9c9efc8438d47036e48f3c8011e9.jpg
#  extracting: train/melanoma/ISIC_0073143_jpg.rf.348acec3f8a085684b63072199b4bf34.jpg
#  extracting: train/melanoma/ISIC_0073147_jpg.rf.b75bb7e84ef1fdd8b39c9453ec690fa1.jpg
#  extracting: train/melanoma/ISIC_0073168_jpg.rf.44220ce365d3921f85d86f283d7259cf.jpg
#  extracting: train/melanoma/ISIC_0073203_jpg.rf.362a720740f068b461e470d47486eec7.jpg
#  extracting: train/melanoma/ISIC_0073210_jpg.rf.6885938ec6ff2b739b4cc028407c85a3.jpg
#  extracting: train/melanoma/ISIC_0073231_jpg.rf.740ba20c7e2b00fdbb6094d7dee296ef.jpg
#  extracting: train/melanoma/ISIC_0073237_jpg.rf.26dd47f71a5b82d18929cc150737a9e0.jpg
#  extracting: train/melanoma/ISIC_0073238_jpg.rf.aa0ea0bc0cd243c3b8412ff25d40978d.jpg
#  extracting: train/melanoma/ISIC_0073249_jpg.rf.0341a41ef9e6b609b9086a41467a839f.jpg

# %% [markdown]
# ### Inspect the Data
# Let's inspect the data. The folder we downloaded and extracted from Kaggle has 12 subfolders, each of which corresponds to one type of seedling with its respective images inside. These will be our labels for the classification task.
#
# If we print the lengths of the contents of these folders we can see that every folder contains a different amount of images. The differences are great, see e.g. that the 'Loose Silky-bent' has the most images (762) while the 'Common Wheat' the fewest (253). We will see later if this amounts to differences in the prediction accuracy.

# %%
import os
labels = os.listdir("train")
print("No. of labels: {}".format(len(labels)))
print("-----------------")

for label in labels:
    print("{}, {} files".format(label, len(os.listdir("train/"+label))))
# Out:
# No. of labels: 6
# -----------------
# dermatofibroma, 191 files
# chickenpox, 832 files
# measles, 613 files
# cowpox, 745 files
# actinic_keratoses, 686 files
# melanoma, 3612 files

# %% [markdown]
# Let's have a look at those images. For each of the 10 labels, we will print one random seedling.

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

fig, ax = plt.subplots(nrows=2, ncols=2)
fig.tight_layout()
cnt = 0
for row in ax:
    for col in row:
        image_name = np.random.choice(os.listdir("train/" + labels[cnt]))
        im = Image.open("train/{}/{}".format(labels[cnt],image_name))
        col.imshow(im)
        col.set_title(labels[cnt])
        col.axis('off')
        cnt += 1
plt.show()

# %% [markdown]
# Alright, they look good with a wide array of images!

# %% [markdown]
# ## Creating the Fastai Model

# %% [markdown]
# We can now create the CNN model using the `Fastai` library. Since its major update to v1, it got a lot clearer and consistent, so we only need to import the vision module and accuracy for our metric.

# %%
from fastai.vision.all import *
from fastai.metrics import accuracy

# %% [markdown]
# `Fastai` has a really nice class for handling everything related to the input images for vision tasks. It is called [`ImageDataBunch`](https://docs.fast.ai/vision.data.html#ImageDataBunch) and has different functions, respective of the different ways data can be presented to the network. Since our images are placed in folders whose names correspond to the image labels, we will use the `ImageDataBunch.from_folder()` function to create an object that contains our image data. This is super useful and makes it incredibly easy to read the data into our model, as you will see in a bit.
#
# What's even more handy is that `Fastai` can automatically split our data into train and validation sets, so we don't even need to create these on our own.
#
# The only hyperparameters we need now are the **path-variable** pointing to our data set, the **size of the inputs** and the **batch size** for each gradient descent iteration. To make matters simple, the `ImageDataBunch` object will scale all images to a size*size squared image unless otherwise instructed.
#
# A quick note on image size: the bigger an image, the more details the CNN will be able to pick out of it. At the same time, a bigger image means longer computation times. On the same note it might be that your GPU runs out of memory for a too large batch size. You can half the batch size if this is the case.

# %%
path = "train/"
# size = 224 -> Les images son de 320x240, natives de la Webcam
bs = 64

# %% [markdown]
# We will create a variable called `data` in which we place the `ImageDataBunch` object. We create this object with the `from_folder()` function that we discussed above. Among the path to our data, the image and batch size, it also takes:
# * a function argument called `get_transforms()` which returns a list of available image transformations upon call.
# * a parameter `valid_pct` which controls the percentage of images that will be randomly chosen to be in the validation set
# * a parameter `flip_vert` which controls vertical flips and 90° turns in addition to just horizontal flips. (Since our plant images are taken from above, we can perform those without a problem, which would not be feasible on e.g. face data.)

# %%
data = ImageDataLoaders.from_folder(path,
                                  valid_pct=0.2, bs=bs, batch_tfms=[Normalize.from_stats(*imagenet_stats)])

# %%
# data = ImageDataBunch.from_folder(path, ds_tfms=get_transforms(do_flip=True, flip_vert=True),
 #                                 valid_pct=0.2, size=size, bs=bs)

# %% [markdown]
# To normalize the data in our object, we simply call `normalize()` on the object. It is possible to use ImageNet, CIFAR or MNIST stats as templates here, and if left empty this function will simply grab a batch of data from our object and compute the stats on it (mean and standard-deviation) and normalize the data accordingly. Since we will be using a ResNet architecture for our model which was trained on ImageNet, we will be using the ImageNet stats. DEPRECATED !! ARA ES FA DINS DE LA INSTRUCCIO ANTERIOR!

# %%
#data.normalize(imagenet_stats)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-c885932acb73> in <cell line: 0>()
# ----> 1 data.normalize(imagenet_stats)
#
# /usr/local/lib/python3.11/dist-packages/fastcore/basics.py in __getattr__(self, k)
#     534         if self._component_attr_filter(k):
#     535             attr = getattr(self,self._default,None)
# --> 536             if attr is not None: return getattr(attr,k)
#     537         raise AttributeError(k)
#     538     def __dir__(self): return custom_dir(self,self._dir())
#
# /usr/local/lib/python3.11/dist-packages/fastcore/basics.py in __getattr__(self, k)
#     534         if self._component_attr_filter(k):
#     535             attr = getattr(self,self._default,None)
# --> 536             if attr is not None: return getattr(attr,k)
#     537         raise AttributeError(k)
#     538     def __dir__(self): return custom_dir(self,self._dir())
#
# /usr/local/lib/python3.11/dist-packages/fastai/data/core.py in __getattr__(self, k)
#     450         return res if is_indexer(it) else list(zip(*res))
#     451
# --> 452     def __getattr__(self,k): return gather_attrs(self, k, 'tls')
#     453     def __dir__(self): return super().__dir__() + gather_attr_names(self, 'tls')
#     454     def __len__(self): return len(self.tls[0])
#
# /usr/local/lib/python3.11/dist-packages/fastcore/transform.py in gather_attrs(o, k, nm)
#     173     att = getattr(o,nm)
#     174     res = [t for t in att.attrgot(k) if t is not None]
# --> 175     if not res: raise AttributeError(k)
#     176     return res[0] if len(res)==1 else L(res)
#     177
#
# AttributeError: normalize

# %% [markdown]
# That's it, two lines of code for optimizing our dataset for training, adding different kinds of transformations and normalization! I would kindly ask you to stop here for a moment and just take a second to appreciate the beauty of this. The beauty of high-level libraries; just two lines of code and we have increased the diversity of our dataset tremendously. I can already hear my ugly batchnorm code crying in the trashbin.
#
# All that is left now is to create the actual network and train it, which could not be more simple.
#
# `Fastai` supplies us with a function called [`create_cnn()`](https://docs.fast.ai/vision.learner.html#create_cnn) from its vision module. This function creates what is called a `learner` object, which we'll put into a properly named variable. See here that we specify the ResNet architecture as our base model for transfer learning. Upon call, the trained architecture will be downloaded via the `Fastai` API and stored locally.
#
# We will use accuracy for our metric. If you check the [docs](https://docs.fast.ai/metrics.html) you can see a list of other metrics which are availabe. Defining the callback function `ShowGraph` simply tells the learner that it should return a graph for whatever it does, which seems very useful to me for seeing whether the model is still improving.

# %%
learner = cnn_learner(data, models.resnet18, metrics=[accuracy])#, callback_fns=ShowGraph)
# Out:
# /usr/local/lib/python3.11/dist-packages/fastai/vision/learner.py:303: UserWarning: `cnn_learner` has been renamed to `vision_learner` -- please update your code
#   warn("`cnn_learner` has been renamed to `vision_learner` -- please update your code")
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 194MB/s]

# %% [markdown]
# ### Finding the learning rate
#
# The learner object we create comes with a build-in function to find the optimal learning rate, or range of learning rates, for training. It achieves this by fitting the model for a few epochs and saving for which learning rates the loss decreases the most.
#
# We want to choose a learning rate, for which the loss is still decreasing, i.e. we do not want the learning rate with the minimum loss, but with the steepest slope.
#
# In the following plot, which is stored in the recorder object of our learner, we can see that this is the case for learning rates between 0.001 and 0.01.

# %%
learner.lr_find()
learner.recorder.plot()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1746584363.py in <cell line: 0>()
#       1 learner.lr_find()
# ----> 2 learner.recorder.plot()
#
# /usr/local/lib/python3.11/dist-packages/fastcore/basics.py in __getattr__(self, k)
#     534         if self._component_attr_filter(k):
#     535             attr = getattr(self,self._default,None)
# --> 536             if attr is not None: return getattr(attr,k)
#     537         raise AttributeError(k)
#     538     def __dir__(self): return custom_dir(self,self._dir())
#
# /usr/local/lib/python3.11/dist-packages/fastcore/basics.py in __getattr__(self, k)
#     534         if self._component_attr_filter(k):
#     535             attr = getattr(self,self._default,None)
# --> 536             if attr is not None: return getattr(attr,k)
#     537         raise AttributeError(k)
#     538     def __dir__(self): return custom_dir(self,self._dir())
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in __getattr__(self, name)
#    1926             if name in modules:
#    1927                 return modules[name]
# -> 1928         raise AttributeError(
#    1929             f"'{type(self).__name__}' object has no attribute '{name}'"
#    1930         )
#
# AttributeError: 'Sequential' object has no attribute 'plot'

# %% [markdown]
# ### First fit and evaluation
# Now let's fit our model for 8 epochs, with a learning rate between 0.001 and 0.01

# %%
learner.fit_one_cycle(8, slice(1e-3, 1e-2))
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.884202</td>
#       <td>0.456728</td>
#       <td>0.851685</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.578412</td>
#       <td>0.372482</td>
#       <td>0.868914</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.421602</td>
#       <td>0.433020</td>
#       <td>0.856929</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.340334</td>
#       <td>0.282786</td>
#       <td>0.897378</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.245266</td>
#       <td>0.245814</td>
#       <td>0.916854</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.170685</td>
#       <td>0.231613</td>
#       <td>0.916854</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.118546</td>
#       <td>0.218309</td>
#       <td>0.926592</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.092452</td>
#       <td>0.214676</td>
#       <td>0.923595</td>
#       <td>00:19</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# That already looks good! The loss is decreasing a lot in the first few 1/5th of iterations, and less but continously afterwards.
#
# Let's see where the algorithm is making the most mistakes:

# %%
interpreter = ClassificationInterpretation.from_learner(learner)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
interpreter.most_confused(min_val=2)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# [('melanoma', 'actinic_keratoses', np.int64(35)),
#  ('actinic_keratoses', 'melanoma', np.int64(29)),
#  ('dermatofibroma', 'melanoma', np.int64(13)),
#  ('chickenpox', 'measles', np.int64(6)),
#  ('actinic_keratoses', 'dermatofibroma', np.int64(5)),
#  ('melanoma', 'dermatofibroma', np.int64(4)),
#  ('dermatofibroma', 'actinic_keratoses', np.int64(3)),
#  ('measles', 'cowpox', np.int64(3)),
#  ('measles', 'chickenpox', np.int64(2))]

# %% [markdown]
# This shows us that the algorithm confuses a few of our class examples, but it's doing well, overall.

# %% [markdown]
# ## Improving the Model

# %% [markdown]
# ### Unfreezing and fine-tuning
# Before we unfreeze the layers and learn again, we save the weights (SAVE) so we can go back in case we mess up.
# GASTEM EXPORT PA PILLAR TOT EL MODEL

# %%
learner.export('biological-stage-1-bo')

#learner.save('stage-1')
#learner.load('stage-1')

# %%
learner.unfreeze()

# %%
learner.fit_one_cycle(12, slice(1e-5, 1e-4))
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.087356</td>
#       <td>0.216821</td>
#       <td>0.923595</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.076198</td>
#       <td>0.219200</td>
#       <td>0.926592</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.067760</td>
#       <td>0.217359</td>
#       <td>0.922097</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.050614</td>
#       <td>0.193105</td>
#       <td>0.931835</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.038466</td>
#       <td>0.207465</td>
#       <td>0.931835</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.026777</td>
#       <td>0.188469</td>
#       <td>0.937079</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.018800</td>
#       <td>0.181709</td>
#       <td>0.935581</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.012858</td>
#       <td>0.193531</td>
#       <td>0.939326</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.009748</td>
#       <td>0.194437</td>
#       <td>0.936330</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.009177</td>
#       <td>0.185728</td>
#       <td>0.943071</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.007032</td>
#       <td>0.189457</td>
#       <td>0.946067</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.005650</td>
#       <td>0.190743</td>
#       <td>0.938577</td>
#       <td>00:25</td>
#     </tr>
#   </tbody>
# </table>

# %%
torch.save(learner.model, 'biological-stage-2-pytorch')

#learner.export('stage-2-bo')

#learner.save('stage-2')

# %% [markdown]
# We will stick to this, because the validation error is getting worse than the testing error, and it looks like this tendency will only increase. The model would start to **overfit the training data** if we continue training from this point onwards!
#
# Good job, we successfully trained a state-of-the-art image classifier for a custom dataset, achieving 96.5% accuracy in just a handful of lines of code!

# %%
interpreter = ClassificationInterpretation.from_learner(learner)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
interpreter.most_confused(min_val=2)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# [('actinic_keratoses', 'melanoma', np.int64(27)),
#  ('melanoma', 'actinic_keratoses', np.int64(27)),
#  ('dermatofibroma', 'melanoma', np.int64(9)),
#  ('melanoma', 'dermatofibroma', np.int64(4)),
#  ('cowpox', 'chickenpox', np.int64(3)),
#  ('dermatofibroma', 'actinic_keratoses', np.int64(3)),
#  ('measles', 'chickenpox', np.int64(3)),
#  ('actinic_keratoses', 'dermatofibroma', np.int64(2))]
