# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
(X_train, y_train), (X_test, y_test) = keras.datasets.cifar10.load_data()
# checking images shape
X_train.shape, X_test.shape


# scaling image values between 0-1
X_train_scaled = X_train/255
X_test_scaled = X_test/255

# one hot encoding labels
y_train_encoded = keras.utils.to_categorical(y_train, num_classes = 10, dtype = 'float32')
y_test_encoded = keras.utils.to_categorical(y_test, num_classes = 10, dtype = 'float32')

# %%
def get_model():
    model = keras.Sequential([
        keras.layers.Flatten(input_shape=(32,32,3)),
        keras.layers.Dense(3000, activation='relu'),
        keras.layers.Dense(1000, activation='relu'),
        keras.layers.Dense(10, activation='sigmoid')    
    ])
    model.compile(optimizer='SGD',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
    return model

# %%
# %%timeit -n1 -r1
# CPU
with tf.device('/CPU:0'):
    model_cpu = get_model()
    model_cpu.fit(X_train_scaled, y_train_encoded, epochs = 1)
# Out:
# 1563/1563 [==============================] - 33s 21ms/step - loss: 1.8115 - accuracy: 0.3571
# 34.4 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)

# %%
# !nvidia-smi -L

import tensorflow as tf
tf.test.gpu_device_name()

from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# GPU 0: NVIDIA GeForce RTX 3070 (UUID: GPU-59bcf217-c061-0021-761c-e5d329b5be78)
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 12208577060701617687
#  xla_global_id: -1,
#  name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 5721030656
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 11852947158928076952
#  physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 3070, pci bus id: 0000:65:00.0, compute capability: 8.6"
#  xla_global_id: 416903419]

# %%
# %%timeit -n1 -r1
# GPU
with tf.device('/GPU:0'):
    model_gpu = get_model()
    model_gpu.fit(X_train_scaled, y_train_encoded, epochs = 10, batch_size = 8)
# Out:
# Epoch 1/10
# 6250/6250 [==============================] - 12s 2ms/step - loss: 1.7714 - accuracy: 0.3619
# Epoch 2/10
# 6250/6250 [==============================] - 12s 2ms/step - loss: 1.5810 - accuracy: 0.4355
# Epoch 3/10
# 6250/6250 [==============================] - 12s 2ms/step - loss: 1.4931 - accuracy: 0.4677
# Epoch 4/10
# 6250/6250 [==============================] - 12s 2ms/step - loss: 1.4279 - accuracy: 0.4923
# Epoch 5/10
# 6250/6250 [==============================] - 12s 2ms/step - loss: 1.3727 - accuracy: 0.5121
# Epoch 6/10
# 6250/6250 [==============================] - 12s 2ms/step - loss: 1.3261 - accuracy: 0.5280
# Epoch 7/10
# 6250/6250 [==============================] - 12s 2ms/step - loss: 1.2794 - accuracy: 0.5472
# Epoch 8/10
# 6250/6250 [==============================] - 12s 2ms/step - loss: 1.2371 - accuracy: 0.5591
# Epoch 9/10
# 6250/6250 [==============================] - 12s 2ms/step - loss: 1.1958 - accuracy: 0.5737
# Epoch 10/10
# ...

# %%
# %%timeit -n1 -r1
# GPU
with tf.device('/GPU:0'):
    model_gpu = get_model()
    model_gpu.fit(X_train_scaled, y_train_encoded, epochs = 100, batch_size =512)
# Out:
# Epoch 1/100
# 98/98 [==============================] - 1s 6ms/step - loss: 2.0596 - accuracy: 0.2732
# Epoch 2/100
# 98/98 [==============================] - 1s 6ms/step - loss: 1.8891 - accuracy: 0.3468
# Epoch 3/100
# 98/98 [==============================] - 1s 6ms/step - loss: 1.8260 - accuracy: 0.3676
# Epoch 4/100
# 98/98 [==============================] - 1s 6ms/step - loss: 1.7863 - accuracy: 0.3804
# Epoch 5/100
# 98/98 [==============================] - 1s 6ms/step - loss: 1.7576 - accuracy: 0.3921
# Epoch 6/100
# 98/98 [==============================] - 1s 6ms/step - loss: 1.7346 - accuracy: 0.4005
# Epoch 7/100
# 98/98 [==============================] - 1s 6ms/step - loss: 1.7107 - accuracy: 0.4108
# Epoch 8/100
# 98/98 [==============================] - 1s 6ms/step - loss: 1.6934 - accuracy: 0.4137
# Epoch 9/100
# 98/98 [==============================] - 1s 6ms/step - loss: 1.6739 - accuracy: 0.4213
# Epoch 10/100
# ...
